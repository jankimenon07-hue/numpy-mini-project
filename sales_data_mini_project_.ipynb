# %%
# @title
import numpy as np

data = np.genfromtxt(
    "datasets/sales_data.csv",
    delimiter=",",
    skip_header=1,
    encoding="latin1",
    filling_values=np.nan,
    invalid_raise=False
)
data.shape
np.isnan(data).sum()
np.isnan(data).sum(axis=0)
# Out:
# C:\Users\lulum\AppData\Local\Temp\ipykernel_26456\4040227948.py:4: ConversionWarning: Some errors were detected !
#     Line #8 (got 26 columns instead of 25)
#     Line #9 (got 26 columns instead of 25)
#     Line #11 (got 26 columns instead of 25)
#     Line #12 (got 26 columns instead of 25)
#     Line #16 (got 26 columns instead of 25)
#     Line #18 (got 26 columns instead of 25)
#     Line #23 (got 26 columns instead of 25)
#     Line #24 (got 26 columns instead of 25)
#     Line #26 (got 26 columns instead of 25)
#     Line #27 (got 26 columns instead of 25)
#     Line #29 (got 26 columns instead of 25)
#     Line #30 (got 27 columns instead of 25)
#     Line #32 (got 27 columns instead of 25)
#     Line #34 (got 26 columns instead of 25)
#     Line #35 (got 26 columns instead of 25)
#     Line #36 (got 27 columns instead of 25)
#     Line #41 (got 26 columns instead of 25)
#     Line #42 (got 26 columns instead of 25)
#     Line #45 (got 26 columns instead of 25)
#     Line #49 (got 26 columns instead of 25)
#     Line #53 (got 26 columns instead of 25)
#     Line #55 (got 26 columns instead of 25)
#     Line #57 (got 26 columns instead of 25)
#     Line #62 (got 26 columns instead of 25)
#     Line #63 (got 26 columns instead of 25)
#     Line #65 (got 27 columns instead of 25)
#     Line #66 (got 26 columns instead of 25)
#     Line #70 (got 26 columns instead of 25)
#     Line #72 (got 26 columns instead of 25)
#     Line #76 (got 26 columns instead of 25)
#     Line #77 (got 26 columns instead of 25)
#     Line #78 (got 26 columns instead of 25)
#     Line #80 (got 26 columns instead of 25)
#     Line #81 (got 26 columns instead of 25)
#     Line #83 (got 26 columns instead of 25)
#     Line #88 (got 26 columns instead of 25)
#     Line #89 (got 26 columns instead of 25)
#     Line #91 (got 27 columns instead of 25)
#     Line #92 (got 26 columns instead of 25)
#     Line #96 (got 26 columns instead of 25)
#     Line #98 (got 26 columns instead of 25)
#     Line #102 (got 26 columns instead of 25)
#     Line #104 (got 26 columns instead of 25)
#     Line #106 (got 26 columns instead of 25)
#     Line #107 (got 26 columns instead of 25)
#     Line #110 (got 26 columns instead of 25)
#     Line #112 (got 26 columns instead of 25)
#     Line #115 (got 26 columns instead of 25)
#     Line #116 (got 26 columns instead of 25)
#     Line #117 (got 26 columns instead of 25)
#     Line #122 (got 26 columns instead of 25)
#     Line #124 (got 26 columns instead of 25)
#     Line #128 (got 26 columns instead of 25)
#     Line #130 (got 26 columns instead of 25)
#     Line #136 (got 27 columns instead of 25)
#     Line #137 (got 27 columns instead of 25)
#     Line #139 (got 27 columns instead of 25)
#     Line #141 (got 26 columns instead of 25)
#     Line #142 (got 26 columns instead of 25)
#     Line #143 (got 27 columns instead of 25)
#     Line #149 (got 26 columns instead of 25)
#     Line #155 (got 26 columns instead of 25)
#     Line #156 (got 26 columns instead of 25)
#     Line #158 (got 26 columns instead of 25)
#     Line #160 (got 26 columns instead of 25)
#     Line #162 (got 26 columns instead of 25)
#     Line #163 (got 16 columns instead of 25)
#     Line #164 (got 26 columns instead of 25)
#     Line #168 (got 26 columns instead of 25)
#     Line #169 (got 26 columns instead of 25)
#     Line #170 (got 26 columns instead of 25)
#     Line #171 (got 26 columns instead of 25)
#     Line #172 (got 26 columns instead of 25)
#     Line #173 (got 26 columns instead of 25)
#     Line #175 (got 26 columns instead of 25)
#     Line #178 (got 26 columns instead of 25)
#     Line #179 (got 26 columns instead of 25)
#     Line #180 (got 26 columns instead of 25)
#     Line #181 (got 26 columns instead of 25)
#     Line #184 (got 26 columns instead of 25)
#     Line #185 (got 26 columns instead of 25)
#     Line #189 (got 27 columns instead of 25)
#     Line #192 (got 26 columns instead of 25)
#     Line #193 (got 27 columns instead of 25)
#     Line #197 (got 27 columns instead of 25)
#     Line #198 (got 26 columns instead of 25)
#     Line #199 (got 26 columns instead of 25)
#     Line #200 (got 26 columns instead of 25)
#     Line #204 (got 26 columns instead of 25)
#     Line #207 (got 27 columns instead of 25)
#     Line #208 (got 27 columns instead of 25)
#     Line #216 (got 27 columns instead of 25)
#     Line #218 (got 27 columns instead of 25)
#     Line #220 (got 26 columns instead of 25)
#     Line #221 (got 26 columns instead of 25)
#     Line #222 (got 27 columns instead of 25)
#     Line #224 (got 26 columns instead of 25)
#     Line #227 (got 26 columns instead of 25)
#     Line #228 (got 26 columns instead of 25)
#     Line #231 (got 26 columns instead of 25)
#     Line #235 (got 26 columns instead of 25)
#     Line #237 (got 26 columns instead of 25)
#     Line #239 (got 26 columns instead of 25)
#     Line #241 (got 26 columns instead of 25)
#     Line #247 (got 26 columns instead of 25)
#     Line #248 (got 26 columns instead of 25)
#     Line #251 (got 26 columns instead of 25)
#     Line #252 (got 26 columns instead of 25)
#     Line #258 (got 26 columns instead of 25)
#     Line #264 (got 26 columns instead of 25)
#     Line #266 (got 26 columns instead of 25)
#     Line #267 (got 26 columns instead of 25)
#     Line #268 (got 26 columns instead of 25)
#     Line #269 (got 27 columns instead of 25)
#     Line #272 (got 26 columns instead of 25)
#     Line #273 (got 27 columns instead of 25)
#     Line #277 (got 27 columns instead of 25)
#     Line #278 (got 26 columns instead of 25)
#     Line #279 (got 26 columns instead of 25)
#     Line #280 (got 26 columns instead of 25)
#     Line #284 (got 26 columns instead of 25)
#     Line #287 (got 27 columns instead of 25)
#     Line #288 (got 27 columns instead of 25)
#     Line #289 (got 26 columns instead of 25)
#     Line #290 (got 26 columns instead of 25)
#     Line #293 (got 16 columns instead of 25)
#     Line #294 (got 26 columns instead of 25)
#     Line #297 (got 26 columns instead of 25)
#     Line #299 (got 26 columns instead of 25)
#     Line #300 (got 26 columns instead of 25)
#     Line #301 (got 26 columns instead of 25)
#     Line #302 (got 26 columns instead of 25)
#     Line #303 (got 26 columns instead of 25)
#     Line #305 (got 26 columns instead of 25)
#     Line #308 (got 26 columns instead of 25)
#     Line #309 (got 26 columns instead of 25)
#     Line #310 (got 26 columns instead of 25)
#     Line #311 (got 26 columns instead of 25)
#     Line #314 (got 26 columns instead of 25)
#     Line #319 (got 27 columns instead of 25)
#     Line #322 (got 26 columns instead of 25)
#     Line #323 (got 27 columns instead of 25)
#     Line #327 (got 27 columns instead of 25)
#     Line #328 (got 26 columns instead of 25)
#     Line #329 (got 26 columns instead of 25)
#     Line #330 (got 26 columns instead of 25)
#     Line #334 (got 26 columns instead of 25)
#     Line #337 (got 27 columns instead of 25)
#     Line #340 (got 26 columns instead of 25)
#     Line #344 (got 16 columns instead of 25)
#     Line #345 (got 26 columns instead of 25)
#     Line #349 (got 26 columns instead of 25)
#     Line #350 (got 26 columns instead of 25)
#     Line #351 (got 26 columns instead of 25)
#     Line #352 (got 26 columns instead of 25)
#     Line #353 (got 26 columns instead of 25)
#     Line #354 (got 26 columns instead of 25)
#     Line #356 (got 26 columns instead of 25)
#     Line #359 (got 26 columns instead of 25)
#     Line #360 (got 26 columns instead of 25)
#     Line #361 (got 26 columns instead of 25)
#     Line #362 (got 26 columns instead of 25)
#     Line #365 (got 26 columns instead of 25)
#     Line #366 (got 26 columns instead of 25)
#     Line #369 (got 26 columns instead of 25)
#     Line #372 (got 26 columns instead of 25)
#     Line #373 (got 26 columns instead of 25)
#     Line #374 (got 27 columns instead of 25)
#     Line #375 (got 26 columns instead of 25)
#     Line #376 (got 27 columns instead of 25)
#     Line #381 (got 26 columns instead of 25)
#     Line #389 (got 27 columns instead of 25)
#     Line #391 (got 26 columns instead of 25)
#     Line #394 (got 26 columns instead of 25)
#     Line #395 (got 26 columns instead of 25)
#     Line #396 (got 16 columns instead of 25)
#     Line #397 (got 26 columns instead of 25)
#     Line #400 (got 26 columns instead of 25)
#     Line #402 (got 26 columns instead of 25)
#     Line #404 (got 26 columns instead of 25)
#     Line #405 (got 26 columns instead of 25)
#     Line #406 (got 26 columns instead of 25)
#     Line #407 (got 26 columns instead of 25)
#     Line #408 (got 26 columns instead of 25)
#     Line #410 (got 27 columns instead of 25)
#     Line #411 (got 26 columns instead of 25)
#     Line #412 (got 26 columns instead of 25)
#     Line #413 (got 26 columns instead of 25)
#     Line #417 (got 26 columns instead of 25)
#     Line #418 (got 26 columns instead of 25)
#     Line #420 (got 26 columns instead of 25)
#     Line #424 (got 27 columns instead of 25)
#     Line #426 (got 27 columns instead of 25)
#     Line #428 (got 26 columns instead of 25)
#     Line #429 (got 26 columns instead of 25)
#     Line #430 (got 27 columns instead of 25)
#     Line #435 (got 26 columns instead of 25)
#     Line #436 (got 26 columns instead of 25)
#     Line #439 (got 26 columns instead of 25)
#     Line #443 (got 26 columns instead of 25)
#     Line #445 (got 26 columns instead of 25)
#     Line #447 (got 26 columns instead of 25)
#     Line #449 (got 26 columns instead of 25)
#     Line #451 (got 26 columns instead of 25)
#     Line #453 (got 26 columns instead of 25)
#     Line #456 (got 26 columns instead of 25)
#     Line #459 (got 26 columns instead of 25)
#     Line #460 (got 26 columns instead of 25)
#     Line #461 (got 27 columns instead of 25)
#     Line #462 (got 26 columns instead of 25)
#     Line #465 (got 26 columns instead of 25)
#     Line #466 (got 27 columns instead of 25)
#     Line #467 (got 26 columns instead of 25)
#     Line #470 (got 26 columns instead of 25)
#     Line #473 (got 26 columns instead of 25)
#     Line #479 (got 26 columns instead of 25)
#     Line #480 (got 26 columns instead of 25)
#     Line #485 (got 26 columns instead of 25)
#     Line #486 (got 26 columns instead of 25)
#     Line #488 (got 27 columns instead of 25)
#     Line #489 (got 26 columns instead of 25)
#     Line #492 (got 26 columns instead of 25)
#     Line #493 (got 26 columns instead of 25)
#     Line #496 (got 26 columns instead of 25)
#     Line #500 (got 26 columns instead of 25)
#     Line #501 (got 26 columns instead of 25)
#     Line #505 (got 27 columns instead of 25)
#     Line #506 (got 26 columns instead of 25)
#     Line #511 (got 26 columns instead of 25)
#     Line #512 (got 26 columns instead of 25)
#     Line #514 (got 27 columns instead of 25)
#     Line #515 (got 26 columns instead of 25)
#     Line #518 (got 26 columns instead of 25)
#     Line #519 (got 26 columns instead of 25)
#     Line #522 (got 26 columns instead of 25)
#     Line #523 (got 26 columns instead of 25)
#     Line #527 (got 26 columns instead of 25)
#     Line #529 (got 26 columns instead of 25)
#     Line #530 (got 26 columns instead of 25)
#     Line #532 (got 26 columns instead of 25)
#     Line #535 (got 26 columns instead of 25)
#     Line #538 (got 26 columns instead of 25)
#     Line #540 (got 26 columns instead of 25)
#     Line #541 (got 26 columns instead of 25)
#     Line #545 (got 27 columns instead of 25)
#     Line #546 (got 26 columns instead of 25)
#     Line #551 (got 26 columns instead of 25)
#     Line #558 (got 26 columns instead of 25)
#     Line #561 (got 26 columns instead of 25)
#     Line #562 (got 16 columns instead of 25)
#     Line #563 (got 27 columns instead of 25)
#     Line #566 (got 26 columns instead of 25)
#     Line #568 (got 27 columns instead of 25)
#     Line #569 (got 26 columns instead of 25)
#     Line #570 (got 26 columns instead of 25)
#     Line #573 (got 26 columns instead of 25)
#     Line #574 (got 26 columns instead of 25)
#     Line #575 (got 26 columns instead of 25)
#     Line #576 (got 26 columns instead of 25)
#     Line #581 (got 26 columns instead of 25)
#     Line #587 (got 26 columns instead of 25)
#     Line #589 (got 27 columns instead of 25)
#     Line #590 (got 27 columns instead of 25)
#     Line #591 (got 26 columns instead of 25)
#     Line #594 (got 26 columns instead of 25)
#     Line #597 (got 26 columns instead of 25)
#     Line #599 (got 26 columns instead of 25)
#     Line #601 (got 26 columns instead of 25)
#     Line #602 (got 16 columns instead of 25)
#     Line #603 (got 26 columns instead of 25)
#     Line #606 (got 26 columns instead of 25)
#     Line #608 (got 26 columns instead of 25)
#     Line #610 (got 26 columns instead of 25)
#     Line #611 (got 26 columns instead of 25)
#     Line #612 (got 26 columns instead of 25)
#     Line #613 (got 26 columns instead of 25)
#     Line #614 (got 26 columns instead of 25)
#     Line #617 (got 26 columns instead of 25)
#     Line #618 (got 26 columns instead of 25)
#     Line #619 (got 26 columns instead of 25)
#     Line #622 (got 26 columns instead of 25)
#     Line #623 (got 26 columns instead of 25)
#     Line #624 (got 26 columns instead of 25)
#     Line #626 (got 26 columns instead of 25)
#     Line #629 (got 26 columns instead of 25)
#     Line #631 (got 26 columns instead of 25)
#     Line #634 (got 26 columns instead of 25)
#     Line #637 (got 26 columns instead of 25)
#     Line #639 (got 27 columns instead of 25)
#     Line #640 (got 26 columns instead of 25)
#     Line #643 (got 26 columns instead of 25)
#     Line #644 (got 27 columns instead of 25)
#     Line #645 (got 26 columns instead of 25)
#     Line #648 (got 26 columns instead of 25)
#     Line #650 (got 26 columns instead of 25)
#     Line #651 (got 26 columns instead of 25)
#     Line #655 (got 26 columns instead of 25)
#     Line #658 (got 26 columns instead of 25)
#     Line #659 (got 26 columns instead of 25)
#     Line #660 (got 27 columns instead of 25)
#     Line #662 (got 27 columns instead of 25)
#     Line #666 (got 26 columns instead of 25)
#     Line #667 (got 26 columns instead of 25)
#     Line #675 (got 27 columns instead of 25)
#     Line #677 (got 26 columns instead of 25)
#     Line #680 (got 26 columns instead of 25)
#     Line #681 (got 26 columns instead of 25)
#     Line #683 (got 26 columns instead of 25)
#     Line #689 (got 26 columns instead of 25)
#     Line #691 (got 27 columns instead of 25)
#     Line #692 (got 27 columns instead of 25)
#     Line #693 (got 26 columns instead of 25)
#     Line #696 (got 27 columns instead of 25)
#     Line #698 (got 26 columns instead of 25)
#     Line #699 (got 26 columns instead of 25)
#     Line #701 (got 26 columns instead of 25)
#     Line #703 (got 26 columns instead of 25)
#     Line #704 (got 26 columns instead of 25)
#     Line #705 (got 27 columns instead of 25)
#     Line #707 (got 26 columns instead of 25)
#     Line #708 (got 26 columns instead of 25)
#     Line #709 (got 27 columns instead of 25)
#     Line #710 (got 26 columns instead of 25)
#     Line #711 (got 27 columns instead of 25)
#     Line #715 (got 26 columns instead of 25)
#     Line #723 (got 26 columns instead of 25)
#     Line #725 (got 26 columns instead of 25)
#     Line #726 (got 26 columns instead of 25)
#     Line #727 (got 26 columns instead of 25)
#     Line #728 (got 26 columns instead of 25)
#     Line #729 (got 26 columns instead of 25)
#     Line #730 (got 26 columns instead of 25)
#     Line #731 (got 26 columns instead of 25)
#     Line #737 (got 26 columns instead of 25)
#     Line #739 (got 27 columns instead of 25)
#     Line #740 (got 27 columns instead of 25)
#     Line #744 (got 26 columns instead of 25)
#     Line #747 (got 26 columns instead of 25)
#     Line #748 (got 26 columns instead of 25)
#     Line #751 (got 26 columns instead of 25)
#     Line #754 (got 26 columns instead of 25)
#     Line #756 (got 27 columns instead of 25)
#     Line #757 (got 27 columns instead of 25)
#     Line #759 (got 26 columns instead of 25)
#     Line #760 (got 27 columns instead of 25)
#     Line #761 (got 26 columns instead of 25)
#     Line #762 (got 27 columns instead of 25)
#     Line #763 (got 27 columns instead of 25)
#     Line #767 (got 26 columns instead of 25)
#     Line #775 (got 26 columns instead of 25)
#     Line #776 (got 26 columns instead of 25)
#     Line #778 (got 26 columns instead of 25)
#     Line #780 (got 26 columns instead of 25)
#     Line #781 (got 26 columns instead of 25)
#     Line #782 (got 26 columns instead of 25)
#     Line #784 (got 26 columns instead of 25)
#     Line #785 (got 26 columns instead of 25)
#     Line #788 (got 27 columns instead of 25)
#     Line #789 (got 26 columns instead of 25)
#     Line #790 (got 26 columns instead of 25)
#     Line #793 (got 26 columns instead of 25)
#     Line #794 (got 27 columns instead of 25)
#     Line #795 (got 26 columns instead of 25)
#     Line #799 (got 26 columns instead of 25)
#     Line #801 (got 26 columns instead of 25)
#     Line #802 (got 26 columns instead of 25)
#     Line #807 (got 26 columns instead of 25)
#     Line #812 (got 26 columns instead of 25)
#     Line #813 (got 26 columns instead of 25)
#     Line #815 (got 27 columns instead of 25)
#     Line #816 (got 26 columns instead of 25)
#     Line #820 (got 26 columns instead of 25)
#     Line #822 (got 26 columns instead of 25)
#     Line #826 (got 26 columns instead of 25)
#     Line #828 (got 26 columns instead of 25)
#     Line #830 (got 26 columns instead of 25)
#     Line #831 (got 26 columns instead of 25)
#     Line #832 (got 26 columns instead of 25)
#     Line #833 (got 26 columns instead of 25)
#     Line #834 (got 26 columns instead of 25)
#     Line #835 (got 26 columns instead of 25)
#     Line #840 (got 26 columns instead of 25)
#     Line #841 (got 26 columns instead of 25)
#     Line #842 (got 27 columns instead of 25)
#     Line #843 (got 27 columns instead of 25)
#     Line #844 (got 26 columns instead of 25)
#     Line #845 (got 26 columns instead of 25)
#     Line #847 (got 26 columns instead of 25)
#     Line #848 (got 26 columns instead of 25)
#     Line #851 (got 26 columns instead of 25)
#     Line #852 (got 26 columns instead of 25)
#     Line #855 (got 26 columns instead of 25)
#     Line #859 (got 26 columns instead of 25)
#     Line #861 (got 26 columns instead of 25)
#     Line #864 (got 26 columns instead of 25)
#     Line #867 (got 26 columns instead of 25)
#     Line #869 (got 26 columns instead of 25)
#     Line #870 (got 26 columns instead of 25)
#     Line #873 (got 26 columns instead of 25)
#     Line #874 (got 27 columns instead of 25)
#     Line #875 (got 26 columns instead of 25)
#     Line #879 (got 26 columns instead of 25)
#     Line #880 (got 26 columns instead of 25)
#     Line #884 (got 26 columns instead of 25)
#     Line #885 (got 27 columns instead of 25)
#     Line #886 (got 26 columns instead of 25)
#     Line #887 (got 27 columns instead of 25)
#     Line #889 (got 26 columns instead of 25)
#     Line #890 (got 26 columns instead of 25)
#     Line #891 (got 26 columns instead of 25)
#     Line #895 (got 26 columns instead of 25)
#     Line #897 (got 26 columns instead of 25)
#     Line #900 (got 26 columns instead of 25)
#     Line #904 (got 26 columns instead of 25)
#     Line #908 (got 26 columns instead of 25)
#     Line #912 (got 27 columns instead of 25)
#     Line #913 (got 26 columns instead of 25)
#     Line #914 (got 27 columns instead of 25)
#     Line #917 (got 26 columns instead of 25)
#     Line #918 (got 26 columns instead of 25)
#     Line #922 (got 26 columns instead of 25)
#     Line #927 (got 26 columns instead of 25)
#     Line #930 (got 26 columns instead of 25)
#     Line #931 (got 26 columns instead of 25)
#     Line #941 (got 26 columns instead of 25)
#     Line #944 (got 26 columns instead of 25)
#     Line #945 (got 26 columns instead of 25)
#     Line #946 (got 26 columns instead of 25)
#     Line #949 (got 26 columns instead of 25)
#     Line #951 (got 26 columns instead of 25)
#     Line #952 (got 26 columns instead of 25)
#     Line #953 (got 26 columns instead of 25)
#     Line #956 (got 26 columns instead of 25)
#     Line #957 (got 26 columns instead of 25)
#     Line #958 (got 26 columns instead of 25)
#     Line #959 (got 26 columns instead of 25)
#     Line #965 (got 27 columns instead of 25)
#     Line #966 (got 26 columns instead of 25)
#     Line #967 (got 27 columns instead of 25)
#     Line #970 (got 26 columns instead of 25)
#     Line #971 (got 26 columns instead of 25)
#     Line #975 (got 26 columns instead of 25)
#     Line #977 (got 26 columns instead of 25)
#     Line #980 (got 26 columns instead of 25)
#     Line #983 (got 26 columns instead of 25)
#     Line #984 (got 26 columns instead of 25)
#     Line #991 (got 27 columns instead of 25)
#     Line #992 (got 26 columns instead of 25)
#     Line #994 (got 26 columns instead of 25)
#     Line #996 (got 26 columns instead of 25)
#     Line #999 (got 27 columns instead of 25)
#     Line #1006 (got 26 columns instead of 25)
#     Line #1009 (got 27 columns instead of 25)
#     Line #1010 (got 26 columns instead of 25)
#     Line #1011 (got 26 columns instead of 25)
#     Line #1012 (got 26 columns instead of 25)
#     Line #1015 (got 26 columns instead of 25)
#     Line #1017 (got 27 columns instead of 25)
#     Line #1018 (got 26 columns instead of 25)
#     Line #1021 (got 26 columns instead of 25)
#     Line #1022 (got 26 columns instead of 25)
#     Line #1023 (got 26 columns instead of 25)
#     Line #1024 (got 26 columns instead of 25)
#     Line #1025 (got 27 columns instead of 25)
#     Line #1027 (got 26 columns instead of 25)
#     Line #1028 (got 26 columns instead of 25)
#     Line #1029 (got 27 columns instead of 25)
#     Line #1032 (got 26 columns instead of 25)
#     Line #1034 (got 26 columns instead of 25)
#     Line #1035 (got 26 columns instead of 25)
#     Line #1037 (got 26 columns instead of 25)
#     Line #1038 (got 26 columns instead of 25)
#     Line #1039 (got 26 columns instead of 25)
#     Line #1045 (got 26 columns instead of 25)
#     Line #1047 (got 27 columns instead of 25)
#     Line #1049 (got 26 columns instead of 25)
#     Line #1054 (got 26 columns instead of 25)
#     Line #1055 (got 26 columns instead of 25)
#     Line #1057 (got 26 columns instead of 25)
#     Line #1058 (got 26 columns instead of 25)
#     Line #1059 (got 26 columns instead of 25)
#     Line #1060 (got 26 columns instead of 25)
#     Line #1061 (got 26 columns instead of 25)
#     Line #1062 (got 26 columns instead of 25)
#     Line #1063 (got 26 columns instead of 25)
#     Line #1064 (got 26 columns instead of 25)
#     Line #1066 (got 26 columns instead of 25)
#     Line #1068 (got 27 columns instead of 25)
#     Line #1069 (got 26 columns instead of 25)
#     Line #1071 (got 26 columns instead of 25)
#     Line #1072 (got 27 columns instead of 25)
#     Line #1073 (got 26 columns instead of 25)
#     Line #1076 (got 27 columns instead of 25)
#     Line #1083 (got 26 columns instead of 25)
#     Line #1085 (got 26 columns instead of 25)
#     Line #1086 (got 27 columns instead of 25)
#     Line #1087 (got 26 columns instead of 25)
#     Line #1088 (got 26 columns instead of 25)
#     Line #1089 (got 26 columns instead of 25)
#     Line #1092 (got 16 columns instead of 25)
#     Line #1093 (got 26 columns instead of 25)
#     Line #1097 (got 26 columns instead of 25)
#     Line #1098 (got 26 columns instead of 25)
#     Line #1099 (got 26 columns instead of 25)
#     Line #1100 (got 26 columns instead of 25)
#     Line #1101 (got 26 columns instead of 25)
#     Line #1102 (got 26 columns instead of 25)
#     Line #1104 (got 26 columns instead of 25)
#     Line #1105 (got 26 columns instead of 25)
#     Line #1107 (got 26 columns instead of 25)
#     Line #1108 (got 26 columns instead of 25)
#     Line #1109 (got 26 columns instead of 25)
#     Line #1112 (got 26 columns instead of 25)
#     Line #1113 (got 26 columns instead of 25)
#     Line #1114 (got 26 columns instead of 25)
#     Line #1118 (got 27 columns instead of 25)
#     Line #1119 (got 26 columns instead of 25)
#     Line #1124 (got 26 columns instead of 25)
#     Line #1127 (got 27 columns instead of 25)
#     Line #1128 (got 26 columns instead of 25)
#     Line #1132 (got 26 columns instead of 25)
#     Line #1134 (got 26 columns instead of 25)
#     Line #1136 (got 26 columns instead of 25)
#     Line #1142 (got 16 columns instead of 25)
#     Line #1143 (got 26 columns instead of 25)
#     Line #1147 (got 26 columns instead of 25)
#     Line #1148 (got 26 columns instead of 25)
#     Line #1149 (got 26 columns instead of 25)
#     Line #1150 (got 26 columns instead of 25)
#     Line #1151 (got 26 columns instead of 25)
#     Line #1152 (got 26 columns instead of 25)
#     Line #1154 (got 26 columns instead of 25)
#     Line #1155 (got 26 columns instead of 25)
#     Line #1157 (got 26 columns instead of 25)
#     Line #1158 (got 26 columns instead of 25)
#     Line #1159 (got 26 columns instead of 25)
#     Line #1160 (got 26 columns instead of 25)
#     Line #1161 (got 16 columns instead of 25)
#     Line #1162 (got 26 columns instead of 25)
#     Line #1163 (got 26 columns instead of 25)
#     Line #1164 (got 26 columns instead of 25)
#     Line #1165 (got 26 columns instead of 25)
#     Line #1168 (got 26 columns instead of 25)
#     Line #1170 (got 26 columns instead of 25)
#     Line #1173 (got 26 columns instead of 25)
#     Line #1176 (got 26 columns instead of 25)
#     Line #1178 (got 27 columns instead of 25)
#     Line #1179 (got 26 columns instead of 25)
#     Line #1182 (got 26 columns instead of 25)
#     Line #1183 (got 27 columns instead of 25)
#     Line #1184 (got 26 columns instead of 25)
#     Line #1189 (got 26 columns instead of 25)
#     Line #1192 (got 16 columns instead of 25)
#     Line #1193 (got 26 columns instead of 25)
#     Line #1197 (got 26 columns instead of 25)
#     Line #1198 (got 26 columns instead of 25)
#     Line #1199 (got 26 columns instead of 25)
#     Line #1200 (got 26 columns instead of 25)
#     Line #1201 (got 26 columns instead of 25)
#     Line #1203 (got 26 columns instead of 25)
#     Line #1206 (got 27 columns instead of 25)
#     Line #1207 (got 26 columns instead of 25)
#     Line #1208 (got 26 columns instead of 25)
#     Line #1210 (got 16 columns instead of 25)
#     Line #1211 (got 26 columns instead of 25)
#     Line #1212 (got 26 columns instead of 25)
#     Line #1213 (got 26 columns instead of 25)
#     Line #1214 (got 26 columns instead of 25)
#     Line #1216 (got 26 columns instead of 25)
#     Line #1221 (got 26 columns instead of 25)
#     Line #1224 (got 26 columns instead of 25)
#     Line #1225 (got 26 columns instead of 25)
#     Line #1226 (got 26 columns instead of 25)
#     Line #1229 (got 26 columns instead of 25)
#     Line #1231 (got 26 columns instead of 25)
#     Line #1232 (got 26 columns instead of 25)
#     Line #1233 (got 26 columns instead of 25)
#     Line #1236 (got 26 columns instead of 25)
#     Line #1237 (got 26 columns instead of 25)
#     Line #1238 (got 26 columns instead of 25)
#     Line #1239 (got 26 columns instead of 25)
#     Line #1242 (got 26 columns instead of 25)
#     Line #1243 (got 26 columns instead of 25)
#     Line #1244 (got 27 columns instead of 25)
#     Line #1247 (got 26 columns instead of 25)
#     Line #1248 (got 27 columns instead of 25)
#     Line #1253 (got 26 columns instead of 25)
#     Line #1254 (got 26 columns instead of 25)
#     Line #1255 (got 26 columns instead of 25)
#     Line #1259 (got 26 columns instead of 25)
#     Line #1264 (got 26 columns instead of 25)
#     Line #1265 (got 26 columns instead of 25)
#     Line #1266 (got 26 columns instead of 25)
#     Line #1267 (got 26 columns instead of 25)
#     Line #1270 (got 26 columns instead of 25)
#     Line #1272 (got 26 columns instead of 25)
#     Line #1276 (got 26 columns instead of 25)
#     Line #1278 (got 26 columns instead of 25)
#     Line #1279 (got 27 columns instead of 25)
#     Line #1280 (got 26 columns instead of 25)
#     Line #1283 (got 26 columns instead of 25)
#     Line #1284 (got 26 columns instead of 25)
#     Line #1285 (got 26 columns instead of 25)
#     Line #1286 (got 26 columns instead of 25)
#     Line #1288 (got 26 columns instead of 25)
#     Line #1290 (got 26 columns instead of 25)
#     Line #1292 (got 27 columns instead of 25)
#     Line #1293 (got 26 columns instead of 25)
#     Line #1295 (got 26 columns instead of 25)
#     Line #1297 (got 26 columns instead of 25)
#     Line #1299 (got 26 columns instead of 25)
#     Line #1300 (got 27 columns instead of 25)
#     Line #1306 (got 26 columns instead of 25)
#     Line #1308 (got 26 columns instead of 25)
#     Line #1309 (got 26 columns instead of 25)
#     Line #1310 (got 26 columns instead of 25)
#     Line #1312 (got 26 columns instead of 25)
#     Line #1313 (got 26 columns instead of 25)
#     Line #1314 (got 26 columns instead of 25)
#     Line #1318 (got 27 columns instead of 25)
#     Line #1319 (got 27 columns instead of 25)
#     Line #1321 (got 27 columns instead of 25)
#     Line #1323 (got 26 columns instead of 25)
#     Line #1324 (got 26 columns instead of 25)
#     Line #1325 (got 27 columns instead of 25)
#     Line #1331 (got 26 columns instead of 25)
#     Line #1336 (got 26 columns instead of 25)
#     Line #1337 (got 26 columns instead of 25)
#     Line #1338 (got 26 columns instead of 25)
#     Line #1340 (got 26 columns instead of 25)
#     Line #1343 (got 26 columns instead of 25)
#     Line #1346 (got 27 columns instead of 25)
#     Line #1348 (got 27 columns instead of 25)
#     Line #1350 (got 26 columns instead of 25)
#     Line #1351 (got 26 columns instead of 25)
#     Line #1352 (got 27 columns instead of 25)
#     Line #1357 (got 26 columns instead of 25)
#     Line #1358 (got 26 columns instead of 25)
#     Line #1361 (got 26 columns instead of 25)
#     Line #1365 (got 27 columns instead of 25)
#     Line #1366 (got 26 columns instead of 25)
#     Line #1367 (got 26 columns instead of 25)
#     Line #1370 (got 26 columns instead of 25)
#     Line #1371 (got 16 columns instead of 25)
#     Line #1372 (got 26 columns instead of 25)
#     Line #1376 (got 26 columns instead of 25)
#     Line #1377 (got 26 columns instead of 25)
#     Line #1378 (got 26 columns instead of 25)
#     Line #1379 (got 26 columns instead of 25)
#     Line #1380 (got 26 columns instead of 25)
#     Line #1382 (got 26 columns instead of 25)
#     Line #1385 (got 26 columns instead of 25)
#     Line #1386 (got 26 columns instead of 25)
#     Line #1387 (got 26 columns instead of 25)
#     Line #1389 (got 16 columns instead of 25)
#     Line #1390 (got 26 columns instead of 25)
#     Line #1391 (got 26 columns instead of 25)
#     Line #1392 (got 26 columns instead of 25)
#     Line #1393 (got 26 columns instead of 25)
#     Line #1395 (got 26 columns instead of 25)
#     Line #1397 (got 26 columns instead of 25)
#     Line #1401 (got 26 columns instead of 25)
#     Line #1403 (got 26 columns instead of 25)
#     Line #1404 (got 27 columns instead of 25)
#     Line #1405 (got 26 columns instead of 25)
#     Line #1407 (got 26 columns instead of 25)
#     Line #1409 (got 26 columns instead of 25)
#     Line #1410 (got 26 columns instead of 25)
#     Line #1411 (got 26 columns instead of 25)
#     Line #1412 (got 26 columns instead of 25)
#     Line #1414 (got 26 columns instead of 25)
#     Line #1416 (got 26 columns instead of 25)
#     Line #1417 (got 26 columns instead of 25)
#     Line #1419 (got 26 columns instead of 25)
#     Line #1425 (got 26 columns instead of 25)
#     Line #1427 (got 26 columns instead of 25)
#     Line #1429 (got 26 columns instead of 25)
#     Line #1431 (got 27 columns instead of 25)
#     Line #1432 (got 26 columns instead of 25)
#     Line #1434 (got 26 columns instead of 25)
#     Line #1435 (got 26 columns instead of 25)
#     Line #1437 (got 26 columns instead of 25)
#     Line #1439 (got 26 columns instead of 25)
#     Line #1440 (got 26 columns instead of 25)
#     Line #1443 (got 26 columns instead of 25)
#     Line #1444 (got 26 columns instead of 25)
#     Line #1445 (got 27 columns instead of 25)
#     Line #1447 (got 27 columns instead of 25)
#     Line #1450 (got 26 columns instead of 25)
#     Line #1451 (got 26 columns instead of 25)
#     Line #1452 (got 26 columns instead of 25)
#     Line #1460 (got 27 columns instead of 25)
#     Line #1462 (got 26 columns instead of 25)
#     Line #1464 (got 26 columns instead of 25)
#     Line #1465 (got 26 columns instead of 25)
#     Line #1466 (got 26 columns instead of 25)
#     Line #1467 (got 26 columns instead of 25)
#     Line #1469 (got 26 columns instead of 25)
#     Line #1474 (got 26 columns instead of 25)
#     Line #1475 (got 26 columns instead of 25)
#     Line #1477 (got 26 columns instead of 25)
#     Line #1478 (got 26 columns instead of 25)
#     Line #1482 (got 26 columns instead of 25)
#     Line #1484 (got 26 columns instead of 25)
#     Line #1488 (got 26 columns instead of 25)
#     Line #1490 (got 26 columns instead of 25)
#     Line #1492 (got 26 columns instead of 25)
#     Line #1493 (got 26 columns instead of 25)
#     Line #1494 (got 26 columns instead of 25)
#     Line #1495 (got 26 columns instead of 25)
#     Line #1497 (got 26 columns instead of 25)
#     Line #1500 (got 26 columns instead of 25)
#     Line #1503 (got 26 columns instead of 25)
#     Line #1505 (got 26 columns instead of 25)
#     Line #1509 (got 27 columns instead of 25)
#     Line #1510 (got 26 columns instead of 25)
#     Line #1512 (got 26 columns instead of 25)
#     Line #1515 (got 26 columns instead of 25)
#     Line #1517 (got 26 columns instead of 25)
#     Line #1519 (got 26 columns instead of 25)
#     Line #1520 (got 26 columns instead of 25)
#     Line #1523 (got 27 columns instead of 25)
#     Line #1524 (got 26 columns instead of 25)
#     Line #1525 (got 26 columns instead of 25)
#     Line #1527 (got 26 columns instead of 25)
#     Line #1528 (got 26 columns instead of 25)
#     Line #1529 (got 27 columns instead of 25)
#     Line #1530 (got 26 columns instead of 25)
#     Line #1534 (got 26 columns instead of 25)
#     Line #1536 (got 26 columns instead of 25)
#     Line #1537 (got 26 columns instead of 25)
#     Line #1541 (got 26 columns instead of 25)
#     Line #1542 (got 26 columns instead of 25)
#     Line #1548 (got 26 columns instead of 25)
#     Line #1549 (got 26 columns instead of 25)
#     Line #1550 (got 27 columns instead of 25)
#     Line #1551 (got 27 columns instead of 25)
#     Line #1555 (got 26 columns instead of 25)
#     Line #1558 (got 26 columns instead of 25)
#     Line #1559 (got 26 columns instead of 25)
#     Line #1562 (got 26 columns instead of 25)
#     Line #1563 (got 26 columns instead of 25)
#     Line #1565 (got 26 columns instead of 25)
#     Line #1567 (got 26 columns instead of 25)
#     Line #1572 (got 26 columns instead of 25)
#     Line #1573 (got 26 columns instead of 25)
#     Line #1575 (got 27 columns instead of 25)
#     Line #1576 (got 26 columns instead of 25)
#     Line #1580 (got 26 columns instead of 25)
#     Line #1582 (got 26 columns instead of 25)
#     Line #1586 (got 26 columns instead of 25)
#     Line #1587 (got 26 columns instead of 25)
#     Line #1588 (got 26 columns instead of 25)
#     Line #1590 (got 26 columns instead of 25)
#     Line #1593 (got 27 columns instead of 25)
#     Line #1594 (got 26 columns instead of 25)
#     Line #1596 (got 26 columns instead of 25)
#     Line #1598 (got 26 columns instead of 25)
#     Line #1600 (got 26 columns instead of 25)
#     Line #1601 (got 27 columns instead of 25)
#     Line #1607 (got 26 columns instead of 25)
#     Line #1609 (got 26 columns instead of 25)
#     Line #1610 (got 26 columns instead of 25)
#     Line #1611 (got 26 columns instead of 25)
#     Line #1613 (got 26 columns instead of 25)
#     Line #1614 (got 26 columns instead of 25)
#     Line #1618 (got 26 columns instead of 25)
#     Line #1619 (got 26 columns instead of 25)
#     Line #1625 (got 26 columns instead of 25)
#     Line #1626 (got 26 columns instead of 25)
#     Line #1627 (got 27 columns instead of 25)
#     Line #1628 (got 27 columns instead of 25)
#     Line #1629 (got 26 columns instead of 25)
#     Line #1630 (got 26 columns instead of 25)
#     Line #1632 (got 26 columns instead of 25)
#     Line #1633 (got 26 columns instead of 25)
#     Line #1636 (got 26 columns instead of 25)
#     Line #1637 (got 26 columns instead of 25)
#     Line #1640 (got 26 columns instead of 25)
#     Line #1641 (got 26 columns instead of 25)
#     Line #1644 (got 27 columns instead of 25)
#     Line #1645 (got 27 columns instead of 25)
#     Line #1647 (got 26 columns instead of 25)
#     Line #1648 (got 27 columns instead of 25)
#     Line #1649 (got 26 columns instead of 25)
#     Line #1650 (got 27 columns instead of 25)
#     Line #1651 (got 27 columns instead of 25)
#     Line #1655 (got 26 columns instead of 25)
#     Line #1663 (got 26 columns instead of 25)
#     Line #1664 (got 27 columns instead of 25)
#     Line #1665 (got 26 columns instead of 25)
#     Line #1668 (got 26 columns instead of 25)
#     Line #1669 (got 26 columns instead of 25)
#     Line #1670 (got 16 columns instead of 25)
#     Line #1675 (got 26 columns instead of 25)
#     Line #1676 (got 26 columns instead of 25)
#     Line #1677 (got 26 columns instead of 25)
#     Line #1678 (got 26 columns instead of 25)
#     Line #1679 (got 26 columns instead of 25)
#     Line #1681 (got 26 columns instead of 25)
#     Line #1685 (got 26 columns instead of 25)
#     Line #1688 (got 16 columns instead of 25)
#     Line #1690 (got 26 columns instead of 25)
#     Line #1691 (got 26 columns instead of 25)
#     Line #1692 (got 26 columns instead of 25)
#     Line #1694 (got 26 columns instead of 25)
#     Line #1695 (got 26 columns instead of 25)
#     Line #1697 (got 26 columns instead of 25)
#     Line #1703 (got 26 columns instead of 25)
#     Line #1704 (got 27 columns instead of 25)
#     Line #1705 (got 26 columns instead of 25)
#     Line #1707 (got 26 columns instead of 25)
#     Line #1709 (got 26 columns instead of 25)
#     Line #1710 (got 26 columns instead of 25)
#     Line #1712 (got 26 columns instead of 25)
#     Line #1715 (got 26 columns instead of 25)
#     Line #1717 (got 26 columns instead of 25)
#     Line #1718 (got 26 columns instead of 25)
#     Line #1719 (got 27 columns instead of 25)
#     Line #1721 (got 26 columns instead of 25)
#     Line #1722 (got 26 columns instead of 25)
#     Line #1723 (got 27 columns instead of 25)
#     Line #1724 (got 26 columns instead of 25)
#     Line #1725 (got 27 columns instead of 25)
#     Line #1730 (got 26 columns instead of 25)
#     Line #1740 (got 26 columns instead of 25)
#     Line #1742 (got 26 columns instead of 25)
#     Line #1743 (got 26 columns instead of 25)
#     Line #1744 (got 26 columns instead of 25)
#     Line #1745 (got 26 columns instead of 25)
#     Line #1750 (got 26 columns instead of 25)
#     Line #1753 (got 26 columns instead of 25)
#     Line #1754 (got 16 columns instead of 25)
#     Line #1755 (got 26 columns instead of 25)
#     Line #1758 (got 26 columns instead of 25)
#     Line #1760 (got 27 columns instead of 25)
#     Line #1761 (got 26 columns instead of 25)
#     Line #1762 (got 26 columns instead of 25)
#     Line #1765 (got 26 columns instead of 25)
#     Line #1766 (got 26 columns instead of 25)
#     Line #1767 (got 26 columns instead of 25)
#     Line #1768 (got 26 columns instead of 25)
#     Line #1771 (got 26 columns instead of 25)
#     Line #1772 (got 26 columns instead of 25)
#     Line #1774 (got 26 columns instead of 25)
#     Line #1780 (got 26 columns instead of 25)
#     Line #1781 (got 27 columns instead of 25)
#     Line #1782 (got 26 columns instead of 25)
#     Line #1784 (got 26 columns instead of 25)
#     Line #1786 (got 26 columns instead of 25)
#     Line #1787 (got 26 columns instead of 25)
#     Line #1788 (got 26 columns instead of 25)
#     Line #1791 (got 26 columns instead of 25)
#     Line #1793 (got 26 columns instead of 25)
#     Line #1795 (got 26 columns instead of 25)
#     Line #1798 (got 26 columns instead of 25)
#     Line #1800 (got 26 columns instead of 25)
#     Line #1802 (got 26 columns instead of 25)
#     Line #1803 (got 26 columns instead of 25)
#     Line #1804 (got 26 columns instead of 25)
#     Line #1805 (got 26 columns instead of 25)
#     Line #1806 (got 26 columns instead of 25)
#     Line #1809 (got 26 columns instead of 25)
#     Line #1810 (got 27 columns instead of 25)
#     Line #1811 (got 26 columns instead of 25)
#     Line #1814 (got 26 columns instead of 25)
#     Line #1815 (got 26 columns instead of 25)
#     Line #1817 (got 26 columns instead of 25)
#     Line #1819 (got 26 columns instead of 25)
#     Line #1823 (got 26 columns instead of 25)
#     Line #1827 (got 26 columns instead of 25)
#     Line #1829 (got 26 columns instead of 25)
#     Line #1830 (got 27 columns instead of 25)
#     Line #1836 (got 26 columns instead of 25)
#     Line #1838 (got 26 columns instead of 25)
#     Line #1839 (got 26 columns instead of 25)
#     Line #1840 (got 26 columns instead of 25)
#     Line #1841 (got 26 columns instead of 25)
#     Line #1842 (got 26 columns instead of 25)
#     Line #1843 (got 26 columns instead of 25)
#     Line #1847 (got 26 columns instead of 25)
#     Line #1849 (got 26 columns instead of 25)
#     Line #1855 (got 26 columns instead of 25)
#     Line #1856 (got 27 columns instead of 25)
#     Line #1857 (got 26 columns instead of 25)
#     Line #1859 (got 26 columns instead of 25)
#     Line #1861 (got 26 columns instead of 25)
#     Line #1862 (got 26 columns instead of 25)
#     Line #1864 (got 26 columns instead of 25)
#     Line #1867 (got 26 columns instead of 25)
#     Line #1869 (got 26 columns instead of 25)
#     Line #1870 (got 16 columns instead of 25)
#     Line #1871 (got 26 columns instead of 25)
#     Line #1875 (got 26 columns instead of 25)
#     Line #1876 (got 26 columns instead of 25)
#     Line #1877 (got 26 columns instead of 25)
#     Line #1878 (got 26 columns instead of 25)
#     Line #1879 (got 26 columns instead of 25)
#     Line #1880 (got 26 columns instead of 25)
#     Line #1882 (got 26 columns instead of 25)
#     Line #1885 (got 26 columns instead of 25)
#     Line #1886 (got 26 columns instead of 25)
#     Line #1887 (got 26 columns instead of 25)
#     Line #1888 (got 26 columns instead of 25)
#     Line #1890 (got 26 columns instead of 25)
#     Line #1891 (got 26 columns instead of 25)
#     Line #1892 (got 26 columns instead of 25)
#     Line #1893 (got 26 columns instead of 25)
#     Line #1900 (got 26 columns instead of 25)
#     Line #1903 (got 26 columns instead of 25)
#     Line #1904 (got 16 columns instead of 25)
#     Line #1905 (got 26 columns instead of 25)
#     Line #1908 (got 26 columns instead of 25)
#     Line #1910 (got 27 columns instead of 25)
#     Line #1911 (got 26 columns instead of 25)
#     Line #1912 (got 26 columns instead of 25)
#     Line #1915 (got 26 columns instead of 25)
#     Line #1916 (got 26 columns instead of 25)
#     Line #1917 (got 26 columns instead of 25)
#     Line #1918 (got 26 columns instead of 25)
#     Line #1919 (got 26 columns instead of 25)
#     Line #1922 (got 26 columns instead of 25)
#     Line #1923 (got 26 columns instead of 25)
#     Line #1925 (got 26 columns instead of 25)
#     Line #1931 (got 26 columns instead of 25)
#     Line #1933 (got 26 columns instead of 25)
#     Line #1935 (got 26 columns instead of 25)
#     Line #1937 (got 27 columns instead of 25)
#     Line #1938 (got 26 columns instead of 25)
#     Line #1940 (got 26 columns instead of 25)
#     Line #1943 (got 26 columns instead of 25)
#     Line #1945 (got 26 columns instead of 25)
#     Line #1948 (got 26 columns instead of 25)
#     Line #1950 (got 26 columns instead of 25)
#     Line #1953 (got 26 columns instead of 25)
#     Line #1954 (got 26 columns instead of 25)
#     Line #1955 (got 26 columns instead of 25)
#     Line #1958 (got 26 columns instead of 25)
#     Line #1960 (got 26 columns instead of 25)
#     Line #1961 (got 26 columns instead of 25)
#     Line #1962 (got 26 columns instead of 25)
#     Line #1964 (got 26 columns instead of 25)
#     Line #1965 (got 26 columns instead of 25)
#     Line #1966 (got 26 columns instead of 25)
#     Line #1967 (got 26 columns instead of 25)
#     Line #1972 (got 16 columns instead of 25)
#     Line #1973 (got 26 columns instead of 25)
#     Line #1976 (got 26 columns instead of 25)
#     Line #1978 (got 26 columns instead of 25)
#     Line #1980 (got 26 columns instead of 25)
#     Line #1981 (got 26 columns instead of 25)
#     Line #1982 (got 26 columns instead of 25)
#     Line #1983 (got 26 columns instead of 25)
#     Line #1984 (got 26 columns instead of 25)
#     Line #1987 (got 26 columns instead of 25)
#     Line #1988 (got 27 columns instead of 25)
#     Line #1989 (got 26 columns instead of 25)
#     Line #1992 (got 26 columns instead of 25)
#     Line #1993 (got 26 columns instead of 25)
#     Line #1994 (got 26 columns instead of 25)
#     Line #1995 (got 26 columns instead of 25)
#     Line #1997 (got 26 columns instead of 25)
#     Line #2003 (got 26 columns instead of 25)
#     Line #2006 (got 16 columns instead of 25)
#     Line #2007 (got 27 columns instead of 25)
#     Line #2009 (got 26 columns instead of 25)
#     Line #2011 (got 26 columns instead of 25)
#     Line #2012 (got 26 columns instead of 25)
#     Line #2013 (got 27 columns instead of 25)
#     Line #2014 (got 26 columns instead of 25)
#     Line #2018 (got 26 columns instead of 25)
#     Line #2019 (got 26 columns instead of 25)
#     Line #2020 (got 26 columns instead of 25)
#     Line #2021 (got 26 columns instead of 25)
#     Line #2022 (got 26 columns instead of 25)
#     Line #2027 (got 26 columns instead of 25)
#     Line #2033 (got 26 columns instead of 25)
#     Line #2035 (got 27 columns instead of 25)
#     Line #2036 (got 27 columns instead of 25)
#     Line #2040 (got 27 columns instead of 25)
#     Line #2042 (got 26 columns instead of 25)
#     Line #2045 (got 26 columns instead of 25)
#     Line #2046 (got 26 columns instead of 25)
#     Line #2047 (got 26 columns instead of 25)
#     Line #2048 (got 26 columns instead of 25)
#     Line #2051 (got 26 columns instead of 25)
#     Line #2052 (got 26 columns instead of 25)
#     Line #2053 (got 27 columns instead of 25)
#     Line #2055 (got 27 columns instead of 25)
#     Line #2058 (got 26 columns instead of 25)
#     Line #2059 (got 26 columns instead of 25)
#     Line #2060 (got 26 columns instead of 25)
#     Line #2067 (got 27 columns instead of 25)
#     Line #2071 (got 26 columns instead of 25)
#     Line #2072 (got 26 columns instead of 25)
#     Line #2073 (got 26 columns instead of 25)
#     Line #2076 (got 27 columns instead of 25)
#     Line #2077 (got 26 columns instead of 25)
#     Line #2081 (got 26 columns instead of 25)
#     Line #2082 (got 26 columns instead of 25)
#     Line #2086 (got 26 columns instead of 25)
#     Line #2091 (got 26 columns instead of 25)
#     Line #2095 (got 27 columns instead of 25)
#     Line #2096 (got 26 columns instead of 25)
#     Line #2101 (got 26 columns instead of 25)
#     Line #2102 (got 26 columns instead of 25)
#     Line #2105 (got 27 columns instead of 25)
#     Line #2106 (got 26 columns instead of 25)
#     Line #2107 (got 26 columns instead of 25)
#     Line #2110 (got 26 columns instead of 25)
#     Line #2111 (got 27 columns instead of 25)
#     Line #2112 (got 26 columns instead of 25)
#     Line #2116 (got 26 columns instead of 25)
#     Line #2118 (got 26 columns instead of 25)
#     Line #2119 (got 26 columns instead of 25)
#     Line #2120 (got 26 columns instead of 25)
#     Line #2124 (got 16 columns instead of 25)
#     Line #2125 (got 26 columns instead of 25)
#     Line #2129 (got 26 columns instead of 25)
#     Line #2130 (got 26 columns instead of 25)
#     Line #2131 (got 26 columns instead of 25)
#     Line #2132 (got 26 columns instead of 25)
#     Line #2133 (got 26 columns instead of 25)
#     Line #2135 (got 26 columns instead of 25)
#     Line #2138 (got 26 columns instead of 25)
#     Line #2139 (got 26 columns instead of 25)
#     Line #2140 (got 26 columns instead of 25)
#     Line #2144 (got 26 columns instead of 25)
#     Line #2145 (got 26 columns instead of 25)
#     Line #2146 (got 26 columns instead of 25)
#     Line #2149 (got 27 columns instead of 25)
#     Line #2150 (got 27 columns instead of 25)
#     Line #2152 (got 26 columns instead of 25)
#     Line #2154 (got 26 columns instead of 25)
#     Line #2155 (got 27 columns instead of 25)
#     Line #2156 (got 27 columns instead of 25)
#     Line #2162 (got 26 columns instead of 25)
#     Line #2169 (got 27 columns instead of 25)
#     Line #2170 (got 26 columns instead of 25)
#     Line #2174 (got 26 columns instead of 25)
#     Line #2176 (got 26 columns instead of 25)
#     Line #2177 (got 26 columns instead of 25)
#     Line #2180 (got 26 columns instead of 25)
#     Line #2181 (got 27 columns instead of 25)
#     Line #2182 (got 26 columns instead of 25)
#     Line #2183 (got 26 columns instead of 25)
#     Line #2186 (got 26 columns instead of 25)
#     Line #2188 (got 26 columns instead of 25)
#     Line #2192 (got 26 columns instead of 25)
#     Line #2194 (got 26 columns instead of 25)
#     Line #2195 (got 26 columns instead of 25)
#     Line #2196 (got 27 columns instead of 25)
#     Line #2199 (got 16 columns instead of 25)
#     Line #2200 (got 26 columns instead of 25)
#     Line #2204 (got 26 columns instead of 25)
#     Line #2205 (got 26 columns instead of 25)
#     Line #2206 (got 26 columns instead of 25)
#     Line #2207 (got 26 columns instead of 25)
#     Line #2208 (got 26 columns instead of 25)
#     Line #2210 (got 26 columns instead of 25)
#     Line #2214 (got 26 columns instead of 25)
#     Line #2215 (got 26 columns instead of 25)
#     Line #2219 (got 26 columns instead of 25)
#     Line #2220 (got 26 columns instead of 25)
#     Line #2221 (got 26 columns instead of 25)
#     Line #2223 (got 26 columns instead of 25)
#     Line #2224 (got 26 columns instead of 25)
#     Line #2225 (got 27 columns instead of 25)
#     Line #2227 (got 26 columns instead of 25)
#     Line #2228 (got 26 columns instead of 25)
#     Line #2229 (got 27 columns instead of 25)
#     Line #2230 (got 26 columns instead of 25)
#     Line #2231 (got 27 columns instead of 25)
#     Line #2236 (got 26 columns instead of 25)
#     Line #2248 (got 26 columns instead of 25)
#     Line #2249 (got 26 columns instead of 25)
#     Line #2250 (got 26 columns instead of 25)
#     Line #2251 (got 26 columns instead of 25)
#     Line #2252 (got 26 columns instead of 25)
#     Line #2253 (got 26 columns instead of 25)
#     Line #2256 (got 26 columns instead of 25)
#     Line #2257 (got 27 columns instead of 25)
#     Line #2259 (got 27 columns instead of 25)
#     Line #2262 (got 26 columns instead of 25)
#     Line #2263 (got 26 columns instead of 25)
#     Line #2264 (got 26 columns instead of 25)
#     Line #2268 (got 26 columns instead of 25)
#     Line #2271 (got 27 columns instead of 25)
#     Line #2272 (got 26 columns instead of 25)
#     Line #2275 (got 26 columns instead of 25)
#     Line #2276 (got 26 columns instead of 25)
#     Line #2280 (got 27 columns instead of 25)
#     Line #2282 (got 27 columns instead of 25)
#     Line #2284 (got 26 columns instead of 25)
#     Line #2285 (got 26 columns instead of 25)
#     Line #2286 (got 27 columns instead of 25)
#     Line #2291 (got 26 columns instead of 25)
#     Line #2292 (got 26 columns instead of 25)
#     Line #2295 (got 26 columns instead of 25)
#     Line #2299 (got 27 columns instead of 25)
#     Line #2300 (got 26 columns instead of 25)
#     Line #2301 (got 26 columns instead of 25)
#     Line #2304 (got 26 columns instead of 25)
#     Line #2306 (got 26 columns instead of 25)
#     Line #2307 (got 26 columns instead of 25)
#     Line #2308 (got 26 columns instead of 25)
#     Line #2310 (got 27 columns instead of 25)
#     Line #2311 (got 26 columns instead of 25)
#     Line #2312 (got 26 columns instead of 25)
#     Line #2314 (got 26 columns instead of 25)
#     Line #2315 (got 26 columns instead of 25)
#     Line #2316 (got 27 columns instead of 25)
#     Line #2317 (got 26 columns instead of 25)
#     Line #2321 (got 26 columns instead of 25)
#     Line #2323 (got 26 columns instead of 25)
#     Line #2324 (got 26 columns instead of 25)
#     Line #2329 (got 16 columns instead of 25)
#     Line #2334 (got 26 columns instead of 25)
#     Line #2335 (got 26 columns instead of 25)
#     Line #2336 (got 26 columns instead of 25)
#     Line #2337 (got 26 columns instead of 25)
#     Line #2338 (got 26 columns instead of 25)
#     Line #2340 (got 26 columns instead of 25)
#     Line #2344 (got 26 columns instead of 25)
#     Line #2349 (got 26 columns instead of 25)
#     Line #2351 (got 26 columns instead of 25)
#     Line #2353 (got 26 columns instead of 25)
#     Line #2355 (got 26 columns instead of 25)
#     Line #2356 (got 26 columns instead of 25)
#     Line #2358 (got 26 columns instead of 25)
#     Line #2361 (got 27 columns instead of 25)
#     Line #2362 (got 26 columns instead of 25)
#     Line #2363 (got 26 columns instead of 25)
#     Line #2365 (got 26 columns instead of 25)
#     Line #2366 (got 26 columns instead of 25)
#     Line #2367 (got 27 columns instead of 25)
#     Line #2368 (got 26 columns instead of 25)
#     Line #2372 (got 26 columns instead of 25)
#     Line #2374 (got 26 columns instead of 25)
#     Line #2375 (got 26 columns instead of 25)
#     Line #2380 (got 26 columns instead of 25)
#     Line #2383 (got 26 columns instead of 25)
#     Line #2384 (got 26 columns instead of 25)
#     Line #2385 (got 27 columns instead of 25)
#     Line #2387 (got 27 columns instead of 25)
#     Line #2390 (got 26 columns instead of 25)
#     Line #2391 (got 26 columns instead of 25)
#     Line #2392 (got 26 columns instead of 25)
#     Line #2400 (got 27 columns instead of 25)
#     Line #2401 (got 26 columns instead of 25)
#     Line #2404 (got 26 columns instead of 25)
#     Line #2406 (got 26 columns instead of 25)
#     Line #2407 (got 26 columns instead of 25)
#     Line #2408 (got 26 columns instead of 25)
#     Line #2409 (got 27 columns instead of 25)
#     Line #2412 (got 26 columns instead of 25)
#     Line #2413 (got 27 columns instead of 25)
#     Line #2417 (got 27 columns instead of 25)
#     Line #2418 (got 26 columns instead of 25)
#     Line #2419 (got 26 columns instead of 25)
#     Line #2420 (got 26 columns instead of 25)
#     Line #2424 (got 26 columns instead of 25)
#     Line #2428 (got 26 columns instead of 25)
#     Line #2430 (got 26 columns instead of 25)
#     Line #2431 (got 26 columns instead of 25)
#     Line #2434 (got 16 columns instead of 25)
#     Line #2439 (got 26 columns instead of 25)
#     Line #2440 (got 26 columns instead of 25)
#     Line #2441 (got 26 columns instead of 25)
#     Line #2442 (got 26 columns instead of 25)
#     Line #2443 (got 26 columns instead of 25)
#     Line #2445 (got 26 columns instead of 25)
#     Line #2449 (got 26 columns instead of 25)
#     Line #2456 (got 26 columns instead of 25)
#     Line #2458 (got 26 columns instead of 25)
#     Line #2461 (got 26 columns instead of 25)
#     Line #2463 (got 26 columns instead of 25)
#     Line #2465 (got 26 columns instead of 25)
#     Line #2467 (got 26 columns instead of 25)
#     Line #2468 (got 27 columns instead of 25)
#     Line #2474 (got 26 columns instead of 25)
#     Line #2476 (got 26 columns instead of 25)
#     Line #2477 (got 26 columns instead of 25)
#     Line #2478 (got 26 columns instead of 25)
#     Line #2479 (got 26 columns instead of 25)
#     Line #2480 (got 26 columns instead of 25)
#     Line #2481 (got 26 columns instead of 25)
#     Line #2486 (got 26 columns instead of 25)
#     Line #2487 (got 26 columns instead of 25)
#     Line #2489 (got 26 columns instead of 25)
#     Line #2492 (got 27 columns instead of 25)
#     Line #2493 (got 26 columns instead of 25)
#     Line #2494 (got 26 columns instead of 25)
#     Line #2496 (got 26 columns instead of 25)
#     Line #2497 (got 26 columns instead of 25)
#     Line #2498 (got 27 columns instead of 25)
#     Line #2499 (got 26 columns instead of 25)
#     Line #2503 (got 26 columns instead of 25)
#     Line #2505 (got 26 columns instead of 25)
#     Line #2506 (got 26 columns instead of 25)
#     Line #2512 (got 27 columns instead of 25)
#     Line #2513 (got 26 columns instead of 25)
#     Line #2515 (got 26 columns instead of 25)
#     Line #2517 (got 26 columns instead of 25)
#     Line #2520 (got 27 columns instead of 25)
#     Line #2527 (got 26 columns instead of 25)
#     Line #2531 (got 26 columns instead of 25)
#     Line #2532 (got 26 columns instead of 25)
#     Line #2540 (got 26 columns instead of 25)
#     Line #2543 (got 26 columns instead of 25)
#     Line #2544 (got 26 columns instead of 25)
#     Line #2545 (got 26 columns instead of 25)
#     Line #2548 (got 26 columns instead of 25)
#     Line #2550 (got 26 columns instead of 25)
#     Line #2551 (got 26 columns instead of 25)
#     Line #2552 (got 26 columns instead of 25)
#     Line #2555 (got 26 columns instead of 25)
#     Line #2557 (got 26 columns instead of 25)
#     Line #2558 (got 26 columns instead of 25)
#     Line #2559 (got 26 columns instead of 25)
#     Line #2562 (got 26 columns instead of 25)
#     Line #2564 (got 26 columns instead of 25)
#     Line #2567 (got 26 columns instead of 25)
#     Line #2570 (got 16 columns instead of 25)
#     Line #2571 (got 27 columns instead of 25)
#     Line #2573 (got 26 columns instead of 25)
#     Line #2575 (got 26 columns instead of 25)
#     Line #2576 (got 26 columns instead of 25)
#     Line #2577 (got 27 columns instead of 25)
#     Line #2578 (got 26 columns instead of 25)
#     Line #2582 (got 26 columns instead of 25)
#     Line #2584 (got 26 columns instead of 25)
#     Line #2585 (got 26 columns instead of 25)
#     Line #2586 (got 26 columns instead of 25)
#     Line #2592 (got 26 columns instead of 25)
#     Line #2596 (got 26 columns instead of 25)
#     Line #2598 (got 26 columns instead of 25)
#     Line #2599 (got 27 columns instead of 25)
#     Line #2605 (got 26 columns instead of 25)
#     Line #2607 (got 26 columns instead of 25)
#     Line #2610 (got 26 columns instead of 25)
#     Line #2611 (got 26 columns instead of 25)
#     Line #2612 (got 26 columns instead of 25)
#     Line #2613 (got 26 columns instead of 25)
#     Line #2617 (got 27 columns instead of 25)
#     Line #2618 (got 27 columns instead of 25)
#     Line #2620 (got 27 columns instead of 25)
#     Line #2622 (got 26 columns instead of 25)
#     Line #2623 (got 26 columns instead of 25)
#     Line #2624 (got 27 columns instead of 25)
#     Line #2629 (got 26 columns instead of 25)
#     Line #2630 (got 26 columns instead of 25)
#     Line #2633 (got 26 columns instead of 25)
#     Line #2636 (got 27 columns instead of 25)
#     Line #2637 (got 27 columns instead of 25)
#     Line #2638 (got 26 columns instead of 25)
#     Line #2642 (got 26 columns instead of 25)
#     Line #2644 (got 26 columns instead of 25)
#     Line #2645 (got 26 columns instead of 25)
#     Line #2648 (got 26 columns instead of 25)
#     Line #2649 (got 27 columns instead of 25)
#     Line #2650 (got 26 columns instead of 25)
#     Line #2651 (got 26 columns instead of 25)
#     Line #2654 (got 26 columns instead of 25)
#     Line #2656 (got 26 columns instead of 25)
#     Line #2660 (got 26 columns instead of 25)
#     Line #2662 (got 26 columns instead of 25)
#     Line #2663 (got 26 columns instead of 25)
#     Line #2669 (got 26 columns instead of 25)
#     Line #2671 (got 26 columns instead of 25)
#     Line #2674 (got 27 columns instead of 25)
#     Line #2675 (got 26 columns instead of 25)
#     Line #2676 (got 26 columns instead of 25)
#     Line #2678 (got 26 columns instead of 25)
#     Line #2679 (got 26 columns instead of 25)
#     Line #2680 (got 27 columns instead of 25)
#     Line #2681 (got 26 columns instead of 25)
#     Line #2687 (got 26 columns instead of 25)
#     Line #2688 (got 26 columns instead of 25)
#     Line #2689 (got 26 columns instead of 25)
#     Line #2694 (got 26 columns instead of 25)
#     Line #2695 (got 26 columns instead of 25)
#     Line #2697 (got 26 columns instead of 25)
#     Line #2699 (got 26 columns instead of 25)
#     Line #2701 (got 26 columns instead of 25)
#     Line #2702 (got 27 columns instead of 25)
#     Line #2708 (got 26 columns instead of 25)
#     Line #2710 (got 26 columns instead of 25)
#     Line #2711 (got 26 columns instead of 25)
#     Line #2714 (got 26 columns instead of 25)
#     Line #2715 (got 26 columns instead of 25)
#     Line #2716 (got 26 columns instead of 25)
#     Line #2720 (got 27 columns instead of 25)
#     Line #2721 (got 26 columns instead of 25)
#     Line #2723 (got 26 columns instead of 25)
#     Line #2725 (got 26 columns instead of 25)
#     Line #2727 (got 26 columns instead of 25)
#     Line #2728 (got 27 columns instead of 25)
#     Line #2734 (got 26 columns instead of 25)
#     Line #2736 (got 26 columns instead of 25)
#     Line #2737 (got 26 columns instead of 25)
#     Line #2740 (got 26 columns instead of 25)
#     Line #2741 (got 26 columns instead of 25)
#     Line #2742 (got 26 columns instead of 25)
#     Line #2749 (got 26 columns instead of 25)
#     Line #2752 (got 16 columns instead of 25)
#     Line #2753 (got 27 columns instead of 25)
#     Line #2755 (got 26 columns instead of 25)
#     Line #2757 (got 26 columns instead of 25)
#     Line #2758 (got 26 columns instead of 25)
#     Line #2759 (got 27 columns instead of 25)
#     Line #2760 (got 26 columns instead of 25)
#     Line #2764 (got 26 columns instead of 25)
#     Line #2766 (got 26 columns instead of 25)
#     Line #2767 (got 26 columns instead of 25)
#     Line #2768 (got 26 columns instead of 25)
#     Line #2776 (got 26 columns instead of 25)
#     Line #2779 (got 26 columns instead of 25)
#     Line #2780 (got 26 columns instead of 25)
#     Line #2781 (got 26 columns instead of 25)
#     Line #2784 (got 26 columns instead of 25)
#     Line #2786 (got 26 columns instead of 25)
#     Line #2787 (got 26 columns instead of 25)
#     Line #2788 (got 26 columns instead of 25)
#     Line #2791 (got 26 columns instead of 25)
#     Line #2793 (got 26 columns instead of 25)
#     Line #2794 (got 26 columns instead of 25)
#     Line #2795 (got 26 columns instead of 25)
#     Line #2798 (got 26 columns instead of 25)
#     Line #2800 (got 27 columns instead of 25)
#     Line #2801 (got 26 columns instead of 25)
#     Line #2803 (got 26 columns instead of 25)
#     Line #2805 (got 26 columns instead of 25)
#     Line #2807 (got 26 columns instead of 25)
#     Line #2808 (got 27 columns instead of 25)
#     Line #2814 (got 26 columns instead of 25)
#     Line #2816 (got 26 columns instead of 25)
#     Line #2817 (got 26 columns instead of 25)
#     Line #2820 (got 26 columns instead of 25)
#     Line #2821 (got 26 columns instead of 25)
#     Line #2822 (got 26 columns instead of 25)
#   data = np.genfromtxt(
# array([   0,    0,    0,    0,    0, 1482, 1482,    0,    0,    0, 1482,
#           0, 1482, 1482,  513, 1482, 1482, 1482, 1482,  195, 1482, 1482,
#        1482, 1482, 1482])

# %%
print("t")
# Out:
# t

# %%
# @title
import numpy as np

data = np.genfromtxt(
    "/sales_data.csv",
    delimiter=",",
    skip_header=1,
    encoding="latin1",
    filling_values=np.nan,
    invalid_raise=False
)
data.shape
np.isnan(data).sum()
# Out:
# /tmp/ipython-input-2811930836.py:4: ConversionWarning: Some errors were detected !
#     Line #8 (got 26 columns instead of 25)
#     Line #9 (got 26 columns instead of 25)
#     Line #11 (got 26 columns instead of 25)
#     Line #12 (got 26 columns instead of 25)
#     Line #16 (got 26 columns instead of 25)
#     Line #18 (got 26 columns instead of 25)
#     Line #23 (got 26 columns instead of 25)
#     Line #24 (got 26 columns instead of 25)
#     Line #26 (got 26 columns instead of 25)
#     Line #27 (got 26 columns instead of 25)
#     Line #29 (got 26 columns instead of 25)
#     Line #30 (got 27 columns instead of 25)
#     Line #32 (got 27 columns instead of 25)
#     Line #34 (got 26 columns instead of 25)
#     Line #35 (got 26 columns instead of 25)
#     Line #36 (got 27 columns instead of 25)
#     Line #41 (got 26 columns instead of 25)
#     Line #42 (got 26 columns instead of 25)
#     Line #45 (got 26 columns instead of 25)
#     Line #49 (got 26 columns instead of 25)
#     Line #53 (got 26 columns instead of 25)
#     Line #55 (got 26 columns instead of 25)
#     Line #57 (got 26 columns instead of 25)
#     Line #62 (got 26 columns instead of 25)
#     Line #63 (got 26 columns instead of 25)
#     Line #65 (got 27 columns instead of 25)
#     Line #66 (got 26 columns instead of 25)
#     Line #70 (got 26 columns instead of 25)
#     Line #72 (got 26 columns instead of 25)
#     Line #76 (got 26 columns instead of 25)
#     Line #77 (got 26 columns instead of 25)
#     Line #78 (got 26 columns instead of 25)
#     Line #80 (got 26 columns instead of 25)
#     Line #81 (got 26 columns instead of 25)
#     Line #83 (got 26 columns instead of 25)
#     Line #88 (got 26 columns instead of 25)
#     Line #89 (got 26 columns instead of 25)
#     Line #91 (got 27 columns instead of 25)
#     Line #92 (got 26 columns instead of 25)
#     Line #96 (got 26 columns instead of 25)
#     Line #98 (got 26 columns instead of 25)
#     Line #102 (got 26 columns instead of 25)
#     Line #104 (got 26 columns instead of 25)
#     Line #106 (got 26 columns instead of 25)
#     Line #107 (got 26 columns instead of 25)
#     Line #110 (got 26 columns instead of 25)
#     Line #112 (got 26 columns instead of 25)
#     Line #115 (got 26 columns instead of 25)
#     Line #116 (got 26 columns instead of 25)
#     Line #117 (got 26 columns instead of 25)
#     Line #122 (got 26 columns instead of 25)
#     Line #124 (got 26 columns instead of 25)
#     Line #128 (got 26 columns instead of 25)
#     Line #130 (got 26 columns instead of 25)
#     Line #136 (got 27 columns instead of 25)
#     Line #137 (got 27 columns instead of 25)
#     Line #139 (got 27 columns instead of 25)
#     Line #141 (got 26 columns instead of 25)
#     Line #142 (got 26 columns instead of 25)
#     Line #143 (got 27 columns instead of 25)
#     Line #149 (got 26 columns instead of 25)
#     Line #155 (got 26 columns instead of 25)
#     Line #156 (got 26 columns instead of 25)
#     Line #158 (got 26 columns instead of 25)
#     Line #160 (got 26 columns instead of 25)
#     Line #162 (got 26 columns instead of 25)
#     Line #163 (got 16 columns instead of 25)
#     Line #164 (got 26 columns instead of 25)
#     Line #168 (got 26 columns instead of 25)
#     Line #169 (got 26 columns instead of 25)
#     Line #170 (got 26 columns instead of 25)
#     Line #171 (got 26 columns instead of 25)
#     Line #172 (got 26 columns instead of 25)
#     Line #173 (got 26 columns instead of 25)
#     Line #175 (got 26 columns instead of 25)
#     Line #178 (got 26 columns instead of 25)
#     Line #179 (got 26 columns instead of 25)
#     Line #180 (got 26 columns instead of 25)
#     Line #181 (got 26 columns instead of 25)
#     Line #184 (got 26 columns instead of 25)
#     Line #185 (got 26 columns instead of 25)
#     Line #189 (got 27 columns instead of 25)
#     Line #192 (got 26 columns instead of 25)
#     Line #193 (got 27 columns instead of 25)
#     Line #197 (got 27 columns instead of 25)
#     Line #198 (got 26 columns instead of 25)
#     Line #199 (got 26 columns instead of 25)
#     Line #200 (got 26 columns instead of 25)
#     Line #204 (got 26 columns instead of 25)
#     Line #207 (got 27 columns instead of 25)
#     Line #208 (got 27 columns instead of 25)
#     Line #216 (got 27 columns instead of 25)
#     Line #218 (got 27 columns instead of 25)
#     Line #220 (got 26 columns instead of 25)
#     Line #221 (got 26 columns instead of 25)
#     Line #222 (got 27 columns instead of 25)
#     Line #224 (got 26 columns instead of 25)
#     Line #227 (got 26 columns instead of 25)
#     Line #228 (got 26 columns instead of 25)
#     Line #231 (got 26 columns instead of 25)
#     Line #235 (got 26 columns instead of 25)
#     Line #237 (got 26 columns instead of 25)
#     Line #239 (got 26 columns instead of 25)
#     Line #241 (got 26 columns instead of 25)
#     Line #247 (got 26 columns instead of 25)
#     Line #248 (got 26 columns instead of 25)
#     Line #251 (got 26 columns instead of 25)
#     Line #252 (got 26 columns instead of 25)
#     Line #258 (got 26 columns instead of 25)
#     Line #264 (got 26 columns instead of 25)
#     Line #266 (got 26 columns instead of 25)
#     Line #267 (got 26 columns instead of 25)
#     Line #268 (got 26 columns instead of 25)
#     Line #269 (got 27 columns instead of 25)
#     Line #272 (got 26 columns instead of 25)
#     Line #273 (got 27 columns instead of 25)
#     Line #277 (got 27 columns instead of 25)
#     Line #278 (got 26 columns instead of 25)
#     Line #279 (got 26 columns instead of 25)
#     Line #280 (got 26 columns instead of 25)
#     Line #284 (got 26 columns instead of 25)
#     Line #287 (got 27 columns instead of 25)
#     Line #288 (got 27 columns instead of 25)
#     Line #289 (got 26 columns instead of 25)
#     Line #290 (got 26 columns instead of 25)
#     Line #293 (got 16 columns instead of 25)
#     Line #294 (got 26 columns instead of 25)
#     Line #297 (got 26 columns instead of 25)
#     Line #299 (got 26 columns instead of 25)
#     Line #300 (got 26 columns instead of 25)
#     Line #301 (got 26 columns instead of 25)
#     Line #302 (got 26 columns instead of 25)
#     Line #303 (got 26 columns instead of 25)
#     Line #305 (got 26 columns instead of 25)
#     Line #308 (got 26 columns instead of 25)
#     Line #309 (got 26 columns instead of 25)
#     Line #310 (got 26 columns instead of 25)
#     Line #311 (got 26 columns instead of 25)
#     Line #314 (got 26 columns instead of 25)
#     Line #319 (got 27 columns instead of 25)
#     Line #322 (got 26 columns instead of 25)
#     Line #323 (got 27 columns instead of 25)
#     Line #327 (got 27 columns instead of 25)
#     Line #328 (got 26 columns instead of 25)
#     Line #329 (got 26 columns instead of 25)
#     Line #330 (got 26 columns instead of 25)
#     Line #334 (got 26 columns instead of 25)
#     Line #337 (got 27 columns instead of 25)
#     Line #340 (got 26 columns instead of 25)
#     Line #344 (got 16 columns instead of 25)
#     Line #345 (got 26 columns instead of 25)
#     Line #349 (got 26 columns instead of 25)
#     Line #350 (got 26 columns instead of 25)
#     Line #351 (got 26 columns instead of 25)
#     Line #352 (got 26 columns instead of 25)
#     Line #353 (got 26 columns instead of 25)
#     Line #354 (got 26 columns instead of 25)
#     Line #356 (got 26 columns instead of 25)
#     Line #359 (got 26 columns instead of 25)
#     Line #360 (got 26 columns instead of 25)
#     Line #361 (got 26 columns instead of 25)
#     Line #362 (got 26 columns instead of 25)
#     Line #365 (got 26 columns instead of 25)
#     Line #366 (got 26 columns instead of 25)
#     Line #369 (got 26 columns instead of 25)
#     Line #372 (got 26 columns instead of 25)
#     Line #373 (got 26 columns instead of 25)
#     Line #374 (got 27 columns instead of 25)
#     Line #375 (got 26 columns instead of 25)
#     Line #376 (got 27 columns instead of 25)
#     Line #381 (got 26 columns instead of 25)
#     Line #389 (got 27 columns instead of 25)
#     Line #391 (got 26 columns instead of 25)
#     Line #394 (got 26 columns instead of 25)
#     Line #395 (got 26 columns instead of 25)
#     Line #396 (got 16 columns instead of 25)
#     Line #397 (got 26 columns instead of 25)
#     Line #400 (got 26 columns instead of 25)
#     Line #402 (got 26 columns instead of 25)
#     Line #404 (got 26 columns instead of 25)
#     Line #405 (got 26 columns instead of 25)
#     Line #406 (got 26 columns instead of 25)
#     Line #407 (got 26 columns instead of 25)
#     Line #408 (got 26 columns instead of 25)
#     Line #410 (got 27 columns instead of 25)
#     Line #411 (got 26 columns instead of 25)
#     Line #412 (got 26 columns instead of 25)
#     Line #413 (got 26 columns instead of 25)
#     Line #417 (got 26 columns instead of 25)
#     Line #418 (got 26 columns instead of 25)
#     Line #420 (got 26 columns instead of 25)
#     Line #424 (got 27 columns instead of 25)
#     Line #426 (got 27 columns instead of 25)
#     Line #428 (got 26 columns instead of 25)
#     Line #429 (got 26 columns instead of 25)
#     Line #430 (got 27 columns instead of 25)
#     Line #435 (got 26 columns instead of 25)
#     Line #436 (got 26 columns instead of 25)
#     Line #439 (got 26 columns instead of 25)
#     Line #443 (got 26 columns instead of 25)
#     Line #445 (got 26 columns instead of 25)
#     Line #447 (got 26 columns instead of 25)
#     Line #449 (got 26 columns instead of 25)
#     Line #451 (got 26 columns instead of 25)
#     Line #453 (got 26 columns instead of 25)
#     Line #456 (got 26 columns instead of 25)
#     Line #459 (got 26 columns instead of 25)
#     Line #460 (got 26 columns instead of 25)
#     Line #461 (got 27 columns instead of 25)
#     Line #462 (got 26 columns instead of 25)
#     Line #465 (got 26 columns instead of 25)
#     Line #466 (got 27 columns instead of 25)
#     Line #467 (got 26 columns instead of 25)
#     Line #470 (got 26 columns instead of 25)
#     Line #473 (got 26 columns instead of 25)
#     Line #479 (got 26 columns instead of 25)
#     Line #480 (got 26 columns instead of 25)
#     Line #485 (got 26 columns instead of 25)
#     Line #486 (got 26 columns instead of 25)
#     Line #488 (got 27 columns instead of 25)
#     Line #489 (got 26 columns instead of 25)
#     Line #492 (got 26 columns instead of 25)
#     Line #493 (got 26 columns instead of 25)
#     Line #496 (got 26 columns instead of 25)
#     Line #500 (got 26 columns instead of 25)
#     Line #501 (got 26 columns instead of 25)
#     Line #505 (got 27 columns instead of 25)
#     Line #506 (got 26 columns instead of 25)
#     Line #511 (got 26 columns instead of 25)
#     Line #512 (got 26 columns instead of 25)
#     Line #514 (got 27 columns instead of 25)
#     Line #515 (got 26 columns instead of 25)
#     Line #518 (got 26 columns instead of 25)
#     Line #519 (got 26 columns instead of 25)
#     Line #522 (got 26 columns instead of 25)
#     Line #523 (got 26 columns instead of 25)
#     Line #527 (got 26 columns instead of 25)
#     Line #529 (got 26 columns instead of 25)
#     Line #530 (got 26 columns instead of 25)
#     Line #532 (got 26 columns instead of 25)
#     Line #535 (got 26 columns instead of 25)
#     Line #538 (got 26 columns instead of 25)
#     Line #540 (got 26 columns instead of 25)
#     Line #541 (got 26 columns instead of 25)
#     Line #545 (got 27 columns instead of 25)
#     Line #546 (got 26 columns instead of 25)
#     Line #551 (got 26 columns instead of 25)
#     Line #558 (got 26 columns instead of 25)
#     Line #561 (got 26 columns instead of 25)
#     Line #562 (got 16 columns instead of 25)
#     Line #563 (got 27 columns instead of 25)
#     Line #566 (got 26 columns instead of 25)
#     Line #568 (got 27 columns instead of 25)
#     Line #569 (got 26 columns instead of 25)
#     Line #570 (got 26 columns instead of 25)
#     Line #573 (got 26 columns instead of 25)
#     Line #574 (got 26 columns instead of 25)
#     Line #575 (got 26 columns instead of 25)
#     Line #576 (got 26 columns instead of 25)
#     Line #581 (got 26 columns instead of 25)
#     Line #587 (got 26 columns instead of 25)
#     Line #589 (got 27 columns instead of 25)
#     Line #590 (got 27 columns instead of 25)
#     Line #591 (got 26 columns instead of 25)
#     Line #594 (got 26 columns instead of 25)
#     Line #597 (got 26 columns instead of 25)
#     Line #599 (got 26 columns instead of 25)
#     Line #601 (got 26 columns instead of 25)
#     Line #602 (got 16 columns instead of 25)
#     Line #603 (got 26 columns instead of 25)
#     Line #606 (got 26 columns instead of 25)
#     Line #608 (got 26 columns instead of 25)
#     Line #610 (got 26 columns instead of 25)
#     Line #611 (got 26 columns instead of 25)
#     Line #612 (got 26 columns instead of 25)
#     Line #613 (got 26 columns instead of 25)
#     Line #614 (got 26 columns instead of 25)
#     Line #617 (got 26 columns instead of 25)
#     Line #618 (got 26 columns instead of 25)
#     Line #619 (got 26 columns instead of 25)
#     Line #622 (got 26 columns instead of 25)
#     Line #623 (got 26 columns instead of 25)
#     Line #624 (got 26 columns instead of 25)
#     Line #626 (got 26 columns instead of 25)
#     Line #629 (got 26 columns instead of 25)
#     Line #631 (got 26 columns instead of 25)
#     Line #634 (got 26 columns instead of 25)
#     Line #637 (got 26 columns instead of 25)
#     Line #639 (got 27 columns instead of 25)
#     Line #640 (got 26 columns instead of 25)
#     Line #643 (got 26 columns instead of 25)
#     Line #644 (got 27 columns instead of 25)
#     Line #645 (got 26 columns instead of 25)
#     Line #648 (got 26 columns instead of 25)
#     Line #650 (got 26 columns instead of 25)
#     Line #651 (got 26 columns instead of 25)
#     Line #655 (got 26 columns instead of 25)
#     Line #658 (got 26 columns instead of 25)
#     Line #659 (got 26 columns instead of 25)
#     Line #660 (got 27 columns instead of 25)
#     Line #662 (got 27 columns instead of 25)
#     Line #666 (got 26 columns instead of 25)
#     Line #667 (got 26 columns instead of 25)
#     Line #675 (got 27 columns instead of 25)
#     Line #677 (got 26 columns instead of 25)
#     Line #680 (got 26 columns instead of 25)
#     Line #681 (got 26 columns instead of 25)
#     Line #683 (got 26 columns instead of 25)
#     Line #689 (got 26 columns instead of 25)
#     Line #691 (got 27 columns instead of 25)
#     Line #692 (got 27 columns instead of 25)
#     Line #693 (got 26 columns instead of 25)
#     Line #696 (got 27 columns instead of 25)
#     Line #698 (got 26 columns instead of 25)
#     Line #699 (got 26 columns instead of 25)
#     Line #701 (got 26 columns instead of 25)
#     Line #703 (got 26 columns instead of 25)
#     Line #704 (got 26 columns instead of 25)
#     Line #705 (got 27 columns instead of 25)
#     Line #707 (got 26 columns instead of 25)
#     Line #708 (got 26 columns instead of 25)
#     Line #709 (got 27 columns instead of 25)
#     Line #710 (got 26 columns instead of 25)
#     Line #711 (got 27 columns instead of 25)
#     Line #715 (got 26 columns instead of 25)
#     Line #723 (got 26 columns instead of 25)
#     Line #725 (got 26 columns instead of 25)
#     Line #726 (got 26 columns instead of 25)
#     Line #727 (got 26 columns instead of 25)
#     Line #728 (got 26 columns instead of 25)
#     Line #729 (got 26 columns instead of 25)
#     Line #730 (got 26 columns instead of 25)
#     Line #731 (got 26 columns instead of 25)
#     Line #737 (got 26 columns instead of 25)
#     Line #739 (got 27 columns instead of 25)
#     Line #740 (got 27 columns instead of 25)
#     Line #744 (got 26 columns instead of 25)
#     Line #747 (got 26 columns instead of 25)
#     Line #748 (got 26 columns instead of 25)
#     Line #751 (got 26 columns instead of 25)
#     Line #754 (got 26 columns instead of 25)
#     Line #756 (got 27 columns instead of 25)
#     Line #757 (got 27 columns instead of 25)
#     Line #759 (got 26 columns instead of 25)
#     Line #760 (got 27 columns instead of 25)
#     Line #761 (got 26 columns instead of 25)
#     Line #762 (got 27 columns instead of 25)
#     Line #763 (got 27 columns instead of 25)
#     Line #767 (got 26 columns instead of 25)
#     Line #775 (got 26 columns instead of 25)
#     Line #776 (got 26 columns instead of 25)
#     Line #778 (got 26 columns instead of 25)
#     Line #780 (got 26 columns instead of 25)
#     Line #781 (got 26 columns instead of 25)
#     Line #782 (got 26 columns instead of 25)
#     Line #784 (got 26 columns instead of 25)
#     Line #785 (got 26 columns instead of 25)
#     Line #788 (got 27 columns instead of 25)
#     Line #789 (got 26 columns instead of 25)
#     Line #790 (got 26 columns instead of 25)
#     Line #793 (got 26 columns instead of 25)
#     Line #794 (got 27 columns instead of 25)
#     Line #795 (got 26 columns instead of 25)
#     Line #799 (got 26 columns instead of 25)
#     Line #801 (got 26 columns instead of 25)
#     Line #802 (got 26 columns instead of 25)
#     Line #807 (got 26 columns instead of 25)
#     Line #812 (got 26 columns instead of 25)
#     Line #813 (got 26 columns instead of 25)
#     Line #815 (got 27 columns instead of 25)
#     Line #816 (got 26 columns instead of 25)
#     Line #820 (got 26 columns instead of 25)
#     Line #822 (got 26 columns instead of 25)
#     Line #826 (got 26 columns instead of 25)
#     Line #828 (got 26 columns instead of 25)
#     Line #830 (got 26 columns instead of 25)
#     Line #831 (got 26 columns instead of 25)
#     Line #832 (got 26 columns instead of 25)
#     Line #833 (got 26 columns instead of 25)
#     Line #834 (got 26 columns instead of 25)
#     Line #835 (got 26 columns instead of 25)
#     Line #840 (got 26 columns instead of 25)
#     Line #841 (got 26 columns instead of 25)
#     Line #842 (got 27 columns instead of 25)
#     Line #843 (got 27 columns instead of 25)
#     Line #844 (got 26 columns instead of 25)
#     Line #845 (got 26 columns instead of 25)
#     Line #847 (got 26 columns instead of 25)
#     Line #848 (got 26 columns instead of 25)
#     Line #851 (got 26 columns instead of 25)
#     Line #852 (got 26 columns instead of 25)
#     Line #855 (got 26 columns instead of 25)
#     Line #859 (got 26 columns instead of 25)
#     Line #861 (got 26 columns instead of 25)
#     Line #864 (got 26 columns instead of 25)
#     Line #867 (got 26 columns instead of 25)
#     Line #869 (got 26 columns instead of 25)
#     Line #870 (got 26 columns instead of 25)
#     Line #873 (got 26 columns instead of 25)
#     Line #874 (got 27 columns instead of 25)
#     Line #875 (got 26 columns instead of 25)
#     Line #879 (got 26 columns instead of 25)
#     Line #880 (got 26 columns instead of 25)
#     Line #884 (got 26 columns instead of 25)
#     Line #885 (got 27 columns instead of 25)
#     Line #886 (got 26 columns instead of 25)
#     Line #887 (got 27 columns instead of 25)
#     Line #889 (got 26 columns instead of 25)
#     Line #890 (got 26 columns instead of 25)
#     Line #891 (got 26 columns instead of 25)
#     Line #895 (got 26 columns instead of 25)
#     Line #897 (got 26 columns instead of 25)
#     Line #900 (got 26 columns instead of 25)
#     Line #904 (got 26 columns instead of 25)
#     Line #908 (got 26 columns instead of 25)
#     Line #912 (got 27 columns instead of 25)
#     Line #913 (got 26 columns instead of 25)
#     Line #914 (got 27 columns instead of 25)
#     Line #917 (got 26 columns instead of 25)
#     Line #918 (got 26 columns instead of 25)
#     Line #922 (got 26 columns instead of 25)
#     Line #927 (got 26 columns instead of 25)
#     Line #930 (got 26 columns instead of 25)
#     Line #931 (got 26 columns instead of 25)
#     Line #941 (got 26 columns instead of 25)
#     Line #944 (got 26 columns instead of 25)
#     Line #945 (got 26 columns instead of 25)
#     Line #946 (got 26 columns instead of 25)
#     Line #949 (got 26 columns instead of 25)
#     Line #951 (got 26 columns instead of 25)
#     Line #952 (got 26 columns instead of 25)
#     Line #953 (got 26 columns instead of 25)
#     Line #956 (got 26 columns instead of 25)
#     Line #957 (got 26 columns instead of 25)
#     Line #958 (got 26 columns instead of 25)
#     Line #959 (got 26 columns instead of 25)
#     Line #965 (got 27 columns instead of 25)
#     Line #966 (got 26 columns instead of 25)
#     Line #967 (got 27 columns instead of 25)
#     Line #970 (got 26 columns instead of 25)
#     Line #971 (got 26 columns instead of 25)
#     Line #975 (got 26 columns instead of 25)
#     Line #977 (got 26 columns instead of 25)
#     Line #980 (got 26 columns instead of 25)
#     Line #983 (got 26 columns instead of 25)
#     Line #984 (got 26 columns instead of 25)
#     Line #991 (got 27 columns instead of 25)
#     Line #992 (got 26 columns instead of 25)
#     Line #994 (got 26 columns instead of 25)
#     Line #996 (got 26 columns instead of 25)
#     Line #999 (got 27 columns instead of 25)
#     Line #1006 (got 26 columns instead of 25)
#     Line #1009 (got 27 columns instead of 25)
#     Line #1010 (got 26 columns instead of 25)
#     Line #1011 (got 26 columns instead of 25)
#     Line #1012 (got 26 columns instead of 25)
#     Line #1015 (got 26 columns instead of 25)
#     Line #1017 (got 27 columns instead of 25)
#     Line #1018 (got 26 columns instead of 25)
#     Line #1021 (got 26 columns instead of 25)
#     Line #1022 (got 26 columns instead of 25)
#     Line #1023 (got 26 columns instead of 25)
#     Line #1024 (got 26 columns instead of 25)
#     Line #1025 (got 27 columns instead of 25)
#     Line #1027 (got 26 columns instead of 25)
#     Line #1028 (got 26 columns instead of 25)
#     Line #1029 (got 27 columns instead of 25)
#     Line #1032 (got 26 columns instead of 25)
#     Line #1034 (got 26 columns instead of 25)
#     Line #1035 (got 26 columns instead of 25)
#     Line #1037 (got 26 columns instead of 25)
#     Line #1038 (got 26 columns instead of 25)
#     Line #1039 (got 26 columns instead of 25)
#     Line #1045 (got 26 columns instead of 25)
#     Line #1047 (got 27 columns instead of 25)
#     Line #1049 (got 26 columns instead of 25)
#     Line #1054 (got 26 columns instead of 25)
#     Line #1055 (got 26 columns instead of 25)
#     Line #1057 (got 26 columns instead of 25)
#     Line #1058 (got 26 columns instead of 25)
#     Line #1059 (got 26 columns instead of 25)
#     Line #1060 (got 26 columns instead of 25)
#     Line #1061 (got 26 columns instead of 25)
#     Line #1062 (got 26 columns instead of 25)
#     Line #1063 (got 26 columns instead of 25)
#     Line #1064 (got 26 columns instead of 25)
#     Line #1066 (got 26 columns instead of 25)
#     Line #1068 (got 27 columns instead of 25)
#     Line #1069 (got 26 columns instead of 25)
#     Line #1071 (got 26 columns instead of 25)
#     Line #1072 (got 27 columns instead of 25)
#     Line #1073 (got 26 columns instead of 25)
#     Line #1076 (got 27 columns instead of 25)
#     Line #1083 (got 26 columns instead of 25)
#     Line #1085 (got 26 columns instead of 25)
#     Line #1086 (got 27 columns instead of 25)
#     Line #1087 (got 26 columns instead of 25)
#     Line #1088 (got 26 columns instead of 25)
#     Line #1089 (got 26 columns instead of 25)
#     Line #1092 (got 16 columns instead of 25)
#     Line #1093 (got 26 columns instead of 25)
#     Line #1097 (got 26 columns instead of 25)
#     Line #1098 (got 26 columns instead of 25)
#     Line #1099 (got 26 columns instead of 25)
#     Line #1100 (got 26 columns instead of 25)
#     Line #1101 (got 26 columns instead of 25)
#     Line #1102 (got 26 columns instead of 25)
#     Line #1104 (got 26 columns instead of 25)
#     Line #1105 (got 26 columns instead of 25)
#     Line #1107 (got 26 columns instead of 25)
#     Line #1108 (got 26 columns instead of 25)
#     Line #1109 (got 26 columns instead of 25)
#     Line #1112 (got 26 columns instead of 25)
#     Line #1113 (got 26 columns instead of 25)
#     Line #1114 (got 26 columns instead of 25)
#     Line #1118 (got 27 columns instead of 25)
#     Line #1119 (got 26 columns instead of 25)
#     Line #1124 (got 26 columns instead of 25)
#     Line #1127 (got 27 columns instead of 25)
#     Line #1128 (got 26 columns instead of 25)
#     Line #1132 (got 26 columns instead of 25)
#     Line #1134 (got 26 columns instead of 25)
#     Line #1136 (got 26 columns instead of 25)
#     Line #1142 (got 16 columns instead of 25)
#     Line #1143 (got 26 columns instead of 25)
#     Line #1147 (got 26 columns instead of 25)
#     Line #1148 (got 26 columns instead of 25)
#     Line #1149 (got 26 columns instead of 25)
#     Line #1150 (got 26 columns instead of 25)
#     Line #1151 (got 26 columns instead of 25)
#     Line #1152 (got 26 columns instead of 25)
#     Line #1154 (got 26 columns instead of 25)
#     Line #1155 (got 26 columns instead of 25)
#     Line #1157 (got 26 columns instead of 25)
#     Line #1158 (got 26 columns instead of 25)
#     Line #1159 (got 26 columns instead of 25)
#     Line #1160 (got 26 columns instead of 25)
#     Line #1161 (got 16 columns instead of 25)
#     Line #1162 (got 26 columns instead of 25)
#     Line #1163 (got 26 columns instead of 25)
#     Line #1164 (got 26 columns instead of 25)
#     Line #1165 (got 26 columns instead of 25)
#     Line #1168 (got 26 columns instead of 25)
#     Line #1170 (got 26 columns instead of 25)
#     Line #1173 (got 26 columns instead of 25)
#     Line #1176 (got 26 columns instead of 25)
#     Line #1178 (got 27 columns instead of 25)
#     Line #1179 (got 26 columns instead of 25)
#     Line #1182 (got 26 columns instead of 25)
#     Line #1183 (got 27 columns instead of 25)
#     Line #1184 (got 26 columns instead of 25)
#     Line #1189 (got 26 columns instead of 25)
#     Line #1192 (got 16 columns instead of 25)
#     Line #1193 (got 26 columns instead of 25)
#     Line #1197 (got 26 columns instead of 25)
#     Line #1198 (got 26 columns instead of 25)
#     Line #1199 (got 26 columns instead of 25)
#     Line #1200 (got 26 columns instead of 25)
#     Line #1201 (got 26 columns instead of 25)
#     Line #1203 (got 26 columns instead of 25)
#     Line #1206 (got 27 columns instead of 25)
#     Line #1207 (got 26 columns instead of 25)
#     Line #1208 (got 26 columns instead of 25)
#     Line #1210 (got 16 columns instead of 25)
#     Line #1211 (got 26 columns instead of 25)
#     Line #1212 (got 26 columns instead of 25)
#     Line #1213 (got 26 columns instead of 25)
#     Line #1214 (got 26 columns instead of 25)
#     Line #1216 (got 26 columns instead of 25)
#     Line #1221 (got 26 columns instead of 25)
#     Line #1224 (got 26 columns instead of 25)
#     Line #1225 (got 26 columns instead of 25)
#     Line #1226 (got 26 columns instead of 25)
#     Line #1229 (got 26 columns instead of 25)
#     Line #1231 (got 26 columns instead of 25)
#     Line #1232 (got 26 columns instead of 25)
#     Line #1233 (got 26 columns instead of 25)
#     Line #1236 (got 26 columns instead of 25)
#     Line #1237 (got 26 columns instead of 25)
#     Line #1238 (got 26 columns instead of 25)
#     Line #1239 (got 26 columns instead of 25)
#     Line #1242 (got 26 columns instead of 25)
#     Line #1243 (got 26 columns instead of 25)
#     Line #1244 (got 27 columns instead of 25)
#     Line #1247 (got 26 columns instead of 25)
#     Line #1248 (got 27 columns instead of 25)
#     Line #1253 (got 26 columns instead of 25)
#     Line #1254 (got 26 columns instead of 25)
#     Line #1255 (got 26 columns instead of 25)
#     Line #1259 (got 26 columns instead of 25)
#     Line #1264 (got 26 columns instead of 25)
#     Line #1265 (got 26 columns instead of 25)
#     Line #1266 (got 26 columns instead of 25)
#     Line #1267 (got 26 columns instead of 25)
#     Line #1270 (got 26 columns instead of 25)
#     Line #1272 (got 26 columns instead of 25)
#     Line #1276 (got 26 columns instead of 25)
#     Line #1278 (got 26 columns instead of 25)
#     Line #1279 (got 27 columns instead of 25)
#     Line #1280 (got 26 columns instead of 25)
#     Line #1283 (got 26 columns instead of 25)
#     Line #1284 (got 26 columns instead of 25)
#     Line #1285 (got 26 columns instead of 25)
#     Line #1286 (got 26 columns instead of 25)
#     Line #1288 (got 26 columns instead of 25)
#     Line #1290 (got 26 columns instead of 25)
#     Line #1292 (got 27 columns instead of 25)
#     Line #1293 (got 26 columns instead of 25)
#     Line #1295 (got 26 columns instead of 25)
#     Line #1297 (got 26 columns instead of 25)
#     Line #1299 (got 26 columns instead of 25)
#     Line #1300 (got 27 columns instead of 25)
#     Line #1306 (got 26 columns instead of 25)
#     Line #1308 (got 26 columns instead of 25)
#     Line #1309 (got 26 columns instead of 25)
#     Line #1310 (got 26 columns instead of 25)
#     Line #1312 (got 26 columns instead of 25)
#     Line #1313 (got 26 columns instead of 25)
#     Line #1314 (got 26 columns instead of 25)
#     Line #1318 (got 27 columns instead of 25)
#     Line #1319 (got 27 columns instead of 25)
#     Line #1321 (got 27 columns instead of 25)
#     Line #1323 (got 26 columns instead of 25)
#     Line #1324 (got 26 columns instead of 25)
#     Line #1325 (got 27 columns instead of 25)
#     Line #1331 (got 26 columns instead of 25)
#     Line #1336 (got 26 columns instead of 25)
#     Line #1337 (got 26 columns instead of 25)
#     Line #1338 (got 26 columns instead of 25)
#     Line #1340 (got 26 columns instead of 25)
#     Line #1343 (got 26 columns instead of 25)
#     Line #1346 (got 27 columns instead of 25)
#     Line #1348 (got 27 columns instead of 25)
#     Line #1350 (got 26 columns instead of 25)
#     Line #1351 (got 26 columns instead of 25)
#     Line #1352 (got 27 columns instead of 25)
#     Line #1357 (got 26 columns instead of 25)
#     Line #1358 (got 26 columns instead of 25)
#     Line #1361 (got 26 columns instead of 25)
#     Line #1365 (got 27 columns instead of 25)
#     Line #1366 (got 26 columns instead of 25)
#     Line #1367 (got 26 columns instead of 25)
#     Line #1370 (got 26 columns instead of 25)
#     Line #1371 (got 16 columns instead of 25)
#     Line #1372 (got 26 columns instead of 25)
#     Line #1376 (got 26 columns instead of 25)
#     Line #1377 (got 26 columns instead of 25)
#     Line #1378 (got 26 columns instead of 25)
#     Line #1379 (got 26 columns instead of 25)
#     Line #1380 (got 26 columns instead of 25)
#     Line #1382 (got 26 columns instead of 25)
#     Line #1385 (got 26 columns instead of 25)
#     Line #1386 (got 26 columns instead of 25)
#     Line #1387 (got 26 columns instead of 25)
#     Line #1389 (got 16 columns instead of 25)
#     Line #1390 (got 26 columns instead of 25)
#     Line #1391 (got 26 columns instead of 25)
#     Line #1392 (got 26 columns instead of 25)
#     Line #1393 (got 26 columns instead of 25)
#     Line #1395 (got 26 columns instead of 25)
#     Line #1397 (got 26 columns instead of 25)
#     Line #1401 (got 26 columns instead of 25)
#     Line #1403 (got 26 columns instead of 25)
#     Line #1404 (got 27 columns instead of 25)
#     Line #1405 (got 26 columns instead of 25)
#     Line #1407 (got 26 columns instead of 25)
#     Line #1409 (got 26 columns instead of 25)
#     Line #1410 (got 26 columns instead of 25)
#     Line #1411 (got 26 columns instead of 25)
#     Line #1412 (got 26 columns instead of 25)
#     Line #1414 (got 26 columns instead of 25)
#     Line #1416 (got 26 columns instead of 25)
#     Line #1417 (got 26 columns instead of 25)
#     Line #1419 (got 26 columns instead of 25)
#     Line #1425 (got 26 columns instead of 25)
#     Line #1427 (got 26 columns instead of 25)
#     Line #1429 (got 26 columns instead of 25)
#     Line #1431 (got 27 columns instead of 25)
#     Line #1432 (got 26 columns instead of 25)
#     Line #1434 (got 26 columns instead of 25)
#     Line #1435 (got 26 columns instead of 25)
#     Line #1437 (got 26 columns instead of 25)
#     Line #1439 (got 26 columns instead of 25)
#     Line #1440 (got 26 columns instead of 25)
#     Line #1443 (got 26 columns instead of 25)
#     Line #1444 (got 26 columns instead of 25)
#     Line #1445 (got 27 columns instead of 25)
#     Line #1447 (got 27 columns instead of 25)
#     Line #1450 (got 26 columns instead of 25)
#     Line #1451 (got 26 columns instead of 25)
#     Line #1452 (got 26 columns instead of 25)
#     Line #1460 (got 27 columns instead of 25)
#     Line #1462 (got 26 columns instead of 25)
#     Line #1464 (got 26 columns instead of 25)
#     Line #1465 (got 26 columns instead of 25)
#     Line #1466 (got 26 columns instead of 25)
#     Line #1467 (got 26 columns instead of 25)
#     Line #1469 (got 26 columns instead of 25)
#     Line #1474 (got 26 columns instead of 25)
#     Line #1475 (got 26 columns instead of 25)
#     Line #1477 (got 26 columns instead of 25)
#     Line #1478 (got 26 columns instead of 25)
#     Line #1482 (got 26 columns instead of 25)
#     Line #1484 (got 26 columns instead of 25)
#     Line #1488 (got 26 columns instead of 25)
#     Line #1490 (got 26 columns instead of 25)
#     Line #1492 (got 26 columns instead of 25)
#     Line #1493 (got 26 columns instead of 25)
#     Line #1494 (got 26 columns instead of 25)
#     Line #1495 (got 26 columns instead of 25)
#     Line #1497 (got 26 columns instead of 25)
#     Line #1500 (got 26 columns instead of 25)
#     Line #1503 (got 26 columns instead of 25)
#     Line #1505 (got 26 columns instead of 25)
#     Line #1509 (got 27 columns instead of 25)
#     Line #1510 (got 26 columns instead of 25)
#     Line #1512 (got 26 columns instead of 25)
#     Line #1515 (got 26 columns instead of 25)
#     Line #1517 (got 26 columns instead of 25)
#     Line #1519 (got 26 columns instead of 25)
#     Line #1520 (got 26 columns instead of 25)
#     Line #1523 (got 27 columns instead of 25)
#     Line #1524 (got 26 columns instead of 25)
#     Line #1525 (got 26 columns instead of 25)
#     Line #1527 (got 26 columns instead of 25)
#     Line #1528 (got 26 columns instead of 25)
#     Line #1529 (got 27 columns instead of 25)
#     Line #1530 (got 26 columns instead of 25)
#     Line #1534 (got 26 columns instead of 25)
#     Line #1536 (got 26 columns instead of 25)
#     Line #1537 (got 26 columns instead of 25)
#     Line #1541 (got 26 columns instead of 25)
#     Line #1542 (got 26 columns instead of 25)
#     Line #1548 (got 26 columns instead of 25)
#     Line #1549 (got 26 columns instead of 25)
#     Line #1550 (got 27 columns instead of 25)
#     Line #1551 (got 27 columns instead of 25)
#     Line #1555 (got 26 columns instead of 25)
#     Line #1558 (got 26 columns instead of 25)
#     Line #1559 (got 26 columns instead of 25)
#     Line #1562 (got 26 columns instead of 25)
#     Line #1563 (got 26 columns instead of 25)
#     Line #1565 (got 26 columns instead of 25)
#     Line #1567 (got 26 columns instead of 25)
#     Line #1572 (got 26 columns instead of 25)
#     Line #1573 (got 26 columns instead of 25)
#     Line #1575 (got 27 columns instead of 25)
#     Line #1576 (got 26 columns instead of 25)
#     Line #1580 (got 26 columns instead of 25)
#     Line #1582 (got 26 columns instead of 25)
#     Line #1586 (got 26 columns instead of 25)
#     Line #1587 (got 26 columns instead of 25)
#     Line #1588 (got 26 columns instead of 25)
#     Line #1590 (got 26 columns instead of 25)
#     Line #1593 (got 27 columns instead of 25)
#     Line #1594 (got 26 columns instead of 25)
#     Line #1596 (got 26 columns instead of 25)
#     Line #1598 (got 26 columns instead of 25)
#     Line #1600 (got 26 columns instead of 25)
#     Line #1601 (got 27 columns instead of 25)
#     Line #1607 (got 26 columns instead of 25)
#     Line #1609 (got 26 columns instead of 25)
#     Line #1610 (got 26 columns instead of 25)
#     Line #1611 (got 26 columns instead of 25)
#     Line #1613 (got 26 columns instead of 25)
#     Line #1614 (got 26 columns instead of 25)
#     Line #1618 (got 26 columns instead of 25)
#     Line #1619 (got 26 columns instead of 25)
#     Line #1625 (got 26 columns instead of 25)
#     Line #1626 (got 26 columns instead of 25)
#     Line #1627 (got 27 columns instead of 25)
#     Line #1628 (got 27 columns instead of 25)
#     Line #1629 (got 26 columns instead of 25)
#     Line #1630 (got 26 columns instead of 25)
#     Line #1632 (got 26 columns instead of 25)
#     Line #1633 (got 26 columns instead of 25)
#     Line #1636 (got 26 columns instead of 25)
#     Line #1637 (got 26 columns instead of 25)
#     Line #1640 (got 26 columns instead of 25)
#     Line #1641 (got 26 columns instead of 25)
#     Line #1644 (got 27 columns instead of 25)
#     Line #1645 (got 27 columns instead of 25)
#     Line #1647 (got 26 columns instead of 25)
#     Line #1648 (got 27 columns instead of 25)
#     Line #1649 (got 26 columns instead of 25)
#     Line #1650 (got 27 columns instead of 25)
#     Line #1651 (got 27 columns instead of 25)
#     Line #1655 (got 26 columns instead of 25)
#     Line #1663 (got 26 columns instead of 25)
#     Line #1664 (got 27 columns instead of 25)
#     Line #1665 (got 26 columns instead of 25)
#     Line #1668 (got 26 columns instead of 25)
#     Line #1669 (got 26 columns instead of 25)
#     Line #1670 (got 16 columns instead of 25)
#     Line #1675 (got 26 columns instead of 25)
#     Line #1676 (got 26 columns instead of 25)
#     Line #1677 (got 26 columns instead of 25)
#     Line #1678 (got 26 columns instead of 25)
#     Line #1679 (got 26 columns instead of 25)
#     Line #1681 (got 26 columns instead of 25)
#     Line #1685 (got 26 columns instead of 25)
#     Line #1688 (got 16 columns instead of 25)
#     Line #1690 (got 26 columns instead of 25)
#     Line #1691 (got 26 columns instead of 25)
#     Line #1692 (got 26 columns instead of 25)
#     Line #1694 (got 26 columns instead of 25)
#     Line #1695 (got 26 columns instead of 25)
#     Line #1697 (got 26 columns instead of 25)
#     Line #1703 (got 26 columns instead of 25)
#     Line #1704 (got 27 columns instead of 25)
#     Line #1705 (got 26 columns instead of 25)
#     Line #1707 (got 26 columns instead of 25)
#     Line #1709 (got 26 columns instead of 25)
#     Line #1710 (got 26 columns instead of 25)
#     Line #1712 (got 26 columns instead of 25)
#     Line #1715 (got 26 columns instead of 25)
#     Line #1717 (got 26 columns instead of 25)
#     Line #1718 (got 26 columns instead of 25)
#     Line #1719 (got 27 columns instead of 25)
#     Line #1721 (got 26 columns instead of 25)
#     Line #1722 (got 26 columns instead of 25)
#     Line #1723 (got 27 columns instead of 25)
#     Line #1724 (got 26 columns instead of 25)
#     Line #1725 (got 27 columns instead of 25)
#     Line #1730 (got 26 columns instead of 25)
#     Line #1740 (got 26 columns instead of 25)
#     Line #1742 (got 26 columns instead of 25)
#     Line #1743 (got 26 columns instead of 25)
#     Line #1744 (got 26 columns instead of 25)
#     Line #1745 (got 26 columns instead of 25)
#     Line #1750 (got 26 columns instead of 25)
#     Line #1753 (got 26 columns instead of 25)
#     Line #1754 (got 16 columns instead of 25)
#     Line #1755 (got 26 columns instead of 25)
#     Line #1758 (got 26 columns instead of 25)
#     Line #1760 (got 27 columns instead of 25)
#     Line #1761 (got 26 columns instead of 25)
#     Line #1762 (got 26 columns instead of 25)
#     Line #1765 (got 26 columns instead of 25)
#     Line #1766 (got 26 columns instead of 25)
#     Line #1767 (got 26 columns instead of 25)
#     Line #1768 (got 26 columns instead of 25)
#     Line #1771 (got 26 columns instead of 25)
#     Line #1772 (got 26 columns instead of 25)
#     Line #1774 (got 26 columns instead of 25)
#     Line #1780 (got 26 columns instead of 25)
#     Line #1781 (got 27 columns instead of 25)
#     Line #1782 (got 26 columns instead of 25)
#     Line #1784 (got 26 columns instead of 25)
#     Line #1786 (got 26 columns instead of 25)
#     Line #1787 (got 26 columns instead of 25)
#     Line #1788 (got 26 columns instead of 25)
#     Line #1791 (got 26 columns instead of 25)
#     Line #1793 (got 26 columns instead of 25)
#     Line #1795 (got 26 columns instead of 25)
#     Line #1798 (got 26 columns instead of 25)
#     Line #1800 (got 26 columns instead of 25)
#     Line #1802 (got 26 columns instead of 25)
#     Line #1803 (got 26 columns instead of 25)
#     Line #1804 (got 26 columns instead of 25)
#     Line #1805 (got 26 columns instead of 25)
#     Line #1806 (got 26 columns instead of 25)
#     Line #1809 (got 26 columns instead of 25)
#     Line #1810 (got 27 columns instead of 25)
#     Line #1811 (got 26 columns instead of 25)
#     Line #1814 (got 26 columns instead of 25)
#     Line #1815 (got 26 columns instead of 25)
#     Line #1817 (got 26 columns instead of 25)
#     Line #1819 (got 26 columns instead of 25)
#     Line #1823 (got 26 columns instead of 25)
#     Line #1827 (got 26 columns instead of 25)
#     Line #1829 (got 26 columns instead of 25)
#     Line #1830 (got 27 columns instead of 25)
#     Line #1836 (got 26 columns instead of 25)
#     Line #1838 (got 26 columns instead of 25)
#     Line #1839 (got 26 columns instead of 25)
#     Line #1840 (got 26 columns instead of 25)
#     Line #1841 (got 26 columns instead of 25)
#     Line #1842 (got 26 columns instead of 25)
#     Line #1843 (got 26 columns instead of 25)
#     Line #1847 (got 26 columns instead of 25)
#     Line #1849 (got 26 columns instead of 25)
#     Line #1855 (got 26 columns instead of 25)
#     Line #1856 (got 27 columns instead of 25)
#     Line #1857 (got 26 columns instead of 25)
#     Line #1859 (got 26 columns instead of 25)
#     Line #1861 (got 26 columns instead of 25)
#     Line #1862 (got 26 columns instead of 25)
#     Line #1864 (got 26 columns instead of 25)
#     Line #1867 (got 26 columns instead of 25)
#     Line #1869 (got 26 columns instead of 25)
#     Line #1870 (got 16 columns instead of 25)
#     Line #1871 (got 26 columns instead of 25)
#     Line #1875 (got 26 columns instead of 25)
#     Line #1876 (got 26 columns instead of 25)
#     Line #1877 (got 26 columns instead of 25)
#     Line #1878 (got 26 columns instead of 25)
#     Line #1879 (got 26 columns instead of 25)
#     Line #1880 (got 26 columns instead of 25)
#     Line #1882 (got 26 columns instead of 25)
#     Line #1885 (got 26 columns instead of 25)
#     Line #1886 (got 26 columns instead of 25)
#     Line #1887 (got 26 columns instead of 25)
#     Line #1888 (got 26 columns instead of 25)
#     Line #1890 (got 26 columns instead of 25)
#     Line #1891 (got 26 columns instead of 25)
#     Line #1892 (got 26 columns instead of 25)
#     Line #1893 (got 26 columns instead of 25)
#     Line #1900 (got 26 columns instead of 25)
#     Line #1903 (got 26 columns instead of 25)
#     Line #1904 (got 16 columns instead of 25)
#     Line #1905 (got 26 columns instead of 25)
#     Line #1908 (got 26 columns instead of 25)
#     Line #1910 (got 27 columns instead of 25)
#     Line #1911 (got 26 columns instead of 25)
#     Line #1912 (got 26 columns instead of 25)
#     Line #1915 (got 26 columns instead of 25)
#     Line #1916 (got 26 columns instead of 25)
#     Line #1917 (got 26 columns instead of 25)
#     Line #1918 (got 26 columns instead of 25)
#     Line #1919 (got 26 columns instead of 25)
#     Line #1922 (got 26 columns instead of 25)
#     Line #1923 (got 26 columns instead of 25)
#     Line #1925 (got 26 columns instead of 25)
#     Line #1931 (got 26 columns instead of 25)
#     Line #1933 (got 26 columns instead of 25)
#     Line #1935 (got 26 columns instead of 25)
#     Line #1937 (got 27 columns instead of 25)
#     Line #1938 (got 26 columns instead of 25)
#     Line #1940 (got 26 columns instead of 25)
#     Line #1943 (got 26 columns instead of 25)
#     Line #1945 (got 26 columns instead of 25)
#     Line #1948 (got 26 columns instead of 25)
#     Line #1950 (got 26 columns instead of 25)
#     Line #1953 (got 26 columns instead of 25)
#     Line #1954 (got 26 columns instead of 25)
#     Line #1955 (got 26 columns instead of 25)
#     Line #1958 (got 26 columns instead of 25)
#     Line #1960 (got 26 columns instead of 25)
#     Line #1961 (got 26 columns instead of 25)
#     Line #1962 (got 26 columns instead of 25)
#     Line #1964 (got 26 columns instead of 25)
#     Line #1965 (got 26 columns instead of 25)
#     Line #1966 (got 26 columns instead of 25)
#     Line #1967 (got 26 columns instead of 25)
#     Line #1972 (got 16 columns instead of 25)
#     Line #1973 (got 26 columns instead of 25)
#     Line #1976 (got 26 columns instead of 25)
#     Line #1978 (got 26 columns instead of 25)
#     Line #1980 (got 26 columns instead of 25)
#     Line #1981 (got 26 columns instead of 25)
#     Line #1982 (got 26 columns instead of 25)
#     Line #1983 (got 26 columns instead of 25)
#     Line #1984 (got 26 columns instead of 25)
#     Line #1987 (got 26 columns instead of 25)
#     Line #1988 (got 27 columns instead of 25)
#     Line #1989 (got 26 columns instead of 25)
#     Line #1992 (got 26 columns instead of 25)
#     Line #1993 (got 26 columns instead of 25)
#     Line #1994 (got 26 columns instead of 25)
#     Line #1995 (got 26 columns instead of 25)
#     Line #1997 (got 26 columns instead of 25)
#     Line #2003 (got 26 columns instead of 25)
#     Line #2006 (got 16 columns instead of 25)
#     Line #2007 (got 27 columns instead of 25)
#     Line #2009 (got 26 columns instead of 25)
#     Line #2011 (got 26 columns instead of 25)
#     Line #2012 (got 26 columns instead of 25)
#     Line #2013 (got 27 columns instead of 25)
#     Line #2014 (got 26 columns instead of 25)
#     Line #2018 (got 26 columns instead of 25)
#     Line #2019 (got 26 columns instead of 25)
#     Line #2020 (got 26 columns instead of 25)
#     Line #2021 (got 26 columns instead of 25)
#     Line #2022 (got 26 columns instead of 25)
#     Line #2027 (got 26 columns instead of 25)
#     Line #2033 (got 26 columns instead of 25)
#     Line #2035 (got 27 columns instead of 25)
#     Line #2036 (got 27 columns instead of 25)
#     Line #2040 (got 27 columns instead of 25)
#     Line #2042 (got 26 columns instead of 25)
#     Line #2045 (got 26 columns instead of 25)
#     Line #2046 (got 26 columns instead of 25)
#     Line #2047 (got 26 columns instead of 25)
#     Line #2048 (got 26 columns instead of 25)
#     Line #2051 (got 26 columns instead of 25)
#     Line #2052 (got 26 columns instead of 25)
#     Line #2053 (got 27 columns instead of 25)
#     Line #2055 (got 27 columns instead of 25)
#     Line #2058 (got 26 columns instead of 25)
#     Line #2059 (got 26 columns instead of 25)
#     Line #2060 (got 26 columns instead of 25)
#     Line #2067 (got 27 columns instead of 25)
#     Line #2071 (got 26 columns instead of 25)
#     Line #2072 (got 26 columns instead of 25)
#     Line #2073 (got 26 columns instead of 25)
#     Line #2076 (got 27 columns instead of 25)
#     Line #2077 (got 26 columns instead of 25)
#     Line #2081 (got 26 columns instead of 25)
#     Line #2082 (got 26 columns instead of 25)
#     Line #2086 (got 26 columns instead of 25)
#     Line #2091 (got 26 columns instead of 25)
#     Line #2095 (got 27 columns instead of 25)
#     Line #2096 (got 26 columns instead of 25)
#     Line #2101 (got 26 columns instead of 25)
#     Line #2102 (got 26 columns instead of 25)
#     Line #2105 (got 27 columns instead of 25)
#     Line #2106 (got 26 columns instead of 25)
#     Line #2107 (got 26 columns instead of 25)
#     Line #2110 (got 26 columns instead of 25)
#     Line #2111 (got 27 columns instead of 25)
#     Line #2112 (got 26 columns instead of 25)
#     Line #2116 (got 26 columns instead of 25)
#     Line #2118 (got 26 columns instead of 25)
#     Line #2119 (got 26 columns instead of 25)
#     Line #2120 (got 26 columns instead of 25)
#     Line #2124 (got 16 columns instead of 25)
#     Line #2125 (got 26 columns instead of 25)
#     Line #2129 (got 26 columns instead of 25)
#     Line #2130 (got 26 columns instead of 25)
#     Line #2131 (got 26 columns instead of 25)
#     Line #2132 (got 26 columns instead of 25)
#     Line #2133 (got 26 columns instead of 25)
#     Line #2135 (got 26 columns instead of 25)
#     Line #2138 (got 26 columns instead of 25)
#     Line #2139 (got 26 columns instead of 25)
#     Line #2140 (got 26 columns instead of 25)
#     Line #2144 (got 26 columns instead of 25)
#     Line #2145 (got 26 columns instead of 25)
#     Line #2146 (got 26 columns instead of 25)
#     Line #2149 (got 27 columns instead of 25)
#     Line #2150 (got 27 columns instead of 25)
#     Line #2152 (got 26 columns instead of 25)
#     Line #2154 (got 26 columns instead of 25)
#     Line #2155 (got 27 columns instead of 25)
#     Line #2156 (got 27 columns instead of 25)
#     Line #2162 (got 26 columns instead of 25)
#     Line #2169 (got 27 columns instead of 25)
#     Line #2170 (got 26 columns instead of 25)
#     Line #2174 (got 26 columns instead of 25)
#     Line #2176 (got 26 columns instead of 25)
#     Line #2177 (got 26 columns instead of 25)
#     Line #2180 (got 26 columns instead of 25)
#     Line #2181 (got 27 columns instead of 25)
#     Line #2182 (got 26 columns instead of 25)
#     Line #2183 (got 26 columns instead of 25)
#     Line #2186 (got 26 columns instead of 25)
#     Line #2188 (got 26 columns instead of 25)
#     Line #2192 (got 26 columns instead of 25)
#     Line #2194 (got 26 columns instead of 25)
#     Line #2195 (got 26 columns instead of 25)
#     Line #2196 (got 27 columns instead of 25)
#     Line #2199 (got 16 columns instead of 25)
#     Line #2200 (got 26 columns instead of 25)
#     Line #2204 (got 26 columns instead of 25)
#     Line #2205 (got 26 columns instead of 25)
#     Line #2206 (got 26 columns instead of 25)
#     Line #2207 (got 26 columns instead of 25)
#     Line #2208 (got 26 columns instead of 25)
#     Line #2210 (got 26 columns instead of 25)
#     Line #2214 (got 26 columns instead of 25)
#     Line #2215 (got 26 columns instead of 25)
#     Line #2219 (got 26 columns instead of 25)
#     Line #2220 (got 26 columns instead of 25)
#     Line #2221 (got 26 columns instead of 25)
#     Line #2223 (got 26 columns instead of 25)
#     Line #2224 (got 26 columns instead of 25)
#     Line #2225 (got 27 columns instead of 25)
#     Line #2227 (got 26 columns instead of 25)
#     Line #2228 (got 26 columns instead of 25)
#     Line #2229 (got 27 columns instead of 25)
#     Line #2230 (got 26 columns instead of 25)
#     Line #2231 (got 27 columns instead of 25)
#     Line #2236 (got 26 columns instead of 25)
#     Line #2248 (got 26 columns instead of 25)
#     Line #2249 (got 26 columns instead of 25)
#     Line #2250 (got 26 columns instead of 25)
#     Line #2251 (got 26 columns instead of 25)
#     Line #2252 (got 26 columns instead of 25)
#     Line #2253 (got 26 columns instead of 25)
#     Line #2256 (got 26 columns instead of 25)
#     Line #2257 (got 27 columns instead of 25)
#     Line #2259 (got 27 columns instead of 25)
#     Line #2262 (got 26 columns instead of 25)
#     Line #2263 (got 26 columns instead of 25)
#     Line #2264 (got 26 columns instead of 25)
#     Line #2268 (got 26 columns instead of 25)
#     Line #2271 (got 27 columns instead of 25)
#     Line #2272 (got 26 columns instead of 25)
#     Line #2275 (got 26 columns instead of 25)
#     Line #2276 (got 26 columns instead of 25)
#     Line #2280 (got 27 columns instead of 25)
#     Line #2282 (got 27 columns instead of 25)
#     Line #2284 (got 26 columns instead of 25)
#     Line #2285 (got 26 columns instead of 25)
#     Line #2286 (got 27 columns instead of 25)
#     Line #2291 (got 26 columns instead of 25)
#     Line #2292 (got 26 columns instead of 25)
#     Line #2295 (got 26 columns instead of 25)
#     Line #2299 (got 27 columns instead of 25)
#     Line #2300 (got 26 columns instead of 25)
#     Line #2301 (got 26 columns instead of 25)
#     Line #2304 (got 26 columns instead of 25)
#     Line #2306 (got 26 columns instead of 25)
#     Line #2307 (got 26 columns instead of 25)
#     Line #2308 (got 26 columns instead of 25)
#     Line #2310 (got 27 columns instead of 25)
#     Line #2311 (got 26 columns instead of 25)
#     Line #2312 (got 26 columns instead of 25)
#     Line #2314 (got 26 columns instead of 25)
#     Line #2315 (got 26 columns instead of 25)
#     Line #2316 (got 27 columns instead of 25)
#     Line #2317 (got 26 columns instead of 25)
#     Line #2321 (got 26 columns instead of 25)
#     Line #2323 (got 26 columns instead of 25)
#     Line #2324 (got 26 columns instead of 25)
#     Line #2329 (got 16 columns instead of 25)
#     Line #2334 (got 26 columns instead of 25)
#     Line #2335 (got 26 columns instead of 25)
#     Line #2336 (got 26 columns instead of 25)
#     Line #2337 (got 26 columns instead of 25)
#     Line #2338 (got 26 columns instead of 25)
#     Line #2340 (got 26 columns instead of 25)
#     Line #2344 (got 26 columns instead of 25)
#     Line #2349 (got 26 columns instead of 25)
#     Line #2351 (got 26 columns instead of 25)
#     Line #2353 (got 26 columns instead of 25)
#     Line #2355 (got 26 columns instead of 25)
#     Line #2356 (got 26 columns instead of 25)
#     Line #2358 (got 26 columns instead of 25)
#     Line #2361 (got 27 columns instead of 25)
#     Line #2362 (got 26 columns instead of 25)
#     Line #2363 (got 26 columns instead of 25)
#     Line #2365 (got 26 columns instead of 25)
#     Line #2366 (got 26 columns instead of 25)
#     Line #2367 (got 27 columns instead of 25)
#     Line #2368 (got 26 columns instead of 25)
#     Line #2372 (got 26 columns instead of 25)
#     Line #2374 (got 26 columns instead of 25)
#     Line #2375 (got 26 columns instead of 25)
#     Line #2380 (got 26 columns instead of 25)
#     Line #2383 (got 26 columns instead of 25)
#     Line #2384 (got 26 columns instead of 25)
#     Line #2385 (got 27 columns instead of 25)
#     Line #2387 (got 27 columns instead of 25)
#     Line #2390 (got 26 columns instead of 25)
#     Line #2391 (got 26 columns instead of 25)
#     Line #2392 (got 26 columns instead of 25)
#     Line #2400 (got 27 columns instead of 25)
#     Line #2401 (got 26 columns instead of 25)
#     Line #2404 (got 26 columns instead of 25)
#     Line #2406 (got 26 columns instead of 25)
#     Line #2407 (got 26 columns instead of 25)
#     Line #2408 (got 26 columns instead of 25)
#     Line #2409 (got 27 columns instead of 25)
#     Line #2412 (got 26 columns instead of 25)
#     Line #2413 (got 27 columns instead of 25)
#     Line #2417 (got 27 columns instead of 25)
#     Line #2418 (got 26 columns instead of 25)
#     Line #2419 (got 26 columns instead of 25)
#     Line #2420 (got 26 columns instead of 25)
#     Line #2424 (got 26 columns instead of 25)
#     Line #2428 (got 26 columns instead of 25)
#     Line #2430 (got 26 columns instead of 25)
#     Line #2431 (got 26 columns instead of 25)
#     Line #2434 (got 16 columns instead of 25)
#     Line #2439 (got 26 columns instead of 25)
#     Line #2440 (got 26 columns instead of 25)
#     Line #2441 (got 26 columns instead of 25)
#     Line #2442 (got 26 columns instead of 25)
#     Line #2443 (got 26 columns instead of 25)
#     Line #2445 (got 26 columns instead of 25)
#     Line #2449 (got 26 columns instead of 25)
#     Line #2456 (got 26 columns instead of 25)
#     Line #2458 (got 26 columns instead of 25)
#     Line #2461 (got 26 columns instead of 25)
#     Line #2463 (got 26 columns instead of 25)
#     Line #2465 (got 26 columns instead of 25)
#     Line #2467 (got 26 columns instead of 25)
#     Line #2468 (got 27 columns instead of 25)
#     Line #2474 (got 26 columns instead of 25)
#     Line #2476 (got 26 columns instead of 25)
#     Line #2477 (got 26 columns instead of 25)
#     Line #2478 (got 26 columns instead of 25)
#     Line #2479 (got 26 columns instead of 25)
#     Line #2480 (got 26 columns instead of 25)
#     Line #2481 (got 26 columns instead of 25)
#     Line #2486 (got 26 columns instead of 25)
#     Line #2487 (got 26 columns instead of 25)
#     Line #2489 (got 26 columns instead of 25)
#     Line #2492 (got 27 columns instead of 25)
#     Line #2493 (got 26 columns instead of 25)
#     Line #2494 (got 26 columns instead of 25)
#     Line #2496 (got 26 columns instead of 25)
#     Line #2497 (got 26 columns instead of 25)
#     Line #2498 (got 27 columns instead of 25)
#     Line #2499 (got 26 columns instead of 25)
#     Line #2503 (got 26 columns instead of 25)
#     Line #2505 (got 26 columns instead of 25)
#     Line #2506 (got 26 columns instead of 25)
#     Line #2512 (got 27 columns instead of 25)
#     Line #2513 (got 26 columns instead of 25)
#     Line #2515 (got 26 columns instead of 25)
#     Line #2517 (got 26 columns instead of 25)
#     Line #2520 (got 27 columns instead of 25)
#     Line #2527 (got 26 columns instead of 25)
#     Line #2531 (got 26 columns instead of 25)
#     Line #2532 (got 26 columns instead of 25)
#     Line #2540 (got 26 columns instead of 25)
#     Line #2543 (got 26 columns instead of 25)
#     Line #2544 (got 26 columns instead of 25)
#     Line #2545 (got 26 columns instead of 25)
#     Line #2548 (got 26 columns instead of 25)
#     Line #2550 (got 26 columns instead of 25)
#     Line #2551 (got 26 columns instead of 25)
#     Line #2552 (got 26 columns instead of 25)
#     Line #2555 (got 26 columns instead of 25)
#     Line #2557 (got 26 columns instead of 25)
#     Line #2558 (got 26 columns instead of 25)
#     Line #2559 (got 26 columns instead of 25)
#     Line #2562 (got 26 columns instead of 25)
#     Line #2564 (got 26 columns instead of 25)
#     Line #2567 (got 26 columns instead of 25)
#     Line #2570 (got 16 columns instead of 25)
#     Line #2571 (got 27 columns instead of 25)
#     Line #2573 (got 26 columns instead of 25)
#     Line #2575 (got 26 columns instead of 25)
#     Line #2576 (got 26 columns instead of 25)
#     Line #2577 (got 27 columns instead of 25)
#     Line #2578 (got 26 columns instead of 25)
#     Line #2582 (got 26 columns instead of 25)
#     Line #2584 (got 26 columns instead of 25)
#     Line #2585 (got 26 columns instead of 25)
#     Line #2586 (got 26 columns instead of 25)
#     Line #2592 (got 26 columns instead of 25)
#     Line #2596 (got 26 columns instead of 25)
#     Line #2598 (got 26 columns instead of 25)
#     Line #2599 (got 27 columns instead of 25)
#     Line #2605 (got 26 columns instead of 25)
#     Line #2607 (got 26 columns instead of 25)
#     Line #2610 (got 26 columns instead of 25)
#     Line #2611 (got 26 columns instead of 25)
#     Line #2612 (got 26 columns instead of 25)
#     Line #2613 (got 26 columns instead of 25)
#     Line #2617 (got 27 columns instead of 25)
#     Line #2618 (got 27 columns instead of 25)
#     Line #2620 (got 27 columns instead of 25)
#     Line #2622 (got 26 columns instead of 25)
#     Line #2623 (got 26 columns instead of 25)
#     Line #2624 (got 27 columns instead of 25)
#     Line #2629 (got 26 columns instead of 25)
#     Line #2630 (got 26 columns instead of 25)
#     Line #2633 (got 26 columns instead of 25)
#     Line #2636 (got 27 columns instead of 25)
#     Line #2637 (got 27 columns instead of 25)
#     Line #2638 (got 26 columns instead of 25)
#     Line #2642 (got 26 columns instead of 25)
#     Line #2644 (got 26 columns instead of 25)
#     Line #2645 (got 26 columns instead of 25)
#     Line #2648 (got 26 columns instead of 25)
#     Line #2649 (got 27 columns instead of 25)
#     Line #2650 (got 26 columns instead of 25)
#     Line #2651 (got 26 columns instead of 25)
#     Line #2654 (got 26 columns instead of 25)
#     Line #2656 (got 26 columns instead of 25)
#     Line #2660 (got 26 columns instead of 25)
#     Line #2662 (got 26 columns instead of 25)
#     Line #2663 (got 26 columns instead of 25)
#     Line #2669 (got 26 columns instead of 25)
#     Line #2671 (got 26 columns instead of 25)
#     Line #2674 (got 27 columns instead of 25)
#     Line #2675 (got 26 columns instead of 25)
#     Line #2676 (got 26 columns instead of 25)
#     Line #2678 (got 26 columns instead of 25)
#     Line #2679 (got 26 columns instead of 25)
#     Line #2680 (got 27 columns instead of 25)
#     Line #2681 (got 26 columns instead of 25)
#     Line #2687 (got 26 columns instead of 25)
#     Line #2688 (got 26 columns instead of 25)
#     Line #2689 (got 26 columns instead of 25)
#     Line #2694 (got 26 columns instead of 25)
#     Line #2695 (got 26 columns instead of 25)
#     Line #2697 (got 26 columns instead of 25)
#     Line #2699 (got 26 columns instead of 25)
#     Line #2701 (got 26 columns instead of 25)
#     Line #2702 (got 27 columns instead of 25)
#     Line #2708 (got 26 columns instead of 25)
#     Line #2710 (got 26 columns instead of 25)
#     Line #2711 (got 26 columns instead of 25)
#     Line #2714 (got 26 columns instead of 25)
#     Line #2715 (got 26 columns instead of 25)
#     Line #2716 (got 26 columns instead of 25)
#     Line #2720 (got 27 columns instead of 25)
#     Line #2721 (got 26 columns instead of 25)
#     Line #2723 (got 26 columns instead of 25)
#     Line #2725 (got 26 columns instead of 25)
#     Line #2727 (got 26 columns instead of 25)
#     Line #2728 (got 27 columns instead of 25)
#     Line #2734 (got 26 columns instead of 25)
#     Line #2736 (got 26 columns instead of 25)
#     Line #2737 (got 26 columns instead of 25)
#     Line #2740 (got 26 columns instead of 25)
#     Line #2741 (got 26 columns instead of 25)
#     Line #2742 (got 26 columns instead of 25)
#     Line #2749 (got 26 columns instead of 25)
#     Line #2752 (got 16 columns instead of 25)
#     Line #2753 (got 27 columns instead of 25)
#     Line #2755 (got 26 columns instead of 25)
#     Line #2757 (got 26 columns instead of 25)
#     Line #2758 (got 26 columns instead of 25)
#     Line #2759 (got 27 columns instead of 25)
#     Line #2760 (got 26 columns instead of 25)
#     Line #2764 (got 26 columns instead of 25)
#     Line #2766 (got 26 columns instead of 25)
#     Line #2767 (got 26 columns instead of 25)
#     Line #2768 (got 26 columns instead of 25)
#     Line #2776 (got 26 columns instead of 25)
#     Line #2779 (got 26 columns instead of 25)
#     Line #2780 (got 26 columns instead of 25)
#     Line #2781 (got 26 columns instead of 25)
#     Line #2784 (got 26 columns instead of 25)
#     Line #2786 (got 26 columns instead of 25)
#     Line #2787 (got 26 columns instead of 25)
#     Line #2788 (got 26 columns instead of 25)
#     Line #2791 (got 26 columns instead of 25)
#     Line #2793 (got 26 columns instead of 25)
#     Line #2794 (got 26 columns instead of 25)
#     Line #2795 (got 26 columns instead of 25)
#     Line #2798 (got 26 columns instead of 25)
#     Line #2800 (got 27 columns instead of 25)
#     Line #2801 (got 26 columns instead of 25)
#     Line #2803 (got 26 columns instead of 25)
#     Line #2805 (got 26 columns instead of 25)
#     Line #2807 (got 26 columns instead of 25)
#     Line #2808 (got 27 columns instead of 25)
#     Line #2814 (got 26 columns instead of 25)
#     Line #2816 (got 26 columns instead of 25)
#     Line #2817 (got 26 columns instead of 25)
#     Line #2820 (got 26 columns instead of 25)
#     Line #2821 (got 26 columns instead of 25)
#     Line #2822 (got 26 columns instead of 25)
#   data = np.genfromtxt(
# np.int64(21456)

# %%
# @title
import numpy as np

data = np.genfromtxt(
    "/sales_data.csv",
    delimiter=",",
    names=True,              # uses header names
    dtype=None,              # auto-detect types (important)
    encoding="latin1",
    invalid_raise=False
)
columns_needed = [
    'ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
    'SALES', 'ORDERDATE', 'STATUS', 'MONTH_ID', 'YEAR_ID',
    'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME',
    'COUNTRY', 'DEALSIZE'
]

filtered_data = data[columns_needed]
print("\t".join(columns_needed))

for row in filtered_data[:10]:
  print("\t".join(str(row[col]) for col in columns_needed))
  # Extract SALES column
sales = filtered_data['SALES']

# Remove missing values (important)
sales = sales[~np.isnan(sales)]

# Total sales
total_sales = np.sum(sales)

print("\nTotal Sales:", total_sales)
# Out:
# ORDERNUMBER	QUANTITYORDERED	PRICEEACH	ORDERLINENUMBER	SALES	ORDERDATE	STATUS	MONTH_ID	YEAR_ID	PRODUCTLINE	MSRP	PRODUCTCODE	CUSTOMERNAME	COUNTRY	DEALSIZE
# 10107	30	95.7	2	2871.0	2/24/2003 0:00	Shipped	2	2003	Motorcycles	95	S10_1678	Land of Toys Inc.	USA	Small
# 10121	34	81.35	5	2765.9	05-07-2003 00:00	Shipped	5	2003	Motorcycles	95	S10_1678	Reims Collectables	France	Small
# 10134	41	94.74	2	3884.34	07-01-2003 00:00	Shipped	7	2003	Motorcycles	95	S10_1678	Lyon Souveniers	France	Medium
# 10145	45	83.26	6	3746.7	8/25/2003 0:00	Shipped	8	2003	Motorcycles	95	S10_1678	Toys4GrownUps.com	USA	Medium
# 10159	49	100.0	14	5205.27	10-10-2003 00:00	Shipped	10	2003	Motorcycles	95	S10_1678	Corporate Gift Ideas Co.	USA	Medium
# 10168	36	96.66	1	3479.76	10/28/2003 0:00	Shipped	10	2003	Motorcycles	95	S10_1678	Technics Stores Inc.	USA	Medium
# 10201	22	98.57	2	2168.54	12-01-2003 00:00	Shipped	12	2003	Motorcycles	95	S10_1678	Mini Wheels Co.	USA	Small
# 10237	23	100.0	7	2333.12	04-05-2004 00:00	Shipped	4	2004	Motorcycles	95	S10_1678	Vitachrome Inc.	USA	Small
# 10251	28	100.0	2	3188.64	5/18/2004 0:00	Shipped	5	2004	Motorcycles	95	S10_1678	Tekni Collectables Inc.	USA	Medium
# 10263	34	100.0	2	3676.76	6/28/2004 0:00	Shipped	6	2004	Motorcycles	95	S10_1678	Gift Depot Inc.	USA	Medium
#
# Total Sales: 5287917.43
# /tmp/ipython-input-1097837271.py:4: ConversionWarning: Some errors were detected !
#     Line #8 (got 26 columns instead of 25)
#     Line #9 (got 26 columns instead of 25)
#     Line #11 (got 26 columns instead of 25)
#     Line #12 (got 26 columns instead of 25)
#     Line #16 (got 26 columns instead of 25)
#     Line #18 (got 26 columns instead of 25)
#     Line #23 (got 26 columns instead of 25)
#     Line #24 (got 26 columns instead of 25)
#     Line #26 (got 26 columns instead of 25)
#     Line #27 (got 26 columns instead of 25)
#     Line #29 (got 26 columns instead of 25)
#     Line #30 (got 27 columns instead of 25)
#     Line #32 (got 27 columns instead of 25)
#     Line #34 (got 26 columns instead of 25)
#     Line #35 (got 26 columns instead of 25)
#     Line #36 (got 27 columns instead of 25)
#     Line #41 (got 26 columns instead of 25)
#     Line #42 (got 26 columns instead of 25)
#     Line #45 (got 26 columns instead of 25)
#     Line #49 (got 26 columns instead of 25)
#     Line #53 (got 26 columns instead of 25)
#     Line #55 (got 26 columns instead of 25)
#     Line #57 (got 26 columns instead of 25)
#     Line #62 (got 26 columns instead of 25)
#     Line #63 (got 26 columns instead of 25)
#     Line #65 (got 27 columns instead of 25)
#     Line #66 (got 26 columns instead of 25)
#     Line #70 (got 26 columns instead of 25)
#     Line #72 (got 26 columns instead of 25)
#     Line #76 (got 26 columns instead of 25)
#     Line #77 (got 26 columns instead of 25)
#     Line #78 (got 26 columns instead of 25)
#     Line #80 (got 26 columns instead of 25)
#     Line #81 (got 26 columns instead of 25)
#     Line #83 (got 26 columns instead of 25)
#     Line #88 (got 26 columns instead of 25)
#     Line #89 (got 26 columns instead of 25)
#     Line #91 (got 27 columns instead of 25)
#     Line #92 (got 26 columns instead of 25)
#     Line #96 (got 26 columns instead of 25)
#     Line #98 (got 26 columns instead of 25)
#     Line #102 (got 26 columns instead of 25)
#     Line #104 (got 26 columns instead of 25)
#     Line #106 (got 26 columns instead of 25)
#     Line #107 (got 26 columns instead of 25)
#     Line #110 (got 26 columns instead of 25)
#     Line #112 (got 26 columns instead of 25)
#     Line #115 (got 26 columns instead of 25)
#     Line #116 (got 26 columns instead of 25)
#     Line #117 (got 26 columns instead of 25)
#     Line #122 (got 26 columns instead of 25)
#     Line #124 (got 26 columns instead of 25)
#     Line #128 (got 26 columns instead of 25)
#     Line #130 (got 26 columns instead of 25)
#     Line #136 (got 27 columns instead of 25)
#     Line #137 (got 27 columns instead of 25)
#     Line #139 (got 27 columns instead of 25)
#     Line #141 (got 26 columns instead of 25)
#     Line #142 (got 26 columns instead of 25)
#     Line #143 (got 27 columns instead of 25)
#     Line #149 (got 26 columns instead of 25)
#     Line #155 (got 26 columns instead of 25)
#     Line #156 (got 26 columns instead of 25)
#     Line #158 (got 26 columns instead of 25)
#     Line #160 (got 26 columns instead of 25)
#     Line #162 (got 26 columns instead of 25)
#     Line #163 (got 16 columns instead of 25)
#     Line #164 (got 26 columns instead of 25)
#     Line #168 (got 26 columns instead of 25)
#     Line #169 (got 26 columns instead of 25)
#     Line #170 (got 26 columns instead of 25)
#     Line #171 (got 26 columns instead of 25)
#     Line #172 (got 26 columns instead of 25)
#     Line #173 (got 26 columns instead of 25)
#     Line #175 (got 26 columns instead of 25)
#     Line #178 (got 26 columns instead of 25)
#     Line #179 (got 26 columns instead of 25)
#     Line #180 (got 26 columns instead of 25)
#     Line #181 (got 26 columns instead of 25)
#     Line #184 (got 26 columns instead of 25)
#     Line #185 (got 26 columns instead of 25)
#     Line #189 (got 27 columns instead of 25)
#     Line #192 (got 26 columns instead of 25)
#     Line #193 (got 27 columns instead of 25)
#     Line #197 (got 27 columns instead of 25)
#     Line #198 (got 26 columns instead of 25)
#     Line #199 (got 26 columns instead of 25)
#     Line #200 (got 26 columns instead of 25)
#     Line #204 (got 26 columns instead of 25)
#     Line #207 (got 27 columns instead of 25)
#     Line #208 (got 27 columns instead of 25)
#     Line #216 (got 27 columns instead of 25)
#     Line #218 (got 27 columns instead of 25)
#     Line #220 (got 26 columns instead of 25)
#     Line #221 (got 26 columns instead of 25)
#     Line #222 (got 27 columns instead of 25)
#     Line #224 (got 26 columns instead of 25)
#     Line #227 (got 26 columns instead of 25)
#     Line #228 (got 26 columns instead of 25)
#     Line #231 (got 26 columns instead of 25)
#     Line #235 (got 26 columns instead of 25)
#     Line #237 (got 26 columns instead of 25)
#     Line #239 (got 26 columns instead of 25)
#     Line #241 (got 26 columns instead of 25)
#     Line #247 (got 26 columns instead of 25)
#     Line #248 (got 26 columns instead of 25)
#     Line #251 (got 26 columns instead of 25)
#     Line #252 (got 26 columns instead of 25)
#     Line #258 (got 26 columns instead of 25)
#     Line #264 (got 26 columns instead of 25)
#     Line #266 (got 26 columns instead of 25)
#     Line #267 (got 26 columns instead of 25)
#     Line #268 (got 26 columns instead of 25)
#     Line #269 (got 27 columns instead of 25)
#     Line #272 (got 26 columns instead of 25)
#     Line #273 (got 27 columns instead of 25)
#     Line #277 (got 27 columns instead of 25)
#     Line #278 (got 26 columns instead of 25)
#     Line #279 (got 26 columns instead of 25)
#     Line #280 (got 26 columns instead of 25)
#     Line #284 (got 26 columns instead of 25)
#     Line #287 (got 27 columns instead of 25)
#     Line #288 (got 27 columns instead of 25)
#     Line #289 (got 26 columns instead of 25)
#     Line #290 (got 26 columns instead of 25)
#     Line #293 (got 16 columns instead of 25)
#     Line #294 (got 26 columns instead of 25)
#     Line #297 (got 26 columns instead of 25)
#     Line #299 (got 26 columns instead of 25)
#     Line #300 (got 26 columns instead of 25)
#     Line #301 (got 26 columns instead of 25)
#     Line #302 (got 26 columns instead of 25)
#     Line #303 (got 26 columns instead of 25)
#     Line #305 (got 26 columns instead of 25)
#     Line #308 (got 26 columns instead of 25)
#     Line #309 (got 26 columns instead of 25)
#     Line #310 (got 26 columns instead of 25)
#     Line #311 (got 26 columns instead of 25)
#     Line #314 (got 26 columns instead of 25)
#     Line #319 (got 27 columns instead of 25)
#     Line #322 (got 26 columns instead of 25)
#     Line #323 (got 27 columns instead of 25)
#     Line #327 (got 27 columns instead of 25)
#     Line #328 (got 26 columns instead of 25)
#     Line #329 (got 26 columns instead of 25)
#     Line #330 (got 26 columns instead of 25)
#     Line #334 (got 26 columns instead of 25)
#     Line #337 (got 27 columns instead of 25)
#     Line #340 (got 26 columns instead of 25)
#     Line #344 (got 16 columns instead of 25)
#     Line #345 (got 26 columns instead of 25)
#     Line #349 (got 26 columns instead of 25)
#     Line #350 (got 26 columns instead of 25)
#     Line #351 (got 26 columns instead of 25)
#     Line #352 (got 26 columns instead of 25)
#     Line #353 (got 26 columns instead of 25)
#     Line #354 (got 26 columns instead of 25)
#     Line #356 (got 26 columns instead of 25)
#     Line #359 (got 26 columns instead of 25)
#     Line #360 (got 26 columns instead of 25)
#     Line #361 (got 26 columns instead of 25)
#     Line #362 (got 26 columns instead of 25)
#     Line #365 (got 26 columns instead of 25)
#     Line #366 (got 26 columns instead of 25)
#     Line #369 (got 26 columns instead of 25)
#     Line #372 (got 26 columns instead of 25)
#     Line #373 (got 26 columns instead of 25)
#     Line #374 (got 27 columns instead of 25)
#     Line #375 (got 26 columns instead of 25)
#     Line #376 (got 27 columns instead of 25)
#     Line #381 (got 26 columns instead of 25)
#     Line #389 (got 27 columns instead of 25)
#     Line #391 (got 26 columns instead of 25)
#     Line #394 (got 26 columns instead of 25)
#     Line #395 (got 26 columns instead of 25)
#     Line #396 (got 16 columns instead of 25)
#     Line #397 (got 26 columns instead of 25)
#     Line #400 (got 26 columns instead of 25)
#     Line #402 (got 26 columns instead of 25)
#     Line #404 (got 26 columns instead of 25)
#     Line #405 (got 26 columns instead of 25)
#     Line #406 (got 26 columns instead of 25)
#     Line #407 (got 26 columns instead of 25)
#     Line #408 (got 26 columns instead of 25)
#     Line #410 (got 27 columns instead of 25)
#     Line #411 (got 26 columns instead of 25)
#     Line #412 (got 26 columns instead of 25)
#     Line #413 (got 26 columns instead of 25)
#     Line #417 (got 26 columns instead of 25)
#     Line #418 (got 26 columns instead of 25)
#     Line #420 (got 26 columns instead of 25)
#     Line #424 (got 27 columns instead of 25)
#     Line #426 (got 27 columns instead of 25)
#     Line #428 (got 26 columns instead of 25)
#     Line #429 (got 26 columns instead of 25)
#     Line #430 (got 27 columns instead of 25)
#     Line #435 (got 26 columns instead of 25)
#     Line #436 (got 26 columns instead of 25)
#     Line #439 (got 26 columns instead of 25)
#     Line #443 (got 26 columns instead of 25)
#     Line #445 (got 26 columns instead of 25)
#     Line #447 (got 26 columns instead of 25)
#     Line #449 (got 26 columns instead of 25)
#     Line #451 (got 26 columns instead of 25)
#     Line #453 (got 26 columns instead of 25)
#     Line #456 (got 26 columns instead of 25)
#     Line #459 (got 26 columns instead of 25)
#     Line #460 (got 26 columns instead of 25)
#     Line #461 (got 27 columns instead of 25)
#     Line #462 (got 26 columns instead of 25)
#     Line #465 (got 26 columns instead of 25)
#     Line #466 (got 27 columns instead of 25)
#     Line #467 (got 26 columns instead of 25)
#     Line #470 (got 26 columns instead of 25)
#     Line #473 (got 26 columns instead of 25)
#     Line #479 (got 26 columns instead of 25)
#     Line #480 (got 26 columns instead of 25)
#     Line #485 (got 26 columns instead of 25)
#     Line #486 (got 26 columns instead of 25)
#     Line #488 (got 27 columns instead of 25)
#     Line #489 (got 26 columns instead of 25)
#     Line #492 (got 26 columns instead of 25)
#     Line #493 (got 26 columns instead of 25)
#     Line #496 (got 26 columns instead of 25)
#     Line #500 (got 26 columns instead of 25)
#     Line #501 (got 26 columns instead of 25)
#     Line #505 (got 27 columns instead of 25)
#     Line #506 (got 26 columns instead of 25)
#     Line #511 (got 26 columns instead of 25)
#     Line #512 (got 26 columns instead of 25)
#     Line #514 (got 27 columns instead of 25)
#     Line #515 (got 26 columns instead of 25)
#     Line #518 (got 26 columns instead of 25)
#     Line #519 (got 26 columns instead of 25)
#     Line #522 (got 26 columns instead of 25)
#     Line #523 (got 26 columns instead of 25)
#     Line #527 (got 26 columns instead of 25)
#     Line #529 (got 26 columns instead of 25)
#     Line #530 (got 26 columns instead of 25)
#     Line #532 (got 26 columns instead of 25)
#     Line #535 (got 26 columns instead of 25)
#     Line #538 (got 26 columns instead of 25)
#     Line #540 (got 26 columns instead of 25)
#     Line #541 (got 26 columns instead of 25)
#     Line #545 (got 27 columns instead of 25)
#     Line #546 (got 26 columns instead of 25)
#     Line #551 (got 26 columns instead of 25)
#     Line #558 (got 26 columns instead of 25)
#     Line #561 (got 26 columns instead of 25)
#     Line #562 (got 16 columns instead of 25)
#     Line #563 (got 27 columns instead of 25)
#     Line #566 (got 26 columns instead of 25)
#     Line #568 (got 27 columns instead of 25)
#     Line #569 (got 26 columns instead of 25)
#     Line #570 (got 26 columns instead of 25)
#     Line #573 (got 26 columns instead of 25)
#     Line #574 (got 26 columns instead of 25)
#     Line #575 (got 26 columns instead of 25)
#     Line #576 (got 26 columns instead of 25)
#     Line #581 (got 26 columns instead of 25)
#     Line #587 (got 26 columns instead of 25)
#     Line #589 (got 27 columns instead of 25)
#     Line #590 (got 27 columns instead of 25)
#     Line #591 (got 26 columns instead of 25)
#     Line #594 (got 26 columns instead of 25)
#     Line #597 (got 26 columns instead of 25)
#     Line #599 (got 26 columns instead of 25)
#     Line #601 (got 26 columns instead of 25)
#     Line #602 (got 16 columns instead of 25)
#     Line #603 (got 26 columns instead of 25)
#     Line #606 (got 26 columns instead of 25)
#     Line #608 (got 26 columns instead of 25)
#     Line #610 (got 26 columns instead of 25)
#     Line #611 (got 26 columns instead of 25)
#     Line #612 (got 26 columns instead of 25)
#     Line #613 (got 26 columns instead of 25)
#     Line #614 (got 26 columns instead of 25)
#     Line #617 (got 26 columns instead of 25)
#     Line #618 (got 26 columns instead of 25)
#     Line #619 (got 26 columns instead of 25)
#     Line #622 (got 26 columns instead of 25)
#     Line #623 (got 26 columns instead of 25)
#     Line #624 (got 26 columns instead of 25)
#     Line #626 (got 26 columns instead of 25)
#     Line #629 (got 26 columns instead of 25)
#     Line #631 (got 26 columns instead of 25)
#     Line #634 (got 26 columns instead of 25)
#     Line #637 (got 26 columns instead of 25)
#     Line #639 (got 27 columns instead of 25)
#     Line #640 (got 26 columns instead of 25)
#     Line #643 (got 26 columns instead of 25)
#     Line #644 (got 27 columns instead of 25)
#     Line #645 (got 26 columns instead of 25)
#     Line #648 (got 26 columns instead of 25)
#     Line #650 (got 26 columns instead of 25)
#     Line #651 (got 26 columns instead of 25)
#     Line #655 (got 26 columns instead of 25)
#     Line #658 (got 26 columns instead of 25)
#     Line #659 (got 26 columns instead of 25)
#     Line #660 (got 27 columns instead of 25)
#     Line #662 (got 27 columns instead of 25)
#     Line #666 (got 26 columns instead of 25)
#     Line #667 (got 26 columns instead of 25)
#     Line #675 (got 27 columns instead of 25)
#     Line #677 (got 26 columns instead of 25)
#     Line #680 (got 26 columns instead of 25)
#     Line #681 (got 26 columns instead of 25)
#     Line #683 (got 26 columns instead of 25)
#     Line #689 (got 26 columns instead of 25)
#     Line #691 (got 27 columns instead of 25)
#     Line #692 (got 27 columns instead of 25)
#     Line #693 (got 26 columns instead of 25)
#     Line #696 (got 27 columns instead of 25)
#     Line #698 (got 26 columns instead of 25)
#     Line #699 (got 26 columns instead of 25)
#     Line #701 (got 26 columns instead of 25)
#     Line #703 (got 26 columns instead of 25)
#     Line #704 (got 26 columns instead of 25)
#     Line #705 (got 27 columns instead of 25)
#     Line #707 (got 26 columns instead of 25)
#     Line #708 (got 26 columns instead of 25)
#     Line #709 (got 27 columns instead of 25)
#     Line #710 (got 26 columns instead of 25)
#     Line #711 (got 27 columns instead of 25)
#     Line #715 (got 26 columns instead of 25)
#     Line #723 (got 26 columns instead of 25)
#     Line #725 (got 26 columns instead of 25)
#     Line #726 (got 26 columns instead of 25)
#     Line #727 (got 26 columns instead of 25)
#     Line #728 (got 26 columns instead of 25)
#     Line #729 (got 26 columns instead of 25)
#     Line #730 (got 26 columns instead of 25)
#     Line #731 (got 26 columns instead of 25)
#     Line #737 (got 26 columns instead of 25)
#     Line #739 (got 27 columns instead of 25)
#     Line #740 (got 27 columns instead of 25)
#     Line #744 (got 26 columns instead of 25)
#     Line #747 (got 26 columns instead of 25)
#     Line #748 (got 26 columns instead of 25)
#     Line #751 (got 26 columns instead of 25)
#     Line #754 (got 26 columns instead of 25)
#     Line #756 (got 27 columns instead of 25)
#     Line #757 (got 27 columns instead of 25)
#     Line #759 (got 26 columns instead of 25)
#     Line #760 (got 27 columns instead of 25)
#     Line #761 (got 26 columns instead of 25)
#     Line #762 (got 27 columns instead of 25)
#     Line #763 (got 27 columns instead of 25)
#     Line #767 (got 26 columns instead of 25)
#     Line #775 (got 26 columns instead of 25)
#     Line #776 (got 26 columns instead of 25)
#     Line #778 (got 26 columns instead of 25)
#     Line #780 (got 26 columns instead of 25)
#     Line #781 (got 26 columns instead of 25)
#     Line #782 (got 26 columns instead of 25)
#     Line #784 (got 26 columns instead of 25)
#     Line #785 (got 26 columns instead of 25)
#     Line #788 (got 27 columns instead of 25)
#     Line #789 (got 26 columns instead of 25)
#     Line #790 (got 26 columns instead of 25)
#     Line #793 (got 26 columns instead of 25)
#     Line #794 (got 27 columns instead of 25)
#     Line #795 (got 26 columns instead of 25)
#     Line #799 (got 26 columns instead of 25)
#     Line #801 (got 26 columns instead of 25)
#     Line #802 (got 26 columns instead of 25)
#     Line #807 (got 26 columns instead of 25)
#     Line #812 (got 26 columns instead of 25)
#     Line #813 (got 26 columns instead of 25)
#     Line #815 (got 27 columns instead of 25)
#     Line #816 (got 26 columns instead of 25)
#     Line #820 (got 26 columns instead of 25)
#     Line #822 (got 26 columns instead of 25)
#     Line #826 (got 26 columns instead of 25)
#     Line #828 (got 26 columns instead of 25)
#     Line #830 (got 26 columns instead of 25)
#     Line #831 (got 26 columns instead of 25)
#     Line #832 (got 26 columns instead of 25)
#     Line #833 (got 26 columns instead of 25)
#     Line #834 (got 26 columns instead of 25)
#     Line #835 (got 26 columns instead of 25)
#     Line #840 (got 26 columns instead of 25)
#     Line #841 (got 26 columns instead of 25)
#     Line #842 (got 27 columns instead of 25)
#     Line #843 (got 27 columns instead of 25)
#     Line #844 (got 26 columns instead of 25)
#     Line #845 (got 26 columns instead of 25)
#     Line #847 (got 26 columns instead of 25)
#     Line #848 (got 26 columns instead of 25)
#     Line #851 (got 26 columns instead of 25)
#     Line #852 (got 26 columns instead of 25)
#     Line #855 (got 26 columns instead of 25)
#     Line #859 (got 26 columns instead of 25)
#     Line #861 (got 26 columns instead of 25)
#     Line #864 (got 26 columns instead of 25)
#     Line #867 (got 26 columns instead of 25)
#     Line #869 (got 26 columns instead of 25)
#     Line #870 (got 26 columns instead of 25)
#     Line #873 (got 26 columns instead of 25)
#     Line #874 (got 27 columns instead of 25)
#     Line #875 (got 26 columns instead of 25)
#     Line #879 (got 26 columns instead of 25)
#     Line #880 (got 26 columns instead of 25)
#     Line #884 (got 26 columns instead of 25)
#     Line #885 (got 27 columns instead of 25)
#     Line #886 (got 26 columns instead of 25)
#     Line #887 (got 27 columns instead of 25)
#     Line #889 (got 26 columns instead of 25)
#     Line #890 (got 26 columns instead of 25)
#     Line #891 (got 26 columns instead of 25)
#     Line #895 (got 26 columns instead of 25)
#     Line #897 (got 26 columns instead of 25)
#     Line #900 (got 26 columns instead of 25)
#     Line #904 (got 26 columns instead of 25)
#     Line #908 (got 26 columns instead of 25)
#     Line #912 (got 27 columns instead of 25)
#     Line #913 (got 26 columns instead of 25)
#     Line #914 (got 27 columns instead of 25)
#     Line #917 (got 26 columns instead of 25)
#     Line #918 (got 26 columns instead of 25)
#     Line #922 (got 26 columns instead of 25)
#     Line #927 (got 26 columns instead of 25)
#     Line #930 (got 26 columns instead of 25)
#     Line #931 (got 26 columns instead of 25)
#     Line #941 (got 26 columns instead of 25)
#     Line #944 (got 26 columns instead of 25)
#     Line #945 (got 26 columns instead of 25)
#     Line #946 (got 26 columns instead of 25)
#     Line #949 (got 26 columns instead of 25)
#     Line #951 (got 26 columns instead of 25)
#     Line #952 (got 26 columns instead of 25)
#     Line #953 (got 26 columns instead of 25)
#     Line #956 (got 26 columns instead of 25)
#     Line #957 (got 26 columns instead of 25)
#     Line #958 (got 26 columns instead of 25)
#     Line #959 (got 26 columns instead of 25)
#     Line #965 (got 27 columns instead of 25)
#     Line #966 (got 26 columns instead of 25)
#     Line #967 (got 27 columns instead of 25)
#     Line #970 (got 26 columns instead of 25)
#     Line #971 (got 26 columns instead of 25)
#     Line #975 (got 26 columns instead of 25)
#     Line #977 (got 26 columns instead of 25)
#     Line #980 (got 26 columns instead of 25)
#     Line #983 (got 26 columns instead of 25)
#     Line #984 (got 26 columns instead of 25)
#     Line #991 (got 27 columns instead of 25)
#     Line #992 (got 26 columns instead of 25)
#     Line #994 (got 26 columns instead of 25)
#     Line #996 (got 26 columns instead of 25)
#     Line #999 (got 27 columns instead of 25)
#     Line #1006 (got 26 columns instead of 25)
#     Line #1009 (got 27 columns instead of 25)
#     Line #1010 (got 26 columns instead of 25)
#     Line #1011 (got 26 columns instead of 25)
#     Line #1012 (got 26 columns instead of 25)
#     Line #1015 (got 26 columns instead of 25)
#     Line #1017 (got 27 columns instead of 25)
#     Line #1018 (got 26 columns instead of 25)
#     Line #1021 (got 26 columns instead of 25)
#     Line #1022 (got 26 columns instead of 25)
#     Line #1023 (got 26 columns instead of 25)
#     Line #1024 (got 26 columns instead of 25)
#     Line #1025 (got 27 columns instead of 25)
#     Line #1027 (got 26 columns instead of 25)
#     Line #1028 (got 26 columns instead of 25)
#     Line #1029 (got 27 columns instead of 25)
#     Line #1032 (got 26 columns instead of 25)
#     Line #1034 (got 26 columns instead of 25)
#     Line #1035 (got 26 columns instead of 25)
#     Line #1037 (got 26 columns instead of 25)
#     Line #1038 (got 26 columns instead of 25)
#     Line #1039 (got 26 columns instead of 25)
#     Line #1045 (got 26 columns instead of 25)
#     Line #1047 (got 27 columns instead of 25)
#     Line #1049 (got 26 columns instead of 25)
#     Line #1054 (got 26 columns instead of 25)
#     Line #1055 (got 26 columns instead of 25)
#     Line #1057 (got 26 columns instead of 25)
#     Line #1058 (got 26 columns instead of 25)
#     Line #1059 (got 26 columns instead of 25)
#     Line #1060 (got 26 columns instead of 25)
#     Line #1061 (got 26 columns instead of 25)
#     Line #1062 (got 26 columns instead of 25)
#     Line #1063 (got 26 columns instead of 25)
#     Line #1064 (got 26 columns instead of 25)
#     Line #1066 (got 26 columns instead of 25)
#     Line #1068 (got 27 columns instead of 25)
#     Line #1069 (got 26 columns instead of 25)
#     Line #1071 (got 26 columns instead of 25)
#     Line #1072 (got 27 columns instead of 25)
#     Line #1073 (got 26 columns instead of 25)
#     Line #1076 (got 27 columns instead of 25)
#     Line #1083 (got 26 columns instead of 25)
#     Line #1085 (got 26 columns instead of 25)
#     Line #1086 (got 27 columns instead of 25)
#     Line #1087 (got 26 columns instead of 25)
#     Line #1088 (got 26 columns instead of 25)
#     Line #1089 (got 26 columns instead of 25)
#     Line #1092 (got 16 columns instead of 25)
#     Line #1093 (got 26 columns instead of 25)
#     Line #1097 (got 26 columns instead of 25)
#     Line #1098 (got 26 columns instead of 25)
#     Line #1099 (got 26 columns instead of 25)
#     Line #1100 (got 26 columns instead of 25)
#     Line #1101 (got 26 columns instead of 25)
#     Line #1102 (got 26 columns instead of 25)
#     Line #1104 (got 26 columns instead of 25)
#     Line #1105 (got 26 columns instead of 25)
#     Line #1107 (got 26 columns instead of 25)
#     Line #1108 (got 26 columns instead of 25)
#     Line #1109 (got 26 columns instead of 25)
#     Line #1112 (got 26 columns instead of 25)
#     Line #1113 (got 26 columns instead of 25)
#     Line #1114 (got 26 columns instead of 25)
#     Line #1118 (got 27 columns instead of 25)
#     Line #1119 (got 26 columns instead of 25)
#     Line #1124 (got 26 columns instead of 25)
#     Line #1127 (got 27 columns instead of 25)
#     Line #1128 (got 26 columns instead of 25)
#     Line #1132 (got 26 columns instead of 25)
#     Line #1134 (got 26 columns instead of 25)
#     Line #1136 (got 26 columns instead of 25)
#     Line #1142 (got 16 columns instead of 25)
#     Line #1143 (got 26 columns instead of 25)
#     Line #1147 (got 26 columns instead of 25)
#     Line #1148 (got 26 columns instead of 25)
#     Line #1149 (got 26 columns instead of 25)
#     Line #1150 (got 26 columns instead of 25)
#     Line #1151 (got 26 columns instead of 25)
#     Line #1152 (got 26 columns instead of 25)
#     Line #1154 (got 26 columns instead of 25)
#     Line #1155 (got 26 columns instead of 25)
#     Line #1157 (got 26 columns instead of 25)
#     Line #1158 (got 26 columns instead of 25)
#     Line #1159 (got 26 columns instead of 25)
#     Line #1160 (got 26 columns instead of 25)
#     Line #1161 (got 16 columns instead of 25)
#     Line #1162 (got 26 columns instead of 25)
#     Line #1163 (got 26 columns instead of 25)
#     Line #1164 (got 26 columns instead of 25)
#     Line #1165 (got 26 columns instead of 25)
#     Line #1168 (got 26 columns instead of 25)
#     Line #1170 (got 26 columns instead of 25)
#     Line #1173 (got 26 columns instead of 25)
#     Line #1176 (got 26 columns instead of 25)
#     Line #1178 (got 27 columns instead of 25)
#     Line #1179 (got 26 columns instead of 25)
#     Line #1182 (got 26 columns instead of 25)
#     Line #1183 (got 27 columns instead of 25)
#     Line #1184 (got 26 columns instead of 25)
#     Line #1189 (got 26 columns instead of 25)
#     Line #1192 (got 16 columns instead of 25)
#     Line #1193 (got 26 columns instead of 25)
#     Line #1197 (got 26 columns instead of 25)
#     Line #1198 (got 26 columns instead of 25)
#     Line #1199 (got 26 columns instead of 25)
#     Line #1200 (got 26 columns instead of 25)
#     Line #1201 (got 26 columns instead of 25)
#     Line #1203 (got 26 columns instead of 25)
#     Line #1206 (got 27 columns instead of 25)
#     Line #1207 (got 26 columns instead of 25)
#     Line #1208 (got 26 columns instead of 25)
#     Line #1210 (got 16 columns instead of 25)
#     Line #1211 (got 26 columns instead of 25)
#     Line #1212 (got 26 columns instead of 25)
#     Line #1213 (got 26 columns instead of 25)
#     Line #1214 (got 26 columns instead of 25)
#     Line #1216 (got 26 columns instead of 25)
#     Line #1221 (got 26 columns instead of 25)
#     Line #1224 (got 26 columns instead of 25)
#     Line #1225 (got 26 columns instead of 25)
#     Line #1226 (got 26 columns instead of 25)
#     Line #1229 (got 26 columns instead of 25)
#     Line #1231 (got 26 columns instead of 25)
#     Line #1232 (got 26 columns instead of 25)
#     Line #1233 (got 26 columns instead of 25)
#     Line #1236 (got 26 columns instead of 25)
#     Line #1237 (got 26 columns instead of 25)
#     Line #1238 (got 26 columns instead of 25)
#     Line #1239 (got 26 columns instead of 25)
#     Line #1242 (got 26 columns instead of 25)
#     Line #1243 (got 26 columns instead of 25)
#     Line #1244 (got 27 columns instead of 25)
#     Line #1247 (got 26 columns instead of 25)
#     Line #1248 (got 27 columns instead of 25)
#     Line #1253 (got 26 columns instead of 25)
#     Line #1254 (got 26 columns instead of 25)
#     Line #1255 (got 26 columns instead of 25)
#     Line #1259 (got 26 columns instead of 25)
#     Line #1264 (got 26 columns instead of 25)
#     Line #1265 (got 26 columns instead of 25)
#     Line #1266 (got 26 columns instead of 25)
#     Line #1267 (got 26 columns instead of 25)
#     Line #1270 (got 26 columns instead of 25)
#     Line #1272 (got 26 columns instead of 25)
#     Line #1276 (got 26 columns instead of 25)
#     Line #1278 (got 26 columns instead of 25)
#     Line #1279 (got 27 columns instead of 25)
#     Line #1280 (got 26 columns instead of 25)
#     Line #1283 (got 26 columns instead of 25)
#     Line #1284 (got 26 columns instead of 25)
#     Line #1285 (got 26 columns instead of 25)
#     Line #1286 (got 26 columns instead of 25)
#     Line #1288 (got 26 columns instead of 25)
#     Line #1290 (got 26 columns instead of 25)
#     Line #1292 (got 27 columns instead of 25)
#     Line #1293 (got 26 columns instead of 25)
#     Line #1295 (got 26 columns instead of 25)
#     Line #1297 (got 26 columns instead of 25)
#     Line #1299 (got 26 columns instead of 25)
#     Line #1300 (got 27 columns instead of 25)
#     Line #1306 (got 26 columns instead of 25)
#     Line #1308 (got 26 columns instead of 25)
#     Line #1309 (got 26 columns instead of 25)
#     Line #1310 (got 26 columns instead of 25)
#     Line #1312 (got 26 columns instead of 25)
#     Line #1313 (got 26 columns instead of 25)
#     Line #1314 (got 26 columns instead of 25)
#     Line #1318 (got 27 columns instead of 25)
#     Line #1319 (got 27 columns instead of 25)
#     Line #1321 (got 27 columns instead of 25)
#     Line #1323 (got 26 columns instead of 25)
#     Line #1324 (got 26 columns instead of 25)
#     Line #1325 (got 27 columns instead of 25)
#     Line #1331 (got 26 columns instead of 25)
#     Line #1336 (got 26 columns instead of 25)
#     Line #1337 (got 26 columns instead of 25)
#     Line #1338 (got 26 columns instead of 25)
#     Line #1340 (got 26 columns instead of 25)
#     Line #1343 (got 26 columns instead of 25)
#     Line #1346 (got 27 columns instead of 25)
#     Line #1348 (got 27 columns instead of 25)
#     Line #1350 (got 26 columns instead of 25)
#     Line #1351 (got 26 columns instead of 25)
#     Line #1352 (got 27 columns instead of 25)
#     Line #1357 (got 26 columns instead of 25)
#     Line #1358 (got 26 columns instead of 25)
#     Line #1361 (got 26 columns instead of 25)
#     Line #1365 (got 27 columns instead of 25)
#     Line #1366 (got 26 columns instead of 25)
#     Line #1367 (got 26 columns instead of 25)
#     Line #1370 (got 26 columns instead of 25)
#     Line #1371 (got 16 columns instead of 25)
#     Line #1372 (got 26 columns instead of 25)
#     Line #1376 (got 26 columns instead of 25)
#     Line #1377 (got 26 columns instead of 25)
#     Line #1378 (got 26 columns instead of 25)
#     Line #1379 (got 26 columns instead of 25)
#     Line #1380 (got 26 columns instead of 25)
#     Line #1382 (got 26 columns instead of 25)
#     Line #1385 (got 26 columns instead of 25)
#     Line #1386 (got 26 columns instead of 25)
#     Line #1387 (got 26 columns instead of 25)
#     Line #1389 (got 16 columns instead of 25)
#     Line #1390 (got 26 columns instead of 25)
#     Line #1391 (got 26 columns instead of 25)
#     Line #1392 (got 26 columns instead of 25)
#     Line #1393 (got 26 columns instead of 25)
#     Line #1395 (got 26 columns instead of 25)
#     Line #1397 (got 26 columns instead of 25)
#     Line #1401 (got 26 columns instead of 25)
#     Line #1403 (got 26 columns instead of 25)
#     Line #1404 (got 27 columns instead of 25)
#     Line #1405 (got 26 columns instead of 25)
#     Line #1407 (got 26 columns instead of 25)
#     Line #1409 (got 26 columns instead of 25)
#     Line #1410 (got 26 columns instead of 25)
#     Line #1411 (got 26 columns instead of 25)
#     Line #1412 (got 26 columns instead of 25)
#     Line #1414 (got 26 columns instead of 25)
#     Line #1416 (got 26 columns instead of 25)
#     Line #1417 (got 26 columns instead of 25)
#     Line #1419 (got 26 columns instead of 25)
#     Line #1425 (got 26 columns instead of 25)
#     Line #1427 (got 26 columns instead of 25)
#     Line #1429 (got 26 columns instead of 25)
#     Line #1431 (got 27 columns instead of 25)
#     Line #1432 (got 26 columns instead of 25)
#     Line #1434 (got 26 columns instead of 25)
#     Line #1435 (got 26 columns instead of 25)
#     Line #1437 (got 26 columns instead of 25)
#     Line #1439 (got 26 columns instead of 25)
#     Line #1440 (got 26 columns instead of 25)
#     Line #1443 (got 26 columns instead of 25)
#     Line #1444 (got 26 columns instead of 25)
#     Line #1445 (got 27 columns instead of 25)
#     Line #1447 (got 27 columns instead of 25)
#     Line #1450 (got 26 columns instead of 25)
#     Line #1451 (got 26 columns instead of 25)
#     Line #1452 (got 26 columns instead of 25)
#     Line #1460 (got 27 columns instead of 25)
#     Line #1462 (got 26 columns instead of 25)
#     Line #1464 (got 26 columns instead of 25)
#     Line #1465 (got 26 columns instead of 25)
#     Line #1466 (got 26 columns instead of 25)
#     Line #1467 (got 26 columns instead of 25)
#     Line #1469 (got 26 columns instead of 25)
#     Line #1474 (got 26 columns instead of 25)
#     Line #1475 (got 26 columns instead of 25)
#     Line #1477 (got 26 columns instead of 25)
#     Line #1478 (got 26 columns instead of 25)
#     Line #1482 (got 26 columns instead of 25)
#     Line #1484 (got 26 columns instead of 25)
#     Line #1488 (got 26 columns instead of 25)
#     Line #1490 (got 26 columns instead of 25)
#     Line #1492 (got 26 columns instead of 25)
#     Line #1493 (got 26 columns instead of 25)
#     Line #1494 (got 26 columns instead of 25)
#     Line #1495 (got 26 columns instead of 25)
#     Line #1497 (got 26 columns instead of 25)
#     Line #1500 (got 26 columns instead of 25)
#     Line #1503 (got 26 columns instead of 25)
#     Line #1505 (got 26 columns instead of 25)
#     Line #1509 (got 27 columns instead of 25)
#     Line #1510 (got 26 columns instead of 25)
#     Line #1512 (got 26 columns instead of 25)
#     Line #1515 (got 26 columns instead of 25)
#     Line #1517 (got 26 columns instead of 25)
#     Line #1519 (got 26 columns instead of 25)
#     Line #1520 (got 26 columns instead of 25)
#     Line #1523 (got 27 columns instead of 25)
#     Line #1524 (got 26 columns instead of 25)
#     Line #1525 (got 26 columns instead of 25)
#     Line #1527 (got 26 columns instead of 25)
#     Line #1528 (got 26 columns instead of 25)
#     Line #1529 (got 27 columns instead of 25)
#     Line #1530 (got 26 columns instead of 25)
#     Line #1534 (got 26 columns instead of 25)
#     Line #1536 (got 26 columns instead of 25)
#     Line #1537 (got 26 columns instead of 25)
#     Line #1541 (got 26 columns instead of 25)
#     Line #1542 (got 26 columns instead of 25)
#     Line #1548 (got 26 columns instead of 25)
#     Line #1549 (got 26 columns instead of 25)
#     Line #1550 (got 27 columns instead of 25)
#     Line #1551 (got 27 columns instead of 25)
#     Line #1555 (got 26 columns instead of 25)
#     Line #1558 (got 26 columns instead of 25)
#     Line #1559 (got 26 columns instead of 25)
#     Line #1562 (got 26 columns instead of 25)
#     Line #1563 (got 26 columns instead of 25)
#     Line #1565 (got 26 columns instead of 25)
#     Line #1567 (got 26 columns instead of 25)
#     Line #1572 (got 26 columns instead of 25)
#     Line #1573 (got 26 columns instead of 25)
#     Line #1575 (got 27 columns instead of 25)
#     Line #1576 (got 26 columns instead of 25)
#     Line #1580 (got 26 columns instead of 25)
#     Line #1582 (got 26 columns instead of 25)
#     Line #1586 (got 26 columns instead of 25)
#     Line #1587 (got 26 columns instead of 25)
#     Line #1588 (got 26 columns instead of 25)
#     Line #1590 (got 26 columns instead of 25)
#     Line #1593 (got 27 columns instead of 25)
#     Line #1594 (got 26 columns instead of 25)
#     Line #1596 (got 26 columns instead of 25)
#     Line #1598 (got 26 columns instead of 25)
#     Line #1600 (got 26 columns instead of 25)
#     Line #1601 (got 27 columns instead of 25)
#     Line #1607 (got 26 columns instead of 25)
#     Line #1609 (got 26 columns instead of 25)
#     Line #1610 (got 26 columns instead of 25)
#     Line #1611 (got 26 columns instead of 25)
#     Line #1613 (got 26 columns instead of 25)
#     Line #1614 (got 26 columns instead of 25)
#     Line #1618 (got 26 columns instead of 25)
#     Line #1619 (got 26 columns instead of 25)
#     Line #1625 (got 26 columns instead of 25)
#     Line #1626 (got 26 columns instead of 25)
#     Line #1627 (got 27 columns instead of 25)
#     Line #1628 (got 27 columns instead of 25)
#     Line #1629 (got 26 columns instead of 25)
#     Line #1630 (got 26 columns instead of 25)
#     Line #1632 (got 26 columns instead of 25)
#     Line #1633 (got 26 columns instead of 25)
#     Line #1636 (got 26 columns instead of 25)
#     Line #1637 (got 26 columns instead of 25)
#     Line #1640 (got 26 columns instead of 25)
#     Line #1641 (got 26 columns instead of 25)
#     Line #1644 (got 27 columns instead of 25)
#     Line #1645 (got 27 columns instead of 25)
#     Line #1647 (got 26 columns instead of 25)
#     Line #1648 (got 27 columns instead of 25)
#     Line #1649 (got 26 columns instead of 25)
#     Line #1650 (got 27 columns instead of 25)
#     Line #1651 (got 27 columns instead of 25)
#     Line #1655 (got 26 columns instead of 25)
#     Line #1663 (got 26 columns instead of 25)
#     Line #1664 (got 27 columns instead of 25)
#     Line #1665 (got 26 columns instead of 25)
#     Line #1668 (got 26 columns instead of 25)
#     Line #1669 (got 26 columns instead of 25)
#     Line #1670 (got 16 columns instead of 25)
#     Line #1675 (got 26 columns instead of 25)
#     Line #1676 (got 26 columns instead of 25)
#     Line #1677 (got 26 columns instead of 25)
#     Line #1678 (got 26 columns instead of 25)
#     Line #1679 (got 26 columns instead of 25)
#     Line #1681 (got 26 columns instead of 25)
#     Line #1685 (got 26 columns instead of 25)
#     Line #1688 (got 16 columns instead of 25)
#     Line #1690 (got 26 columns instead of 25)
#     Line #1691 (got 26 columns instead of 25)
#     Line #1692 (got 26 columns instead of 25)
#     Line #1694 (got 26 columns instead of 25)
#     Line #1695 (got 26 columns instead of 25)
#     Line #1697 (got 26 columns instead of 25)
#     Line #1703 (got 26 columns instead of 25)
#     Line #1704 (got 27 columns instead of 25)
#     Line #1705 (got 26 columns instead of 25)
#     Line #1707 (got 26 columns instead of 25)
#     Line #1709 (got 26 columns instead of 25)
#     Line #1710 (got 26 columns instead of 25)
#     Line #1712 (got 26 columns instead of 25)
#     Line #1715 (got 26 columns instead of 25)
#     Line #1717 (got 26 columns instead of 25)
#     Line #1718 (got 26 columns instead of 25)
#     Line #1719 (got 27 columns instead of 25)
#     Line #1721 (got 26 columns instead of 25)
#     Line #1722 (got 26 columns instead of 25)
#     Line #1723 (got 27 columns instead of 25)
#     Line #1724 (got 26 columns instead of 25)
#     Line #1725 (got 27 columns instead of 25)
#     Line #1730 (got 26 columns instead of 25)
#     Line #1740 (got 26 columns instead of 25)
#     Line #1742 (got 26 columns instead of 25)
#     Line #1743 (got 26 columns instead of 25)
#     Line #1744 (got 26 columns instead of 25)
#     Line #1745 (got 26 columns instead of 25)
#     Line #1750 (got 26 columns instead of 25)
#     Line #1753 (got 26 columns instead of 25)
#     Line #1754 (got 16 columns instead of 25)
#     Line #1755 (got 26 columns instead of 25)
#     Line #1758 (got 26 columns instead of 25)
#     Line #1760 (got 27 columns instead of 25)
#     Line #1761 (got 26 columns instead of 25)
#     Line #1762 (got 26 columns instead of 25)
#     Line #1765 (got 26 columns instead of 25)
#     Line #1766 (got 26 columns instead of 25)
#     Line #1767 (got 26 columns instead of 25)
#     Line #1768 (got 26 columns instead of 25)
#     Line #1771 (got 26 columns instead of 25)
#     Line #1772 (got 26 columns instead of 25)
#     Line #1774 (got 26 columns instead of 25)
#     Line #1780 (got 26 columns instead of 25)
#     Line #1781 (got 27 columns instead of 25)
#     Line #1782 (got 26 columns instead of 25)
#     Line #1784 (got 26 columns instead of 25)
#     Line #1786 (got 26 columns instead of 25)
#     Line #1787 (got 26 columns instead of 25)
#     Line #1788 (got 26 columns instead of 25)
#     Line #1791 (got 26 columns instead of 25)
#     Line #1793 (got 26 columns instead of 25)
#     Line #1795 (got 26 columns instead of 25)
#     Line #1798 (got 26 columns instead of 25)
#     Line #1800 (got 26 columns instead of 25)
#     Line #1802 (got 26 columns instead of 25)
#     Line #1803 (got 26 columns instead of 25)
#     Line #1804 (got 26 columns instead of 25)
#     Line #1805 (got 26 columns instead of 25)
#     Line #1806 (got 26 columns instead of 25)
#     Line #1809 (got 26 columns instead of 25)
#     Line #1810 (got 27 columns instead of 25)
#     Line #1811 (got 26 columns instead of 25)
#     Line #1814 (got 26 columns instead of 25)
#     Line #1815 (got 26 columns instead of 25)
#     Line #1817 (got 26 columns instead of 25)
#     Line #1819 (got 26 columns instead of 25)
#     Line #1823 (got 26 columns instead of 25)
#     Line #1827 (got 26 columns instead of 25)
#     Line #1829 (got 26 columns instead of 25)
#     Line #1830 (got 27 columns instead of 25)
#     Line #1836 (got 26 columns instead of 25)
#     Line #1838 (got 26 columns instead of 25)
#     Line #1839 (got 26 columns instead of 25)
#     Line #1840 (got 26 columns instead of 25)
#     Line #1841 (got 26 columns instead of 25)
#     Line #1842 (got 26 columns instead of 25)
#     Line #1843 (got 26 columns instead of 25)
#     Line #1847 (got 26 columns instead of 25)
#     Line #1849 (got 26 columns instead of 25)
#     Line #1855 (got 26 columns instead of 25)
#     Line #1856 (got 27 columns instead of 25)
#     Line #1857 (got 26 columns instead of 25)
#     Line #1859 (got 26 columns instead of 25)
#     Line #1861 (got 26 columns instead of 25)
#     Line #1862 (got 26 columns instead of 25)
#     Line #1864 (got 26 columns instead of 25)
#     Line #1867 (got 26 columns instead of 25)
#     Line #1869 (got 26 columns instead of 25)
#     Line #1870 (got 16 columns instead of 25)
#     Line #1871 (got 26 columns instead of 25)
#     Line #1875 (got 26 columns instead of 25)
#     Line #1876 (got 26 columns instead of 25)
#     Line #1877 (got 26 columns instead of 25)
#     Line #1878 (got 26 columns instead of 25)
#     Line #1879 (got 26 columns instead of 25)
#     Line #1880 (got 26 columns instead of 25)
#     Line #1882 (got 26 columns instead of 25)
#     Line #1885 (got 26 columns instead of 25)
#     Line #1886 (got 26 columns instead of 25)
#     Line #1887 (got 26 columns instead of 25)
#     Line #1888 (got 26 columns instead of 25)
#     Line #1890 (got 26 columns instead of 25)
#     Line #1891 (got 26 columns instead of 25)
#     Line #1892 (got 26 columns instead of 25)
#     Line #1893 (got 26 columns instead of 25)
#     Line #1900 (got 26 columns instead of 25)
#     Line #1903 (got 26 columns instead of 25)
#     Line #1904 (got 16 columns instead of 25)
#     Line #1905 (got 26 columns instead of 25)
#     Line #1908 (got 26 columns instead of 25)
#     Line #1910 (got 27 columns instead of 25)
#     Line #1911 (got 26 columns instead of 25)
#     Line #1912 (got 26 columns instead of 25)
#     Line #1915 (got 26 columns instead of 25)
#     Line #1916 (got 26 columns instead of 25)
#     Line #1917 (got 26 columns instead of 25)
#     Line #1918 (got 26 columns instead of 25)
#     Line #1919 (got 26 columns instead of 25)
#     Line #1922 (got 26 columns instead of 25)
#     Line #1923 (got 26 columns instead of 25)
#     Line #1925 (got 26 columns instead of 25)
#     Line #1931 (got 26 columns instead of 25)
#     Line #1933 (got 26 columns instead of 25)
#     Line #1935 (got 26 columns instead of 25)
#     Line #1937 (got 27 columns instead of 25)
#     Line #1938 (got 26 columns instead of 25)
#     Line #1940 (got 26 columns instead of 25)
#     Line #1943 (got 26 columns instead of 25)
#     Line #1945 (got 26 columns instead of 25)
#     Line #1948 (got 26 columns instead of 25)
#     Line #1950 (got 26 columns instead of 25)
#     Line #1953 (got 26 columns instead of 25)
#     Line #1954 (got 26 columns instead of 25)
#     Line #1955 (got 26 columns instead of 25)
#     Line #1958 (got 26 columns instead of 25)
#     Line #1960 (got 26 columns instead of 25)
#     Line #1961 (got 26 columns instead of 25)
#     Line #1962 (got 26 columns instead of 25)
#     Line #1964 (got 26 columns instead of 25)
#     Line #1965 (got 26 columns instead of 25)
#     Line #1966 (got 26 columns instead of 25)
#     Line #1967 (got 26 columns instead of 25)
#     Line #1972 (got 16 columns instead of 25)
#     Line #1973 (got 26 columns instead of 25)
#     Line #1976 (got 26 columns instead of 25)
#     Line #1978 (got 26 columns instead of 25)
#     Line #1980 (got 26 columns instead of 25)
#     Line #1981 (got 26 columns instead of 25)
#     Line #1982 (got 26 columns instead of 25)
#     Line #1983 (got 26 columns instead of 25)
#     Line #1984 (got 26 columns instead of 25)
#     Line #1987 (got 26 columns instead of 25)
#     Line #1988 (got 27 columns instead of 25)
#     Line #1989 (got 26 columns instead of 25)
#     Line #1992 (got 26 columns instead of 25)
#     Line #1993 (got 26 columns instead of 25)
#     Line #1994 (got 26 columns instead of 25)
#     Line #1995 (got 26 columns instead of 25)
#     Line #1997 (got 26 columns instead of 25)
#     Line #2003 (got 26 columns instead of 25)
#     Line #2006 (got 16 columns instead of 25)
#     Line #2007 (got 27 columns instead of 25)
#     Line #2009 (got 26 columns instead of 25)
#     Line #2011 (got 26 columns instead of 25)
#     Line #2012 (got 26 columns instead of 25)
#     Line #2013 (got 27 columns instead of 25)
#     Line #2014 (got 26 columns instead of 25)
#     Line #2018 (got 26 columns instead of 25)
#     Line #2019 (got 26 columns instead of 25)
#     Line #2020 (got 26 columns instead of 25)
#     Line #2021 (got 26 columns instead of 25)
#     Line #2022 (got 26 columns instead of 25)
#     Line #2027 (got 26 columns instead of 25)
#     Line #2033 (got 26 columns instead of 25)
#     Line #2035 (got 27 columns instead of 25)
#     Line #2036 (got 27 columns instead of 25)
#     Line #2040 (got 27 columns instead of 25)
#     Line #2042 (got 26 columns instead of 25)
#     Line #2045 (got 26 columns instead of 25)
#     Line #2046 (got 26 columns instead of 25)
#     Line #2047 (got 26 columns instead of 25)
#     Line #2048 (got 26 columns instead of 25)
#     Line #2051 (got 26 columns instead of 25)
#     Line #2052 (got 26 columns instead of 25)
#     Line #2053 (got 27 columns instead of 25)
#     Line #2055 (got 27 columns instead of 25)
#     Line #2058 (got 26 columns instead of 25)
#     Line #2059 (got 26 columns instead of 25)
#     Line #2060 (got 26 columns instead of 25)
#     Line #2067 (got 27 columns instead of 25)
#     Line #2071 (got 26 columns instead of 25)
#     Line #2072 (got 26 columns instead of 25)
#     Line #2073 (got 26 columns instead of 25)
#     Line #2076 (got 27 columns instead of 25)
#     Line #2077 (got 26 columns instead of 25)
#     Line #2081 (got 26 columns instead of 25)
#     Line #2082 (got 26 columns instead of 25)
#     Line #2086 (got 26 columns instead of 25)
#     Line #2091 (got 26 columns instead of 25)
#     Line #2095 (got 27 columns instead of 25)
#     Line #2096 (got 26 columns instead of 25)
#     Line #2101 (got 26 columns instead of 25)
#     Line #2102 (got 26 columns instead of 25)
#     Line #2105 (got 27 columns instead of 25)
#     Line #2106 (got 26 columns instead of 25)
#     Line #2107 (got 26 columns instead of 25)
#     Line #2110 (got 26 columns instead of 25)
#     Line #2111 (got 27 columns instead of 25)
#     Line #2112 (got 26 columns instead of 25)
#     Line #2116 (got 26 columns instead of 25)
#     Line #2118 (got 26 columns instead of 25)
#     Line #2119 (got 26 columns instead of 25)
#     Line #2120 (got 26 columns instead of 25)
#     Line #2124 (got 16 columns instead of 25)
#     Line #2125 (got 26 columns instead of 25)
#     Line #2129 (got 26 columns instead of 25)
#     Line #2130 (got 26 columns instead of 25)
#     Line #2131 (got 26 columns instead of 25)
#     Line #2132 (got 26 columns instead of 25)
#     Line #2133 (got 26 columns instead of 25)
#     Line #2135 (got 26 columns instead of 25)
#     Line #2138 (got 26 columns instead of 25)
#     Line #2139 (got 26 columns instead of 25)
#     Line #2140 (got 26 columns instead of 25)
#     Line #2144 (got 26 columns instead of 25)
#     Line #2145 (got 26 columns instead of 25)
#     Line #2146 (got 26 columns instead of 25)
#     Line #2149 (got 27 columns instead of 25)
#     Line #2150 (got 27 columns instead of 25)
#     Line #2152 (got 26 columns instead of 25)
#     Line #2154 (got 26 columns instead of 25)
#     Line #2155 (got 27 columns instead of 25)
#     Line #2156 (got 27 columns instead of 25)
#     Line #2162 (got 26 columns instead of 25)
#     Line #2169 (got 27 columns instead of 25)
#     Line #2170 (got 26 columns instead of 25)
#     Line #2174 (got 26 columns instead of 25)
#     Line #2176 (got 26 columns instead of 25)
#     Line #2177 (got 26 columns instead of 25)
#     Line #2180 (got 26 columns instead of 25)
#     Line #2181 (got 27 columns instead of 25)
#     Line #2182 (got 26 columns instead of 25)
#     Line #2183 (got 26 columns instead of 25)
#     Line #2186 (got 26 columns instead of 25)
#     Line #2188 (got 26 columns instead of 25)
#     Line #2192 (got 26 columns instead of 25)
#     Line #2194 (got 26 columns instead of 25)
#     Line #2195 (got 26 columns instead of 25)
#     Line #2196 (got 27 columns instead of 25)
#     Line #2199 (got 16 columns instead of 25)
#     Line #2200 (got 26 columns instead of 25)
#     Line #2204 (got 26 columns instead of 25)
#     Line #2205 (got 26 columns instead of 25)
#     Line #2206 (got 26 columns instead of 25)
#     Line #2207 (got 26 columns instead of 25)
#     Line #2208 (got 26 columns instead of 25)
#     Line #2210 (got 26 columns instead of 25)
#     Line #2214 (got 26 columns instead of 25)
#     Line #2215 (got 26 columns instead of 25)
#     Line #2219 (got 26 columns instead of 25)
#     Line #2220 (got 26 columns instead of 25)
#     Line #2221 (got 26 columns instead of 25)
#     Line #2223 (got 26 columns instead of 25)
#     Line #2224 (got 26 columns instead of 25)
#     Line #2225 (got 27 columns instead of 25)
#     Line #2227 (got 26 columns instead of 25)
#     Line #2228 (got 26 columns instead of 25)
#     Line #2229 (got 27 columns instead of 25)
#     Line #2230 (got 26 columns instead of 25)
#     Line #2231 (got 27 columns instead of 25)
#     Line #2236 (got 26 columns instead of 25)
#     Line #2248 (got 26 columns instead of 25)
#     Line #2249 (got 26 columns instead of 25)
#     Line #2250 (got 26 columns instead of 25)
#     Line #2251 (got 26 columns instead of 25)
#     Line #2252 (got 26 columns instead of 25)
#     Line #2253 (got 26 columns instead of 25)
#     Line #2256 (got 26 columns instead of 25)
#     Line #2257 (got 27 columns instead of 25)
#     Line #2259 (got 27 columns instead of 25)
#     Line #2262 (got 26 columns instead of 25)
#     Line #2263 (got 26 columns instead of 25)
#     Line #2264 (got 26 columns instead of 25)
#     Line #2268 (got 26 columns instead of 25)
#     Line #2271 (got 27 columns instead of 25)
#     Line #2272 (got 26 columns instead of 25)
#     Line #2275 (got 26 columns instead of 25)
#     Line #2276 (got 26 columns instead of 25)
#     Line #2280 (got 27 columns instead of 25)
#     Line #2282 (got 27 columns instead of 25)
#     Line #2284 (got 26 columns instead of 25)
#     Line #2285 (got 26 columns instead of 25)
#     Line #2286 (got 27 columns instead of 25)
#     Line #2291 (got 26 columns instead of 25)
#     Line #2292 (got 26 columns instead of 25)
#     Line #2295 (got 26 columns instead of 25)
#     Line #2299 (got 27 columns instead of 25)
#     Line #2300 (got 26 columns instead of 25)
#     Line #2301 (got 26 columns instead of 25)
#     Line #2304 (got 26 columns instead of 25)
#     Line #2306 (got 26 columns instead of 25)
#     Line #2307 (got 26 columns instead of 25)
#     Line #2308 (got 26 columns instead of 25)
#     Line #2310 (got 27 columns instead of 25)
#     Line #2311 (got 26 columns instead of 25)
#     Line #2312 (got 26 columns instead of 25)
#     Line #2314 (got 26 columns instead of 25)
#     Line #2315 (got 26 columns instead of 25)
#     Line #2316 (got 27 columns instead of 25)
#     Line #2317 (got 26 columns instead of 25)
#     Line #2321 (got 26 columns instead of 25)
#     Line #2323 (got 26 columns instead of 25)
#     Line #2324 (got 26 columns instead of 25)
#     Line #2329 (got 16 columns instead of 25)
#     Line #2334 (got 26 columns instead of 25)
#     Line #2335 (got 26 columns instead of 25)
#     Line #2336 (got 26 columns instead of 25)
#     Line #2337 (got 26 columns instead of 25)
#     Line #2338 (got 26 columns instead of 25)
#     Line #2340 (got 26 columns instead of 25)
#     Line #2344 (got 26 columns instead of 25)
#     Line #2349 (got 26 columns instead of 25)
#     Line #2351 (got 26 columns instead of 25)
#     Line #2353 (got 26 columns instead of 25)
#     Line #2355 (got 26 columns instead of 25)
#     Line #2356 (got 26 columns instead of 25)
#     Line #2358 (got 26 columns instead of 25)
#     Line #2361 (got 27 columns instead of 25)
#     Line #2362 (got 26 columns instead of 25)
#     Line #2363 (got 26 columns instead of 25)
#     Line #2365 (got 26 columns instead of 25)
#     Line #2366 (got 26 columns instead of 25)
#     Line #2367 (got 27 columns instead of 25)
#     Line #2368 (got 26 columns instead of 25)
#     Line #2372 (got 26 columns instead of 25)
#     Line #2374 (got 26 columns instead of 25)
#     Line #2375 (got 26 columns instead of 25)
#     Line #2380 (got 26 columns instead of 25)
#     Line #2383 (got 26 columns instead of 25)
#     Line #2384 (got 26 columns instead of 25)
#     Line #2385 (got 27 columns instead of 25)
#     Line #2387 (got 27 columns instead of 25)
#     Line #2390 (got 26 columns instead of 25)
#     Line #2391 (got 26 columns instead of 25)
#     Line #2392 (got 26 columns instead of 25)
#     Line #2400 (got 27 columns instead of 25)
#     Line #2401 (got 26 columns instead of 25)
#     Line #2404 (got 26 columns instead of 25)
#     Line #2406 (got 26 columns instead of 25)
#     Line #2407 (got 26 columns instead of 25)
#     Line #2408 (got 26 columns instead of 25)
#     Line #2409 (got 27 columns instead of 25)
#     Line #2412 (got 26 columns instead of 25)
#     Line #2413 (got 27 columns instead of 25)
#     Line #2417 (got 27 columns instead of 25)
#     Line #2418 (got 26 columns instead of 25)
#     Line #2419 (got 26 columns instead of 25)
#     Line #2420 (got 26 columns instead of 25)
#     Line #2424 (got 26 columns instead of 25)
#     Line #2428 (got 26 columns instead of 25)
#     Line #2430 (got 26 columns instead of 25)
#     Line #2431 (got 26 columns instead of 25)
#     Line #2434 (got 16 columns instead of 25)
#     Line #2439 (got 26 columns instead of 25)
#     Line #2440 (got 26 columns instead of 25)
#     Line #2441 (got 26 columns instead of 25)
#     Line #2442 (got 26 columns instead of 25)
#     Line #2443 (got 26 columns instead of 25)
#     Line #2445 (got 26 columns instead of 25)
#     Line #2449 (got 26 columns instead of 25)
#     Line #2456 (got 26 columns instead of 25)
#     Line #2458 (got 26 columns instead of 25)
#     Line #2461 (got 26 columns instead of 25)
#     Line #2463 (got 26 columns instead of 25)
#     Line #2465 (got 26 columns instead of 25)
#     Line #2467 (got 26 columns instead of 25)
#     Line #2468 (got 27 columns instead of 25)
#     Line #2474 (got 26 columns instead of 25)
#     Line #2476 (got 26 columns instead of 25)
#     Line #2477 (got 26 columns instead of 25)
#     Line #2478 (got 26 columns instead of 25)
#     Line #2479 (got 26 columns instead of 25)
#     Line #2480 (got 26 columns instead of 25)
#     Line #2481 (got 26 columns instead of 25)
#     Line #2486 (got 26 columns instead of 25)
#     Line #2487 (got 26 columns instead of 25)
#     Line #2489 (got 26 columns instead of 25)
#     Line #2492 (got 27 columns instead of 25)
#     Line #2493 (got 26 columns instead of 25)
#     Line #2494 (got 26 columns instead of 25)
#     Line #2496 (got 26 columns instead of 25)
#     Line #2497 (got 26 columns instead of 25)
#     Line #2498 (got 27 columns instead of 25)
#     Line #2499 (got 26 columns instead of 25)
#     Line #2503 (got 26 columns instead of 25)
#     Line #2505 (got 26 columns instead of 25)
#     Line #2506 (got 26 columns instead of 25)
#     Line #2512 (got 27 columns instead of 25)
#     Line #2513 (got 26 columns instead of 25)
#     Line #2515 (got 26 columns instead of 25)
#     Line #2517 (got 26 columns instead of 25)
#     Line #2520 (got 27 columns instead of 25)
#     Line #2527 (got 26 columns instead of 25)
#     Line #2531 (got 26 columns instead of 25)
#     Line #2532 (got 26 columns instead of 25)
#     Line #2540 (got 26 columns instead of 25)
#     Line #2543 (got 26 columns instead of 25)
#     Line #2544 (got 26 columns instead of 25)
#     Line #2545 (got 26 columns instead of 25)
#     Line #2548 (got 26 columns instead of 25)
#     Line #2550 (got 26 columns instead of 25)
#     Line #2551 (got 26 columns instead of 25)
#     Line #2552 (got 26 columns instead of 25)
#     Line #2555 (got 26 columns instead of 25)
#     Line #2557 (got 26 columns instead of 25)
#     Line #2558 (got 26 columns instead of 25)
#     Line #2559 (got 26 columns instead of 25)
#     Line #2562 (got 26 columns instead of 25)
#     Line #2564 (got 26 columns instead of 25)
#     Line #2567 (got 26 columns instead of 25)
#     Line #2570 (got 16 columns instead of 25)
#     Line #2571 (got 27 columns instead of 25)
#     Line #2573 (got 26 columns instead of 25)
#     Line #2575 (got 26 columns instead of 25)
#     Line #2576 (got 26 columns instead of 25)
#     Line #2577 (got 27 columns instead of 25)
#     Line #2578 (got 26 columns instead of 25)
#     Line #2582 (got 26 columns instead of 25)
#     Line #2584 (got 26 columns instead of 25)
#     Line #2585 (got 26 columns instead of 25)
#     Line #2586 (got 26 columns instead of 25)
#     Line #2592 (got 26 columns instead of 25)
#     Line #2596 (got 26 columns instead of 25)
#     Line #2598 (got 26 columns instead of 25)
#     Line #2599 (got 27 columns instead of 25)
#     Line #2605 (got 26 columns instead of 25)
#     Line #2607 (got 26 columns instead of 25)
#     Line #2610 (got 26 columns instead of 25)
#     Line #2611 (got 26 columns instead of 25)
#     Line #2612 (got 26 columns instead of 25)
#     Line #2613 (got 26 columns instead of 25)
#     Line #2617 (got 27 columns instead of 25)
#     Line #2618 (got 27 columns instead of 25)
#     Line #2620 (got 27 columns instead of 25)
#     Line #2622 (got 26 columns instead of 25)
#     Line #2623 (got 26 columns instead of 25)
#     Line #2624 (got 27 columns instead of 25)
#     Line #2629 (got 26 columns instead of 25)
#     Line #2630 (got 26 columns instead of 25)
#     Line #2633 (got 26 columns instead of 25)
#     Line #2636 (got 27 columns instead of 25)
#     Line #2637 (got 27 columns instead of 25)
#     Line #2638 (got 26 columns instead of 25)
#     Line #2642 (got 26 columns instead of 25)
#     Line #2644 (got 26 columns instead of 25)
#     Line #2645 (got 26 columns instead of 25)
#     Line #2648 (got 26 columns instead of 25)
#     Line #2649 (got 27 columns instead of 25)
#     Line #2650 (got 26 columns instead of 25)
#     Line #2651 (got 26 columns instead of 25)
#     Line #2654 (got 26 columns instead of 25)
#     Line #2656 (got 26 columns instead of 25)
#     Line #2660 (got 26 columns instead of 25)
#     Line #2662 (got 26 columns instead of 25)
#     Line #2663 (got 26 columns instead of 25)
#     Line #2669 (got 26 columns instead of 25)
#     Line #2671 (got 26 columns instead of 25)
#     Line #2674 (got 27 columns instead of 25)
#     Line #2675 (got 26 columns instead of 25)
#     Line #2676 (got 26 columns instead of 25)
#     Line #2678 (got 26 columns instead of 25)
#     Line #2679 (got 26 columns instead of 25)
#     Line #2680 (got 27 columns instead of 25)
#     Line #2681 (got 26 columns instead of 25)
#     Line #2687 (got 26 columns instead of 25)
#     Line #2688 (got 26 columns instead of 25)
#     Line #2689 (got 26 columns instead of 25)
#     Line #2694 (got 26 columns instead of 25)
#     Line #2695 (got 26 columns instead of 25)
#     Line #2697 (got 26 columns instead of 25)
#     Line #2699 (got 26 columns instead of 25)
#     Line #2701 (got 26 columns instead of 25)
#     Line #2702 (got 27 columns instead of 25)
#     Line #2708 (got 26 columns instead of 25)
#     Line #2710 (got 26 columns instead of 25)
#     Line #2711 (got 26 columns instead of 25)
#     Line #2714 (got 26 columns instead of 25)
#     Line #2715 (got 26 columns instead of 25)
#     Line #2716 (got 26 columns instead of 25)
#     Line #2720 (got 27 columns instead of 25)
#     Line #2721 (got 26 columns instead of 25)
#     Line #2723 (got 26 columns instead of 25)
#     Line #2725 (got 26 columns instead of 25)
#     Line #2727 (got 26 columns instead of 25)
#     Line #2728 (got 27 columns instead of 25)
#     Line #2734 (got 26 columns instead of 25)
#     Line #2736 (got 26 columns instead of 25)
#     Line #2737 (got 26 columns instead of 25)
#     Line #2740 (got 26 columns instead of 25)
#     Line #2741 (got 26 columns instead of 25)
#     Line #2742 (got 26 columns instead of 25)
#     Line #2749 (got 26 columns instead of 25)
#     Line #2752 (got 16 columns instead of 25)
#     Line #2753 (got 27 columns instead of 25)
#     Line #2755 (got 26 columns instead of 25)
#     Line #2757 (got 26 columns instead of 25)
#     Line #2758 (got 26 columns instead of 25)
#     Line #2759 (got 27 columns instead of 25)
#     Line #2760 (got 26 columns instead of 25)
#     Line #2764 (got 26 columns instead of 25)
#     Line #2766 (got 26 columns instead of 25)
#     Line #2767 (got 26 columns instead of 25)
#     Line #2768 (got 26 columns instead of 25)
#     Line #2776 (got 26 columns instead of 25)
#     Line #2779 (got 26 columns instead of 25)
#     Line #2780 (got 26 columns instead of 25)
#     Line #2781 (got 26 columns instead of 25)
#     Line #2784 (got 26 columns instead of 25)
#     Line #2786 (got 26 columns instead of 25)
#     Line #2787 (got 26 columns instead of 25)
#     Line #2788 (got 26 columns instead of 25)
#     Line #2791 (got 26 columns instead of 25)
#     Line #2793 (got 26 columns instead of 25)
#     Line #2794 (got 26 columns instead of 25)
#     Line #2795 (got 26 columns instead of 25)
#     Line #2798 (got 26 columns instead of 25)
#     Line #2800 (got 27 columns instead of 25)
#     Line #2801 (got 26 columns instead of 25)
#     Line #2803 (got 26 columns instead of 25)
#     Line #2805 (got 26 columns instead of 25)
#     Line #2807 (got 26 columns instead of 25)
#     Line #2808 (got 27 columns instead of 25)
#     Line #2814 (got 26 columns instead of 25)
#     Line #2816 (got 26 columns instead of 25)
#     Line #2817 (got 26 columns instead of 25)
#     Line #2820 (got 26 columns instead of 25)
#     Line #2821 (got 26 columns instead of 25)
#     Line #2822 (got 26 columns instead of 25)
#   data = np.genfromtxt(

# %%
# @title
years = filtered_data['YEAR_ID']
sales = filtered_data['SALES']
unique_years = np.unique(years)
print("YEAR_ID\tTOTAL_SALES")

for year in unique_years:
    year_sales = np.sum(sales[years == year])
    print(f"{year}\t{year_sales}")
# Out:
# YEAR_ID	TOTAL_SALES
# 2003	1837756.01
# 2004	2513235.1500000004
# 2005	936926.27

# %%
# @title
# Store total sales per year
yearly_sales = np.array([
    np.sum(sales[years == year]) for year in unique_years
])

# Find index of highest and lowest sales
max_index = np.argmax(yearly_sales)
min_index = np.argmin(yearly_sales)

# Get corresponding years and sales values
highest_sales_year = unique_years[max_index]
lowest_sales_year = unique_years[min_index]

highest_sales_value = yearly_sales[max_index]
lowest_sales_value = yearly_sales[min_index]

print("\nYear with Highest Sales:", highest_sales_year, "->", highest_sales_value)
print("Year with Lowest Sales:", lowest_sales_year, "->", lowest_sales_value)
# Out:
# Year with Highest Sales: 2004 -> 2513235.1500000004
# Year with Lowest Sales: 2005 -> 936926.27

# %%
# @title
# Extract product and sales columns
products = filtered_data['PRODUCTCODE']
sales = filtered_data['SALES']

# Remove rows with missing sales
valid = ~np.isnan(sales)
products = products[valid]
sales = sales[valid]

# Unique products
unique_products = np.unique(products)

# Total sales per product
product_sales = np.array([
    np.sum(sales[products == product]) for product in unique_products
])

# Find most and least sold products
max_index = np.argmax(product_sales)
min_index = np.argmin(product_sales)

most_sold_product = unique_products[max_index]
least_sold_product = unique_products[min_index]

most_sold_value = product_sales[max_index]
least_sold_value = product_sales[min_index]

print("\nMost Sold Product:", most_sold_product, "->", most_sold_value)
print("Least Sold Product:", least_sold_product, "->", least_sold_value)
# Out:
# Most Sold Product: S18_3232 -> 109770.3
# Least Sold Product: S24_2022 -> 17238.09

# %%
# @title
# Extract required columns
years = filtered_data['YEAR_ID']
productlines = filtered_data['PRODUCTLINE']
status = filtered_data['STATUS']
sales = filtered_data['SALES']

# Remove rows with missing sales
valid = ~np.isnan(sales)
years = years[valid]
productlines = productlines[valid]
status = status[valid]
sales = sales[valid]

unique_years = np.unique(years)

for year in unique_years:
    print(f"\nYEAR: {year}")

    # Filter data for this year
    year_mask = years == year

    year_products = productlines[year_mask]
    year_status = status[year_mask]
    year_sales = sales[year_mask]

    # -------- SHIPPED --------
    shipped_mask = year_status == 'Shipped'
    shipped_products = year_products[shipped_mask]
    shipped_sales = year_sales[shipped_mask]

    if shipped_sales.size > 0:
        unique_shipped_products = np.unique(shipped_products)

        shipped_totals = np.array([
            np.sum(shipped_sales[shipped_products == p])
            for p in unique_shipped_products
        ])

        max_ship_idx = np.argmax(shipped_totals)
        min_ship_idx = np.argmin(shipped_totals)

        print("  Highest SHIPPED ProductLine:",
              unique_shipped_products[max_ship_idx], "->",
              shipped_totals[max_ship_idx])

        print("  Lowest SHIPPED ProductLine:",
              unique_shipped_products[min_ship_idx], "->",
              shipped_totals[min_ship_idx])
    else:
        print("  No SHIPPED data")

    # -------- CANCELLED --------
    cancelled_mask = year_status == 'Cancelled'
    cancelled_products = year_products[cancelled_mask]
    cancelled_sales = year_sales[cancelled_mask]

    if cancelled_sales.size > 0:
        unique_cancelled_products = np.unique(cancelled_products)

        cancelled_totals = np.array([
            np.sum(cancelled_sales[cancelled_products == p])
            for p in unique_cancelled_products
        ])

        max_can_idx = np.argmax(cancelled_totals)
        min_can_idx = np.argmin(cancelled_totals)

        print("  Highest CANCELLED ProductLine:",
              unique_cancelled_products[max_can_idx], "->",
              cancelled_totals[max_can_idx])

        print("  Lowest CANCELLED ProductLine:",
              unique_cancelled_products[min_can_idx], "->",
              cancelled_totals[min_can_idx])
    else:
        print("  No CANCELLED data")
# Out:
# YEAR: 2003
#   Highest SHIPPED ProductLine: Classic Cars -> 727578.25
#   Lowest SHIPPED ProductLine: Trains -> 36490.95
#   Highest CANCELLED ProductLine: Ships -> 24242.6
#   Lowest CANCELLED ProductLine: Classic Cars -> 5924.16
#
# YEAR: 2004
#   Highest SHIPPED ProductLine: Classic Cars -> 859440.1400000001
#   Lowest SHIPPED ProductLine: Trains -> 59172.34
#   Highest CANCELLED ProductLine: Ships -> 25583.29
#   Lowest CANCELLED ProductLine: Classic Cars -> 2910.4
#
# YEAR: 2005
#   Highest SHIPPED ProductLine: Classic Cars -> 256916.74
#   Lowest SHIPPED ProductLine: Trains -> 18566.94
#   No CANCELLED data

# %%
# @title
# Extract required columns
years = filtered_data['YEAR_ID']
productlines = filtered_data['PRODUCTLINE']
status = filtered_data['STATUS']

# Filter only "In Process" records
inprocess_mask = status == 'In Process'

inprocess_years = years[inprocess_mask]
inprocess_productlines = productlines[inprocess_mask]

# Unique years
unique_years = np.unique(inprocess_years)

for year in unique_years:
    print(f"\nYEAR: {year}")

    # Filter for this year
    year_mask = inprocess_years == year
    year_productlines = inprocess_productlines[year_mask]

    # Unique productlines for this year
    unique_productlines = np.unique(year_productlines)

    for pl in unique_productlines:
        count = np.sum(year_productlines == pl)
        print(f"  {pl}: {count}")
# Out:
# YEAR: 2005
#   Vintage Cars: 9

# %%
# @title
 # Extract required columns
years = filtered_data['YEAR_ID']
customers = filtered_data['CUSTOMERNAME']
sales = filtered_data['SALES']

# Remove rows with missing sales
valid = ~np.isnan(sales)
years = years[valid]
customers = customers[valid]
sales = sales[valid]

# Unique years
unique_years = np.unique(years)

for year in unique_years:
    print(f"\nYEAR: {year}")

    # Filter data for this year
    year_mask = years == year
    year_customers = customers[year_mask]
    year_sales = sales[year_mask]

    # Unique customers in this year
    unique_customers = np.unique(year_customers)

    # Total sales per customer
    customer_totals = np.array([
        np.sum(year_sales[year_customers == cust])
        for cust in unique_customers
    ])

    # Find highest sales customer
    max_index = np.argmax(customer_totals)

    print("  Customer with Highest Sales:",
          unique_customers[max_index], "->",
          customer_totals[max_index])
# Out:
# YEAR: 2003
#   Customer with Highest Sales: Mini Gifts Distributors Ltd. -> 185128.11999999997
#
# YEAR: 2004
#   Customer with Highest Sales: Mini Gifts Distributors Ltd. -> 256474.26
#
# YEAR: 2005
#   Customer with Highest Sales: Mini Gifts Distributors Ltd. -> 213255.67999999996

# %%
# @title
# Extract required columns
years = filtered_data['YEAR_ID']
countries = filtered_data['COUNTRY']
sales = filtered_data['SALES']

# Remove rows with missing sales
valid = ~np.isnan(sales)
years = years[valid]
countries = countries[valid]
sales = sales[valid]

# Unique years
unique_years = np.unique(years)

for year in unique_years:
    print(f"\nYEAR: {year}")

    # Filter data for this year
    year_mask = years == year
    year_countries = countries[year_mask]
    year_sales = sales[year_mask]

    # Unique countries in this year
    unique_countries = np.unique(year_countries)

    # Total sales per country
    country_totals = np.array([
        np.sum(year_sales[year_countries == country])
        for country in unique_countries
    ])

    # Find country with highest sales
    max_index = np.argmax(country_totals)

    print("  Country with Highest Sales:",
          unique_countries[max_index], "->",
          country_totals[max_index])
# Out:
# YEAR: 2003
#   Country with Highest Sales: USA -> 1240927.08
#
# YEAR: 2004
#   Country with Highest Sales: USA -> 1634136.06
#
# YEAR: 2005
#   Country with Highest Sales: USA -> 637364.26

# %%
# @title
years = filtered_data['YEAR_ID']
months = filtered_data['MONTH_ID']
sales = filtered_data['SALES']
products = filtered_data['PRODUCTCODE']
productlines = filtered_data['PRODUCTLINE']
status = filtered_data['STATUS']
customers = filtered_data['CUSTOMERNAME']
countries = filtered_data['COUNTRY']

# Remove rows with missing sales
valid = ~np.isnan(sales)
years = years[valid]
months = months[valid]
sales = sales[valid]
products = products[valid]
productlines = productlines[valid]
status = status[valid]
customers = customers[valid]
countries = countries[valid]

unique_years = np.unique(years)

for year in unique_years:
    print(f"\nYEAR: {year}")
    year_mask = years == year

    year_months = months[year_mask]
    year_sales = sales[year_mask]

    unique_months = np.unique(year_months)
    monthly_totals = []

    for m in unique_months:
        total = np.sum(year_sales[year_months == m])
        monthly_totals.append(total)
        print(f"  Month {m} Total Sales: {total}")

    monthly_totals = np.array(monthly_totals)

    print("  Highest Sales Month:", unique_months[np.argmax(monthly_totals)])
    print("  Lowest Sales Month:", unique_months[np.argmin(monthly_totals)])
# Out:
# YEAR: 2003
#   Month 1 Total Sales: 73699.30000000002
#   Month 2 Total Sales: 140836.19
#   Month 3 Total Sales: 58492.96000000001
#   Month 4 Total Sales: 63406.55
#   Month 5 Total Sales: 52819.58
#   Month 6 Total Sales: 96090.45000000001
#   Month 7 Total Sales: 159334.62
#   Month 8 Total Sales: 164602.67
#   Month 9 Total Sales: 76692.54999999999
#   Month 10 Total Sales: 319330.72
#   Month 11 Total Sales: 432074.89999999997
#   Month 12 Total Sales: 200375.52000000002
#   Highest Sales Month: 11
#   Lowest Sales Month: 5
#
# YEAR: 2004
#   Month 1 Total Sales: 37850.08
#   Month 2 Total Sales: 146627.39
#   Month 3 Total Sales: 106334.27
#   Month 4 Total Sales: 72248.92
#   Month 5 Total Sales: 173171.2
#   Month 6 Total Sales: 154909.67
#   Month 7 Total Sales: 217509.23
#   Month 8 Total Sales: 289454.69
#   Month 9 Total Sales: 202369.89
#   Month 10 Total Sales: 280820.11
#   Month 11 Total Sales: 644370.84
#   Month 12 Total Sales: 187568.86000000002
#   Highest Sales Month: 11
#   Lowest Sales Month: 1
#
# YEAR: 2005
#   Month 1 Total Sales: 152125.37
#   Month 2 Total Sales: 119030.32
#   Month 3 Total Sales: 258757.33000000002
#   Month 4 Total Sales: 170529.37999999998
#   Month 5 Total Sales: 236483.87000000002
#   Highest Sales Month: 3
#   Lowest Sales Month: 2

# %%
# @title
for year in unique_years:
    print(f"\nYEAR: {year}")
    year_mask = years == year

    for month in np.unique(months[year_mask]):
        print(f"  Month: {month}")

        mask = (years == year) & (months == month)
        m_products = products[mask]
        m_sales = sales[mask]

        unique_products = np.unique(m_products)
        totals = np.array([
            np.sum(m_sales[m_products == p]) for p in unique_products
        ])

        print("    Max Product:", unique_products[np.argmax(totals)])
        print("    Min Product:", unique_products[np.argmin(totals)])
# Out:
# YEAR: 2003
#   Month: 1
#     Max Product: S10_1949
#     Min Product: S18_2432
#   Month: 2
#     Max Product: S12_1108
#     Min Product: S72_3212
#   Month: 3
#     Max Product: S18_3232
#     Min Product: S24_2972
#   Month: 4
#     Max Product: S18_2238
#     Min Product: S72_1253
#   Month: 5
#     Max Product: S12_2823
#     Min Product: S24_2022
#   Month: 6
#     Max Product: S12_1108
#     Min Product: S72_1253
#   Month: 7
#     Max Product: S18_3232
#     Min Product: S24_2972
#   Month: 8
#     Max Product: S12_3891
#     Min Product: S32_2206
#   Month: 9
#     Max Product: S12_1099
#     Min Product: S24_3969
#   Month: 10
#     Max Product: S24_1578
#     Min Product: S24_1937
#   Month: 11
#     Max Product: S12_3891
#     Min Product: S24_2840
#   Month: 12
#     Max Product: S10_1949
#     Min Product: S50_1341
#
# YEAR: 2004
#   Month: 1
#     Max Product: S10_1949
#     Min Product: S18_1367
#   Month: 2
#     Max Product: S18_2238
#     Min Product: S24_2840
#   Month: 3
#     Max Product: S10_1949
#     Min Product: S24_2840
#   Month: 4
#     Max Product: S10_4698
#     Min Product: S24_1937
#   Month: 5
#     Max Product: S18_1662
#     Min Product: S24_2841
#   Month: 6
#     Max Product: S10_4698
#     Min Product: S32_2206
#   Month: 7
#     Max Product: S18_2238
#     Min Product: S24_1628
#   Month: 8
#     Max Product: S12_2823
#     Min Product: S24_1937
#   Month: 9
#     Max Product: S12_1108
#     Min Product: S24_1937
#   Month: 10
#     Max Product: S10_4962
#     Min Product: S24_2022
#   Month: 11
#     Max Product: S10_1678
#     Min Product: S18_2957
#   Month: 12
#     Max Product: S24_1937
#     Min Product: S24_2022
#
# YEAR: 2005
#   Month: 1
#     Max Product: S18_1342
#     Min Product: S24_1937
#   Month: 2
#     Max Product: S18_3320
#     Min Product: S18_1367
#   Month: 3
#     Max Product: S700_1691
#     Min Product: S72_1253
#   Month: 4
#     Max Product: S18_1749
#     Min Product: S18_4409
#   Month: 5
#     Max Product: S24_3856
#     Min Product: S24_2972

# %%
# @title
for year in unique_years:
    print(f"\nYEAR: {year}")

    for month in np.unique(months[years == year]):
        print(f"  Month: {month}")

        base_mask = (years == year) & (months == month)

        for st in ['Shipped', 'Cancelled']:
            st_mask = base_mask & (status == st)

            if np.sum(st_mask) == 0:
                print(f"    {st}: No data")
                continue

            pl = productlines[st_mask]
            sl = sales[st_mask]

            unique_pl = np.unique(pl)
            totals = np.array([
                np.sum(sl[pl == p]) for p in unique_pl
            ])

            print(f"    {st} Highest:",
                  unique_pl[np.argmax(totals)])
            print(f"    {st} Lowest:",
                  unique_pl[np.argmin(totals)])
# Out:
# YEAR: 2003
#   Month: 1
#     Shipped Highest: Vintage Cars
#     Shipped Lowest: Classic Cars
#     Cancelled: No data
#   Month: 2
#     Shipped Highest: Planes
#     Shipped Lowest: Trains
#     Cancelled: No data
#   Month: 3
#     Shipped Highest: Classic Cars
#     Shipped Lowest: Trucks and Buses
#     Cancelled: No data
#   Month: 4
#     Shipped Highest: Classic Cars
#     Shipped Lowest: Trucks and Buses
#     Cancelled: No data
#   Month: 5
#     Shipped Highest: Motorcycles
#     Shipped Lowest: Vintage Cars
#     Cancelled: No data
#   Month: 6
#     Shipped Highest: Classic Cars
#     Shipped Lowest: Vintage Cars
#     Cancelled: No data
#   Month: 7
#     Shipped Highest: Classic Cars
#     Shipped Lowest: Vintage Cars
#     Cancelled: No data
#   Month: 8
#     Shipped Highest: Motorcycles
#     Shipped Lowest: Trains
#     Cancelled: No data
#   Month: 9
#     Shipped Highest: Classic Cars
#     Shipped Lowest: Motorcycles
#     Cancelled: No data
#   Month: 10
#     Shipped Highest: Classic Cars
#     Shipped Lowest: Ships
#     Cancelled Highest: Ships
#     Cancelled Lowest: Classic Cars
#   Month: 11
#     Shipped Highest: Classic Cars
#     Shipped Lowest: Motorcycles
#     Cancelled: No data
#   Month: 12
#     Shipped Highest: Classic Cars
#     Shipped Lowest: Trains
#     Cancelled: No data
#
# YEAR: 2004
#   Month: 1
#     Shipped Highest: Vintage Cars
#     Shipped Lowest: Trucks and Buses
#     Cancelled: No data
#   Month: 2
#     Shipped Highest: Classic Cars
#     Shipped Lowest: Trains
#     Cancelled: No data
#   Month: 3
#     Shipped Highest: Trucks and Buses
#     Shipped Lowest: Trains
#     Cancelled: No data
#   Month: 4
#     Shipped Highest: Motorcycles
#     Shipped Lowest: Vintage Cars
#     Cancelled: No data
#   Month: 5
#     Shipped Highest: Planes
#     Shipped Lowest: Ships
#     Cancelled Highest: Ships
#     Cancelled Lowest: Classic Cars
#   Month: 6
#     Shipped Highest: Motorcycles
#     Shipped Lowest: Planes
#     Cancelled: No data
#   Month: 7
#     Shipped Highest: Classic Cars
#     Shipped Lowest: Trains
#     Cancelled: No data
#   Month: 8
#     Shipped Highest: Classic Cars
#     Shipped Lowest: Ships
#     Cancelled: No data
#   Month: 9
#     Shipped Highest: Classic Cars
#     Shipped Lowest: Trains
#     Cancelled: No data
#   Month: 10
#     Shipped Highest: Classic Cars
#     Shipped Lowest: Ships
#     Cancelled: No data
#   Month: 11
#     Shipped Highest: Classic Cars
#     Shipped Lowest: Trains
#     Cancelled: No data
#   Month: 12
#     Shipped Highest: Classic Cars
#     Shipped Lowest: Ships
#     Cancelled: No data
#
# YEAR: 2005
#   Month: 1
#     Shipped Highest: Classic Cars
#     Shipped Lowest: Trains
#     Cancelled: No data
#   Month: 2
#     Shipped Highest: Vintage Cars
#     Shipped Lowest: Ships
#     Cancelled: No data
#   Month: 3
#     Shipped Highest: Classic Cars
#     Shipped Lowest: Trucks and Buses
#     Cancelled: No data
#   Month: 4
#     Shipped Highest: Vintage Cars
#     Shipped Lowest: Ships
#     Cancelled: No data
#   Month: 5
#     Shipped Highest: Classic Cars
#     Shipped Lowest: Trains
#     Cancelled: No data

# %%
# @title
for year in unique_years:
    print(f"\nYEAR: {year}")

    for month in np.unique(months[years == year]):
        print(f"  Month: {month}")

        mask = (
            (years == year) &
            (months == month) &
            (status == 'In Process')
        )

        if np.sum(mask) == 0:
            print("    No In-Process products")
            continue

        pl = productlines[mask]
        for p in np.unique(pl):
            print(f"    {p}: {np.sum(pl == p)}")
# Out:
# YEAR: 2003
#   Month: 1
#     No In-Process products
#   Month: 2
#     No In-Process products
#   Month: 3
#     No In-Process products
#   Month: 4
#     No In-Process products
#   Month: 5
#     No In-Process products
#   Month: 6
#     No In-Process products
#   Month: 7
#     No In-Process products
#   Month: 8
#     No In-Process products
#   Month: 9
#     No In-Process products
#   Month: 10
#     No In-Process products
#   Month: 11
#     No In-Process products
#   Month: 12
#     No In-Process products
#
# YEAR: 2004
#   Month: 1
#     No In-Process products
#   Month: 2
#     No In-Process products
#   Month: 3
#     No In-Process products
#   Month: 4
#     No In-Process products
#   Month: 5
#     No In-Process products
#   Month: 6
#     No In-Process products
#   Month: 7
#     No In-Process products
#   Month: 8
#     No In-Process products
#   Month: 9
#     No In-Process products
#   Month: 10
#     No In-Process products
#   Month: 11
#     No In-Process products
#   Month: 12
#     No In-Process products
#
# YEAR: 2005
#   Month: 1
#     No In-Process products
#   Month: 2
#     No In-Process products
#   Month: 3
#     No In-Process products
#   Month: 4
#     No In-Process products
#   Month: 5
#     Vintage Cars: 9

# %%
# @title
for year in unique_years:
    print(f"\nYEAR: {year}")

    for month in np.unique(months[years == year]):
        print(f"  Month: {month}")

        mask = (years == year) & (months == month)

        # CUSTOMER
        m_customers = customers[mask]
        m_sales = sales[mask]

        unique_cust = np.unique(m_customers)
        cust_totals = np.array([
            np.sum(m_sales[m_customers == c]) for c in unique_cust
        ])

        print("    Top Customer:",
              unique_cust[np.argmax(cust_totals)])

        # COUNTRY
        m_countries = countries[mask]
        unique_ctry = np.unique(m_countries)
        ctry_totals = np.array([
            np.sum(m_sales[m_countries == c]) for c in unique_ctry
        ])

        print("    Top Country:",
              unique_ctry[np.argmax(ctry_totals)])
# Out:
# YEAR: 2003
#   Month: 1
#     Top Customer: Baane Mini Imports
#     Top Country: Norway
#   Month: 2
#     Top Customer: Danish Wholesale Imports
#     Top Country: Denmark
#   Month: 3
#     Top Customer: Motor Mint Distributors Inc.
#     Top Country: USA
#   Month: 4
#     Top Customer: Salzburg Collectables
#     Top Country: Austria
#   Month: 5
#     Top Customer: Signal Gift Stores
#     Top Country: USA
#   Month: 6
#     Top Customer: Muscle Machine Inc
#     Top Country: USA
#   Month: 7
#     Top Customer: Mini Gifts Distributors Ltd.
#     Top Country: USA
#   Month: 8
#     Top Customer: Mini Gifts Distributors Ltd.
#     Top Country: USA
#   Month: 9
#     Top Customer: Collectables For Less Inc.
#     Top Country: USA
#   Month: 10
#     Top Customer: Corporate Gift Ideas Co.
#     Top Country: USA
#   Month: 11
#     Top Customer: Online Diecast Creations Co.
#     Top Country: USA
#   Month: 12
#     Top Customer: Muscle Machine Inc
#     Top Country: USA
#
# YEAR: 2004
#   Month: 1
#     Top Customer: West Coast Collectables Co.
#     Top Country: USA
#   Month: 2
#     Top Customer: Collectable Mini Designs Co.
#     Top Country: USA
#   Month: 3
#     Top Customer: Mini Gifts Distributors Ltd.
#     Top Country: USA
#   Month: 4
#     Top Customer: Danish Wholesale Imports
#     Top Country: USA
#   Month: 5
#     Top Customer: The Sharp Gifts Warehouse
#     Top Country: USA
#   Month: 6
#     Top Customer: Handji Gifts& Co
#     Top Country: USA
#   Month: 7
#     Top Customer: L'ordine Souveniers
#     Top Country: USA
#   Month: 8
#     Top Customer: Amica Models & Co.
#     Top Country: USA
#   Month: 9
#     Top Customer: Scandinavian Gift Ideas
#     Top Country: USA
#   Month: 10
#     Top Customer: Mini Gifts Distributors Ltd.
#     Top Country: USA
#   Month: 11
#     Top Customer: Vitachrome Inc.
#     Top Country: USA
#   Month: 12
#     Top Customer: Mini Gifts Distributors Ltd.
#     Top Country: USA
#
# YEAR: 2005
#   Month: 1
#     Top Customer: Mini Gifts Distributors Ltd.
#     Top Country: USA
#   Month: 2
#     Top Customer: Mini Gifts Distributors Ltd.
#     Top Country: USA
#   Month: 3
#     Top Customer: Mini Gifts Distributors Ltd.
#     Top Country: USA
#   Month: 4
#     Top Customer: The Sharp Gifts Warehouse
#     Top Country: USA
#   Month: 5
#     Top Customer: Salzburg Collectables
#     Top Country: USA

# %%
# @title
unique_products = np.unique(products)

max_prices = np.array([
    np.max(prices[products == p]) for p in unique_products
])

max_index = np.argmax(max_prices)

print("Highest Priced Product:", unique_products[max_index])
print("Highest Price:", max_prices[max_index])
# Out:
# Highest Priced Product: S10_1678
# Highest Price: 100.0

# %%
# @title
# Extract product column
products = filtered_data['PRODUCTCODE']

# Get unique products
unique_products = np.unique(products)

# Count orders for each product
order_counts = np.array([
    np.sum(products == p) for p in unique_products
])

# Find product with maximum orders
max_index = np.argmax(order_counts)

most_ordered_product = unique_products[max_index]
max_orders = order_counts[max_index]

print("Product with Maximum Orders:", most_ordered_product)
print("Number of Orders:", max_orders)
# Out:
# Product with Maximum Orders: S18_3232
# Number of Orders: 21

# %%
# @title
years = filtered_data['YEAR_ID']
sales = filtered_data['SALES']

# Remove missing sales
valid = ~np.isnan(sales)
years = years[valid]
sales = sales[valid]

unique_years = np.unique(years)

print("YEAR_ID\tTOTAL_REVENUE")

for year in unique_years:
    year_revenue = np.sum(sales[years == year])
    print(f"{year}\t{year_revenue}")
# Out:
# YEAR_ID	TOTAL_REVENUE
# 2003	1837756.01
# 2004	2513235.1500000004
# 2005	936926.27

# %%
# @title
months = filtered_data['MONTH_ID']
months = months[valid]

for year in unique_years:
    print(f"\nYEAR: {year}")

    year_mask = years == year
    year_months = months[year_mask]
    year_sales = sales[year_mask]

    unique_months = np.unique(year_months)

    for month in unique_months:
        month_revenue = np.sum(year_sales[year_months == month])
        print(f"  Month {month}: {month_revenue}")
# Out:
# YEAR: 2003
#   Month 1: 73699.30000000002
#   Month 2: 140836.19
#   Month 3: 58492.96000000001
#   Month 4: 63406.55
#   Month 5: 52819.58
#   Month 6: 96090.45000000001
#   Month 7: 159334.62
#   Month 8: 164602.67
#   Month 9: 76692.54999999999
#   Month 10: 319330.72
#   Month 11: 432074.89999999997
#   Month 12: 200375.52000000002
#
# YEAR: 2004
#   Month 1: 37850.08
#   Month 2: 146627.39
#   Month 3: 106334.27
#   Month 4: 72248.92
#   Month 5: 173171.2
#   Month 6: 154909.67
#   Month 7: 217509.23
#   Month 8: 289454.69
#   Month 9: 202369.89
#   Month 10: 280820.11
#   Month 11: 644370.84
#   Month 12: 187568.86000000002
#
# YEAR: 2005
#   Month 1: 152125.37
#   Month 2: 119030.32
#   Month 3: 258757.33000000002
#   Month 4: 170529.37999999998
#   Month 5: 236483.87000000002
